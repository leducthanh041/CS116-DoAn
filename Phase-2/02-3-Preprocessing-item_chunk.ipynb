# %%
import os
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Tạo hàm để đọc file parquet (đọc các file parquet - data sau khi được processed)

# %%
def read_parquet_user(train_path: str):
    # Lấy tất cả các file parquet trong thư mục
    files = [os.path.join(train_path, f) for f in os.listdir(train_path) if f.endswith('.parquet')]
    
    # Phân loại các file theo loại tên
    user_chunk_files = [file for file in files if 'user_chunk' in file]
        
    # Đọc các file riêng biệt thành DataFrame
    user_chunk_df = pl.concat([pl.read_parquet(file) for file in user_chunk_files]) if user_chunk_files else None
        
    # Trả về một dictionary chứa các DataFrame
    return user_chunk_df

# %%
def read_parquet_item(train_path: str):
    # Lấy tất cả các file parquet trong thư mục
    files = [os.path.join(train_path, f) for f in os.listdir(train_path) if f.endswith('.parquet')]
    
    # Phân loại các file theo loại tên
    item_chunk_files = [file for file in files if 'item_chunk' in file]
        
    # Đọc các file riêng biệt thành DataFrame
    item_chunk_df = pl.concat([pl.read_parquet(file) for file in item_chunk_files]) if item_chunk_files else None
        
    # Trả về một dictionary chứa các DataFrame
    return item_chunk_df

# %%
def read_parquet_transaction(train_path: str):
    # Lấy tất cả các file parquet trong thư mục
    files = [os.path.join(train_path, f) for f in os.listdir(train_path) if f.endswith('.parquet')]
    
    # Phân loại các file theo loại tên
    purchase_chunk_files = [file for file in files if 'purchase_history_daily_chunk' in file]
        
    # Đọc các file riêng biệt thành DataFrame
    purchase_chunk_df = pl.concat([pl.read_parquet(file) for file in purchase_chunk_files]) if purchase_chunk_files else None
        
    # Trả về một dictionary chứa các DataFrame
    return purchase_chunk_df

# %% [markdown]
# # Tạo hàm lưu file parquet sau mỗi task

# %%
def split_and_save_parquet(df, num_files, output_dir):
    """
    Tách DataFrame thành nhiều file Parquet và lưu vào thư mục đích.
    
    :param df: DataFrame cần tách
    :param num_files: Số lượng file Parquet muốn tách
    :param output_dir: Thư mục lưu các file Parquet
    """
    # Đảm bảo thư mục tồn tại
    os.makedirs(output_dir, exist_ok=True)
    
    # Tính số dòng mỗi file sẽ có
    num_rows = df.height
    rows_per_file = num_rows // num_files

    # Tách DataFrame thành các phần và lưu mỗi phần vào một file Parquet
    for i in range(num_files):
        start_row = i * rows_per_file
        # Đảm bảo phần cuối cùng sẽ chứa tất cả các dòng còn lại
        end_row = (i + 1) * rows_per_file if i < num_files - 1 else num_rows
        
        # Tách phần DataFrame
        split_df = df[start_row:end_row]
        
        # Lưu phần DataFrame vào file .parquet
        file_path = os.path.join(output_dir, f"sale_pers.item_chunk_{i}.parquet")
        split_df.write_parquet(file_path)
        print(f"Đã lưu file: {file_path}")

# %% [markdown]
# # Task 2: Xử lý NULL, Xử lý Outlier

# %% [markdown]
# ## Xử lý null

# %% [markdown]
# ### Xử lý age_group

# %%
df_age = read_parquet_item("./preprocessed-dataset")
df_age.head()
# Out:
# shape: (5, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ item_id   ┆ price     ┆ category_ ┆ category_ ┆ … ┆ descripti ┆ gender_ta ┆ age_group ┆ age_grou │
# │ ---       ┆ ---       ┆ l1        ┆ l2        ┆   ┆ on_new    ┆ rget_fina ┆ _final    ┆ p_final_ │
# │ str       ┆ decimal[3 ┆ ---       ┆ ---       ┆   ┆ ---       ┆ l         ┆ ---       ┆ before   │
# │           ┆ 8,4]      ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 050202000 ┆ 99000.000 ┆ Babycare  ┆ Bình sữa, ┆ … ┆ Chi tiết  ┆ Không xác ┆ Từ 9M     ┆ Từ 9M    │
# │ 0004      ┆ 0         ┆           ┆ phụ kiện  ┆   ┆ sản phẩm  ┆ định      ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ Tên sản   ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ phẩm: Hộp ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 2 núm ty  ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ DrBrown's ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ Options   ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ Plus cổ   ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ rộng Y    ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ cu…       ┆           ┆           ┆          │
# │ 001029004 ┆ 69000.000 ┆ Thời      ┆ Cơ cấu    ┆ … ┆ Không xác ┆ Bé Gái    ┆ Từ 36M    ┆ Từ 36M   │
# │ 0150      ┆ 0         ┆ trang     ┆ hàng cũ   ┆   ┆ định      ┆           ┆           ┆          │
# │ 000801000 ┆ 45000.000 ┆ Đồ chơi & ┆ 0-1Y      ┆ … ┆ Chi tiết  ┆ Không xác ┆ 0-12M     ┆ 0-12M    │
# │ 0015      ┆ 0         ┆ Sách      ┆           ┆   ┆ sản phẩm  ┆ định      ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ Tên sản   ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ phẩm:     ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ Miếng Gặm ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ Nướu Papa ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ (CEQ004)  ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ (Cá hồng) ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ C…        ┆           ┆           ┆          │
# │ 002001000 ┆ 401000.00 ┆ Tã        ┆ Merries   ┆ … ┆ Không xác ┆ Không xác ┆ ["Từ 6M", ┆ ["Từ     │
# │ 0094      ┆ 00        ┆           ┆           ┆   ┆ định      ┆ định      ┆ "3M-6M",  ┆ 6M",     │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ "12-36M"] ┆ "3M-6M", │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ "12-36M" │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ]        │
# │ 002001000 ┆ 401000.00 ┆ Tã        ┆ Merries   ┆ … ┆ Không xác ┆ Không xác ┆ 12-36M    ┆ 12-36M   │
# │ 0098      ┆ 00        ┆           ┆           ┆   ┆ định      ┆ định      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# #### Ý tưởng 2 (tiếp theo):

# %% [markdown]
# ##### Thống kê

# %%
import polars as pl

df = df_age   # hoặc df_filled tùy bạn đang dùng

# Hàm tiện dụng để lấy danh sách unique của 1 cột
def get_unique_list(df, col):
    return (
        df.select(col)
          .unique()
          .sort(col)
          .get_column(col)
          .to_list()
    )

# Lấy tất cả class
age_list    = get_unique_list(df, "age_group_final")

# Gom vào dictionary
category_dict = {
    "age_group": age_list
}

print(len(age_list))

# In ra theo từng dòng, rất dễ đọc
print("\n=== DANH SÁCH TẤT CẢ CLASS CỦA TỪNG CATEGORY ===\n")
for key, value in category_dict.items():
    print(f"{key}: {value}\n")
# Out:
# 322
#
# === DANH SÁCH TẤT CẢ CLASS CỦA TỪNG CATEGORY ===
#
# age_group: ['0-10M', '0-11M', '0-120M', '0-12M', '0-144M', '0-14M', '0-18M', '0-1M', '0-24M', '0-2M', '0-30M', '0-36M', '0-3M', '0-48M', '0-4M', '0-5M', '0-60M', '0-6M', '0-72M', '0-84M', '0-9M', '1-12M', '1-18M', '1-24M', '1-36M', '1-3M', '108-120M', '108-132M', '12-108M', '12-120M', '12-132M', '12-144M', '12-14M', '12-192M', '12-24M', '12-36M', '12-48M', '12-60M', '12-72M', '120-144M', '12M-18M', '12M-4Y', '13-16M', '13-17M', '132-144M', '13M-24M', '14-17M', '18-24M', '18M-24M', '18M-36M', '18M-4Y', '1M-12M', '1M-15M', '1M-3M', '216-360M', '216-720M', '24-120M', '24-36M', '24-48M', '24-60M', '24-72M', '24-96M', '2M-15M', '2M-6M', '3-12M', '3-18M', '3-24M', '3-36M', '3-60M', '3-6M', '36-120M', '36-144M', '36-216M', '36-48M', '36-60M', '36-72M', '3M-12M', '3M-18M', '3M-24M', '3M-6M', '4-24M', '4-30M', '4-6M', '48-60M', '48-72M', '4M-4Y', '4M-6M', '6-12M', '6-144M', '6-15M', '6-18M', '6-24M', '6-30M', '6-36M', '6-60M', '6-72M', '6-84M', '6-8M', '6-9M', '60-72M', '6M-10M', '6M-12M', '6M-12Y', '6M-15M', '6M-18M', '6M-24M', '6M-36M', '6M-5Y', '6M-6Y', '6M-9M', '7-15M', '7-24M', '7-60M', '8-24M', '84-120M', '84-144M', '84-168M', '84-96M', '9-20M', '9-24M', '9-48M', '9-72M', '96-168M', '9M-12M', '9M-15M', '9M-20M', '9M-24M', '9M-36M', '9M-4Y', '9M-6Y', 'Không xác định', 'Mẹ', 'Trên 6M', 'Từ 0M', 'Từ 10M', 'Từ 120M', 'Từ 12M', 'Từ 144M', 'Từ 156M', 'Từ 15M', 'Từ 168M', 'Từ 16M', 'Từ 18M', 'Từ 19M', 'Từ 1M', 'Từ 216M', 'Từ 228M', 'Từ 24M', 'Từ 2M', 'Từ 36M', 'Từ 3M', 'Từ 48M', 'Từ 4M', 'Từ 5M', 'Từ 60M', 'Từ 6M', 'Từ 72M', 'Từ 7M', 'Từ 84M', 'Từ 8M', 'Từ 9M', '["0-120M", "Từ 12M"]', '["0-120M", "Từ 60M"]', '["0-12M", "12-24M", "24-36M", "36-48M"]', '["0-12M", "12-36M", "36-144M", "Từ 0M"]', '["0-12M", "12-36M", "36-144M"]', '["0-12M", "12-36M", "Từ 0M"]', '["0-12M", "12-36M", "Từ 48M"]', '["0-12M", "12-36M", "Từ 4M"]', '["0-12M", "12-36M"]', '["0-12M", "Từ 0M"]', '["0-12M", "Từ 12M"]', '["0-12M", "Từ 1M"]', '["0-144M", "12-36M", "3M-6M", "0-12M"]', '["0-144M", "Từ 12M"]', '["0-144M", "Từ 144M"]', '["0-1M", "1-4M", "Từ 0M"]', '["0-24M", "24-36M", "36-48M", "48-60M"]', '["0-24M", "Từ 0M"]', '["0-24M", "Từ 6M"]', '["0-25M", "Từ 6M"]', '["0-36M", "Từ 0M"]', '["0-3M", "3-6M", "6-12M", "Từ 0M"]', '["0-3M", "3-6M", "6-9M", "Từ 9M"]', '["0-3M", "3-6M", "Từ 6M"]', '["0-48M", "Từ 48M"]', '["0-60M", "Từ 60M"]', '["0-6M", "12-36M", "36-96M", "6-12M", "Từ 96M"]', '["0-6M", "12-36M", "36-96M", "6-12M"]', '["0-6M", "6-12M", "12-18M"]', '["0-6M", "6-12M"]', '["0-6M", "6-9M", "9-12M"]', '["0-6M", "Từ 0M"]', '["0-6M", "Từ 3M"]', '["0-6M", "Từ 6M"]', '["0-72M", "84-132M"]', '["0-72M", "Từ 0M"]', '["0-72M", "Từ 36M"]', '["0-72M", "Từ 72M"]', '["0-84M", "Từ 6M"]', '["1-24M", "Từ 1M"]', '["10-12M", "12-18M", "18-24M"]', '["10-12M", "12-18M"]', '["12-108M", "Từ 0M", "0-12M"]', '["12-144M", "0-12M"]', '["12-18M", "18-24M", "24-30M", "30-36M", "Từ 12M"]', '["12-18M", "18-24M", "24-30M"]', '["12-18M", "18-24M", "Từ 12M"]', '["12-24M", "0-12M"]', '["12-24M", "24-36M", "36-48M"]', '["12-24M", "24-48M", "48-72M"]', '["12-24M", "24-60M", "Từ 12M"]', '["12-24M", "36-48M"]', '["12-24M", "Từ 12M"]', '["12-36M", "36-192M", "Từ 12M"]', '["12-36M", "36-192M"]', '["12-36M", "36-48M", "48-60M"]', '["12-36M", "36-48M"]', '["12-36M", "36-72M", "72-108M"]', '["12-36M", "36-72M", "84-144M", "0-12M", "Từ 144M"]', '["12-36M", "36-84M", "96-144M"]', '["12-36M", "48-96M", "108-132M", "144-216M", "24-48M", "Từ 12M"]', '["12-36M", "48-96M", "108-132M", "Từ 12M"]', '["12-36M", "48-96M", "108-144M", "0-12M"]', '["12-36M", "48-96M", "108-156M", "Từ 12M", "0-12M"]', '["12-36M", "60-72M", "24-36M", "Từ 12M", "3M-6M", "0-12M"]', '["12-36M", "Từ 12M", "0-12M", "36-48M"]', '["12-36M", "Từ 12M", "0-12M", "3M-6M"]', '["12-36M", "Từ 12M", "0-12M", "48-60M"]', '["12-36M", "Từ 12M", "0-12M", "60-72M"]', '["12-36M", "Từ 12M", "0-12M", "Từ 60M"]', '["12-36M", "Từ 12M", "0-12M"]', '["12-36M", "Từ 12M", "24-36M", "0-12M"]', '["12-36M", "Từ 12M", "24-36M", "36-48M"]', '["12-36M", "Từ 12M", "24-36M"] ...

# %%
import polars as pl
import textwrap

# ===============================
# 1) LỌC DỮ LIỆU CẦN XUẤT
# ===============================
import polars as pl

# Điều kiện "có thông tin" cho description
desc_has_info = (
    pl.col("description").is_not_null()
    & (pl.col("description") != "Không xác định")
    & (pl.col("description").str.strip_chars() != "")
)

# Điều kiện "có thông tin" cho description_new
desc_new_has_info = (
    pl.col("description_new").is_not_null()
    & (pl.col("description_new") != "Không xác định")
    & (pl.col("description_new").str.strip_chars() != "")
)

# Lọc các dòng cần thống kê
df_unknown_desc = (
    df_age
    .filter(
        (pl.col("age_group_final") == "Không xác định")
        & (desc_has_info | desc_new_has_info)
    )
    .select([
        "item_id",
        "description",
        "description_new",
        "age_group_final",
    ])
)
print("Số dòng cần xuất:", df_unknown_desc.height)

# ===============================
# 2) HÀM FORMAT TEXT
# ===============================
def wrap175(text):
    if text is None:
        return ""
    return textwrap.fill(str(text), width=175)

# ===============================
# 3) XUẤT RA FILE TXT
# ===============================
output_file = "unknown_description_items.txt"

with open(output_file, "w", encoding="utf-8") as f:
    for row in df_unknown_desc.iter_rows(named=True):
        f.write("=====================================\n")
        f.write(f"item_id: {row['item_id']}\n\n")

        f.write("age_group_final: ")
        f.write(f"{row['age_group_final']}\n\n")

        f.write("description:\n")
        f.write(wrap175(row["description"]) + "\n\n")

        f.write("description_new:\n")
        f.write(wrap175(row["description_new"]) + "\n\n")

print(f"Đã xuất file: {output_file}")
# Out:
# Số dòng cần xuất: 3530
# Đã xuất file: unknown_description_items.txt

# %%
# Thống kê
total_rows = df_age.height
unknown_after = df_age.filter(pl.col("age_group_final") == "Không xác định").height
ratio_after = unknown_after / total_rows * 100

print(f"Số dòng 'Không xác định': {unknown_after}")
print(f"Tỉ lệ: {ratio_after:.2f}%")
print()
# Out:
# Số dòng 'Không xác định': 10595
# Tỉ lệ: 38.78%

# %% [markdown]
# ##### Thử fill lại

# %% [markdown]
# Cấu hình & tiền xử lý

# %%
import re
from typing import Optional, List, Tuple

import polars as pl

# =========================================
# 1. CẤU HÌNH CONTEXT & TỪ KHÓA
# =========================================

POS_CONTEXT = [
    # Trẻ em / baby
    "bé", "trẻ", "trẻ em", "em bé",
    "baby", "kid", "child", "children",
    "thiếu nhi", "newborn", "sơ sinh",

    # Ngữ cảnh độ tuổi
    "độ tuổi",
    "tháng tuổi",
    "months old",
    "years old",
    "tuổi",
]

CHILD_WORDS = [
    "bé", "trẻ", "trẻ em", "em bé",
    "baby", "kid", "child", "children",
]

NEG_STRONG = [
    # hạn sử dụng / bảo quản / bảo hành
    "sử dụng trong vòng",
    "hạn sử dụng", "thời hạn", "hạn dùng", "hạn sử dụng tốt nhất",
    "bảo quản", "kể từ ngày sản xuất", "sau khi mở nắp",
    "bảo hành",

    # không dùng / không phù hợp cho trẻ
    "không thích hợp cho trẻ",
    "không thích hợp với trẻ",
    "không dùng cho trẻ",
    "không nên dùng cho trẻ",
    "không phù hợp cho trẻ",
    "không phù hợp với trẻ",
    "không sử dụng sản phẩm cho trẻ",
    "không sử dụng cho trẻ",

    # nguy cơ / rủi ro
    "nguy cơ",
    "nguy hiểm",
    "rủi ro",

    # tiếng Anh
    "not suitable for children",
    "do not use for children",
]

# Đơn vị thời gian dùng để quy đổi -> THÁNG
MONTH_WORDS = ["tháng", "thang", "month", "months"]
YEAR_WORDS  = ["tuổi", "year", "years", "y"]
WEEK_WORDS  = ["tuần", "tuan", "week", "weeks"]
DAY_WORDS   = ["ngày", "ngay", "day", "days", "ngày tuổi", "ngay tuoi"]

WINDOW_POS = 80   # nới rộng để bắt được "dành cho bé ..." / "đối tượng sử dụng ..."
WINDOW_NEG = 100

# Các cụm nói về "dưới sự hướng dẫn/giám sát"
NEG_SUPERVISION = [
    "dưới sự hướng dẫn",
    "cần sử dụng dưới sự hướng dẫn",
    "dưới sự giám sát",
    "under supervision",
    "under the guidance",
]

# Từ gợi ý mạnh rằng câu đang nói về tuổi / đối tượng dùng (không chỉ mô tả thời gian)
USAGE_KEYWORDS = [
    "dành cho", "cho bé", "cho trẻ",
    "dùng cho", "sử dụng cho",
    "đối tượng sử dụng",
    "phù hợp cho", "phù hợp với",
    "độ tuổi phù hợp", "độ tuổi sử dụng",
    "trong độ tuổi",
    "giai đoạn từ", "giai đoạn dành cho",
    "khuyên dùng cho",
]

# Từ khoá nhận biết cân nặng / khối lượng
WEIGHT_KEYWORDS = [
    "cân nặng", "trẻ nặng", "bé nặng",
    "kg", "kilogram", "ký", "kí",
]


# =========================================
# 2. PREPROCESS TEXT TRƯỚC KHI MATCH
# =========================================

def preprocess_text_for_age(text: Optional[str]) -> str:
    """
    Chuẩn hoá text:
      - Nếu None -> ""
      - Chuẩn hoá khoảng trắng
      - Chèn space chỗ dính chữ: 'hợpBé' -> 'hợp Bé'
      - Chèn space trước '(' nếu dính
      - Chèn space sau ':' nếu thiếu
    """
    if text is None:
        return ""

    t = str(text)

    # Chuẩn hoá khoảng trắng (bao gồm cả non-breaking space)
    t = re.sub(r"\s+", " ", t)

    # Tách giữa 1 ký tự bất kỳ (không phải space) và chữ hoa (kể cả Đ)
    # 'hợpBé' -> 'hợp Bé', 'sizeSản' -> 'size Sản'
    t = re.sub(r"([^\s])([A-ZĐ])", r"\1 \2", t)

    # 'Formula(1-3 tuổi)' -> 'Formula (1-3 tuổi)'
    t = re.sub(r"([a-zA-ZÀ-ỹ])\(", r"\1 (", t)

    # 'Độ tuổi:5-7Y' -> 'Độ tuổi: 5-7Y'
    t = re.sub(r":([^\s])", r": \1", t)

    return t.strip()

# %%
# =========================================
# 3. REGEX PATTERNS CHO EXTRACT
# =========================================

# Range đặc biệt "3M-5T"
AGE_MT_RANGE_PATTERN = re.compile(
    r"(?P<n1>\d{1,2})\s*m\s*(?:-|–|—|đến|to)\s*(?P<n2>\d{1,2})\s*t"
)

# "0-6 tháng ... đến ... 3 tuổi"
CROSS_MONTH_RANGE_TO_YEAR_PATTERN = re.compile(
    r"(?P<m_start>\d{1,2})\s*-\s*(?P<m_end>\d{1,2})\s*"
    r"(?:tháng|thang|month|months)"
    r".{0,40}?(?:đến|tới|to)\s*.{0,40}?"
    r"(?P<y_end>\d{1,2}(?:[.,]\d+)?)\s*(?:tuổi|year|years|y)",
)

# "sơ sinh ... đến ... 3 tuổi"
NEWBORN_RANGE_PATTERN = re.compile(
    r"(?:từ\s+giai\s*đoạn\s+)?sơ\s*sinh"
    r".{0,30}?(?:đến|tới|to|-).{0,30}?"
    r"\d{1,2}(?:[.,]\d+)?\s*(tháng|thang|month|months|tuổi|year|years|y)",
)

# Newborn phrase không số: "trẻ sơ sinh trở lên", "từ trẻ sơ sinh"
NEWBORN_PHRASE_PATTERN = re.compile(
    r"(?:từ\s+)?(?:trẻ\s+)?sơ\s*sinh(?:\s*(trở lên|\+))?"
)

# "trong độ tuổi từ 1 đến 5", "độ tuổi từ 2 đến 6"
AGE_WORD_RANGE_PATTERN = re.compile(
    r"độ\s*tuổi[^0-9]{0,40}"
    r"(?:từ\s*)?"
    r"(?P<n1>\d{1,2}(?:[.,]\d+)?)\s*(?:-|–|—|đến|to)\s*"
    r"(?P<n2>\d{1,2}(?:[.,]\d+)?)"
)

# "6 tháng đến 5 tuổi", "từ 1 tuần - 1 tuổi"
RANGE_BOTH_UNITS_PATTERN = re.compile(
    r"(?P<n1>\d{1,2}(?:[.,]\d+)?)\s*"
    r"(?P<u1>tháng tuổi|tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks)\s*"
    r"(?:-|–|—|đến|to)\s*"
    r"(?P<n2>\d{1,2}(?:[.,]\d+)?)\s*"
    r"(?P<u2>tháng tuổi|tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks)"
)

# "0-12 tháng", "từ 2-6 tuổi", "Từ 1-36 tháng tuổi"
RANGE_ONE_UNIT_PATTERN = re.compile(
    r"(?:(?:từ)\s*)?"
    r"(?P<n1>\d{1,2}(?:[.,]\d+)?)\s*"
    r"(?:-|–|—|đến|to)\s*"
    r"(?P<n2>\d{1,2}(?:[.,]\d+)?)\s*"
    r"(?P<u>tháng tuổi|tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks)"
)

# Single: "dưới 12 tháng", "từ 6 tháng tuổi", "trên 6 tuổi", "từ 1 ngày tuổi"
SINGLE_PATTERN = re.compile(
    r"(?:(?P<cmp>dưới|under|<|từ|trên|hơn|sau|>=|over|more than)\s*)?"
    r"(?P<n>\d{1,2}(?:[.,]\d+)?)\s*"
    r"(?P<u>"
    r"tháng tuổi|tháng|thang|month|months|"
    r"tuổi|year|years|"
    r"tuần|tuan|week|weeks|"
    r"ngày tuổi|ngày|ngay|day|days"
    r")"
    r"(?:\s*(?P<suffix>trở lên|\+))?"
)

# %%
# =========================================
# 4. HÀM CONTEXT POS / NEG
# =========================================

def has_pos_context(context: str) -> bool:
    return any(tok in context for tok in POS_CONTEXT)


def has_neg_context(context: str) -> bool:
    ctx = context

    # 1) NEG mạnh (hạn sử dụng / bảo quản / bảo hành / nguy cơ...)
    if any(phrase in ctx for phrase in NEG_STRONG):
        return True

    # 2) "không ... (phù hợp/thích hợp/dùng/sử dụng/bôi/cho) ... trẻ"
    if "không" in ctx:
        if any(v in ctx for v in ["phù hợp", "thích hợp", "dùng", "sử dụng", "bôi", "cho"]):
            if any(c in ctx for c in CHILD_WORDS):
                return True

    # 3) "tránh ... trẻ"
    if "tránh" in ctx and any(c in ctx for c in CHILD_WORDS):
        return True

    # 4) English NEG
    if "not suitable" in ctx and any(c in ctx for c in ["child", "children", "kid", "baby"]):
        return True
    if "do not use" in ctx and any(c in ctx for c in ["child", "children", "kid", "baby"]):
        return True

    # 5) "dưới sự hướng dẫn/giám sát"
    if any(phrase in ctx for phrase in NEG_SUPERVISION):
        if "dưới" in ctx or "under" in ctx:
            if any(c in ctx for c in CHILD_WORDS):
                return True

    # 6) "6 tháng đầu", "giai đoạn 6 tháng đầu"
    if "tháng đầu" in ctx or "tháng đầu đời" in ctx:
        if any(k in ctx for k in ["trong ", "trong vòng", "giai đoạn"]):
            return True

    return False


# =========================================
# 5. HELPER: NHẬN DIỆN PHRASE CÂN NẶNG
# =========================================

def is_weight_phrase(match_text: str, left_context: str, right_context: str) -> bool:
    """
    Trả True nếu cụm này nhiều khả năng nói về CÂN NẶNG, không phải TUỔI:
      - match_text chứa 'kg', 'kilogram', ...
      - HOẶC right_context gần bên phải chứa 'kg' (trường hợp dính liền 20-35kgBỉm)
      - HOẶC có 'cân nặng' / 'trẻ nặng' / 'bé nặng' trong match_text, left_context hoặc right_context.
    """
    s = match_text
    lc = left_context
    rc = right_context

    # 1) '... 10-15kg' nằm trong match_text
    if any(kw in s for kw in ["kg", "kilogram", "ký", "kí"]):
        return True

    # 2) '... 10-15kgBỉm' -> 'kg' nằm ngay sau match
    if any(kw in rc[:10] for kw in ["kg", "kilogram", "ký", "kí"]):
        return True

    # 3) 'cân nặng', 'trẻ nặng', 'bé nặng'
    weight_markers = ["cân nặng", "trẻ nặng", "bé nặng"]
    if any(kw in s for kw in weight_markers):
        return True
    if any(kw in lc for kw in weight_markers):
        return True
    if any(kw in rc for kw in weight_markers):
        return True

    return False


# =========================================
# 6. HELPER: NHẬN DIỆN DURATION "sau X tháng sử dụng"
# =========================================

DURATION_PATTERN = re.compile(
    r"sau\s+\d{1,2}\s*"
    r"(tháng|thang|month|months|tuần|tuan|week|weeks)\s+"
    r"(sử dụng|su dung|dùng|dung)"
)

def is_duration_context(context: str) -> bool:
    """
    Trả True nếu context mô tả thời lượng sử dụng:
    ví dụ 'sau 3 tháng sử dụng', 'sau 6 tháng dùng' -> KHÔNG phải tuổi.
    """
    return bool(DURATION_PATTERN.search(context))

# %%
# =========================================
# 7. HÀM EXTRACT_AGE_PHRASES (DÙNG desc_all)
# =========================================

def extract_age_phrases(desc_all: Optional[str]) -> List[str]:
    """
    Nhận 1 chuỗi desc_all (merge 2 description),
    preprocess và trả về list các cụm tuổi/tháng/ngày.
    """
    if desc_all is None:
        return []

    pre = preprocess_text_for_age(desc_all)
    if not pre:
        return []

    text = pre.lower()

    matches: List[str] = []
    used_spans: List[Tuple[int, int]] = []

    def overlap_span(start: int, end: int) -> bool:
        return any(not (end <= s or start >= e) for (s, e) in used_spans)

    def get_contexts(start_idx: int, end_idx: int) -> Tuple[str, str, str, str]:
        left_pos = max(0, start_idx - WINDOW_POS)
        right_pos = min(len(text), end_idx + WINDOW_POS)
        context_pos = text[left_pos:right_pos]

        left_neg = max(0, start_idx - WINDOW_NEG)
        right_neg = min(len(text), end_idx + WINDOW_NEG)
        context_neg = text[left_neg:right_neg]

        left_weight = text[max(0, start_idx - 40):start_idx]
        right_weight = text[end_idx:min(len(text), end_idx + 40)]

        return context_pos, context_neg, left_weight, right_weight

    def handle_match(m: re.Match):
        start_idx, end_idx = m.span()
        if overlap_span(start_idx, end_idx):
            return

        ctx_pos, ctx_neg, left_weight, right_weight = get_contexts(start_idx, end_idx)
        match_text = text[start_idx:end_idx].strip()

        # 1) Bỏ các cụm về CÂN NẶNG
        if is_weight_phrase(match_text, left_weight, right_weight):
            return

        # 2) Bỏ các cụm mô tả THỜI LƯỢNG SỬ DỤNG (sau X tháng sử dụng/dùng)
        if is_duration_context(ctx_pos):
            return

        # 3) Nếu đơn vị là TUẦN (week), yêu cầu phải có usage-keywords
        #    để tránh câu mô tả như "khi được 6 đến 8 tuần thì giấc ngủ..."
        if any(w in match_text for w in ["tuần", "tuan", "week", "weeks"]):
            if not any(kw in ctx_pos for kw in USAGE_KEYWORDS):
                return

        # 4) POS/NEG context tổng quát
        if not has_pos_context(ctx_pos) or has_neg_context(ctx_neg):
            return

        matches.append(match_text)
        used_spans.append((start_idx, end_idx))

    # 0) Range "3M-5T"
    for m in AGE_MT_RANGE_PATTERN.finditer(text):
        handle_match(m)

    # 1) Range "0-6 tháng ... đến ... 3 tuổi"
    for m in CROSS_MONTH_RANGE_TO_YEAR_PATTERN.finditer(text):
        handle_match(m)

    # 2) Range newborn "sơ sinh ... đến ... 3 tuổi"
    for m in NEWBORN_RANGE_PATTERN.finditer(text):
        handle_match(m)

    # 3) Newborn phrase "trẻ sơ sinh trở lên", "từ trẻ sơ sinh"
    for m in NEWBORN_PHRASE_PATTERN.finditer(text):
        handle_match(m)

    # 4) Range 2 đơn vị: '6 tháng đến 5 tuổi', 'từ 1 tuần - 1 tuổi'
    for m in RANGE_BOTH_UNITS_PATTERN.finditer(text):
        handle_match(m)

    # 5) Range 1 đơn vị: '0-12 tháng', 'từ 2-6 tuổi', 'Từ 1-36 tháng tuổi'
    for m in RANGE_ONE_UNIT_PATTERN.finditer(text):
        handle_match(m)

    # 6) "độ tuổi từ 2 đến 6"
    for m in AGE_WORD_RANGE_PATTERN.finditer(text):
        handle_match(m)

    # 7) Single: 'dưới 12 tháng', 'từ 6 tháng tuổi', 'từ 1 ngày tuổi'
    for m in SINGLE_PATTERN.finditer(text):
        handle_match(m)

    return matches

# %%
# =========================================
# 8. CHUẨN HOÁ VỀ CANONICAL (THÁNG / NGÀY)
# =========================================

def _to_months(num_str: str, unit: str) -> int:
    """Chuyển '1', '1,5', '2.5' -> số THÁNG theo unit."""
    val = float(num_str.replace(",", "."))
    unit = unit.lower()

    if unit in MONTH_WORDS:
        return int(round(val))
    if unit in YEAR_WORDS:
        return int(round(val * 12))
    if unit in WEEK_WORDS:
        m = int(round(val * 7.0 / 30.0))
        return max(0, m)

    raise ValueError(f"Unit không hợp lệ cho _to_months: {unit}")


def _parse_canonical(c: str) -> Tuple[float, Optional[float], bool]:
    """
    Trả về (start_in_months, end_in_months_or_None, is_plus)
    Hỗ trợ:
      - '6-36M', '12M+', '0-12D', '1D+'
    (giữ lại để dùng nếu sau này cần, hiện tại normalize_age_phrase_list không dùng coverage nữa)
    """
    is_plus = c.endswith("+")
    base = c[:-1] if is_plus else c

    unit = base[-1]   # 'M' hoặc 'D'
    inner = base[:-1]

    if "-" in inner:
        a, b = inner.split("-", 1)
        start_val = float(a)
        end_val = float(b)
    else:
        start_val = end_val = float(inner)

    if unit == "M":
        start_m = start_val
        end_m = None if is_plus else end_val
    elif unit == "D":
        start_m = start_val / 30.0
        end_m = None if is_plus else end_val / 30.0
    else:
        raise ValueError(f"Unit canonical không hợp lệ: {unit} trong {c}")

    return start_m, end_m, is_plus

# %%
def normalize_age_phrase(raw: str) -> Optional[str]:
    """
    Chuẩn hóa 1 cụm tuổi/tháng/ngày về canonical:

      - 'từ 3 tháng tuổi'           -> '3M+'
      - 'từ 2-6 tuổi'               -> '24-72M'
      - 'trong độ tuổi từ 1 đến 5'  -> '12-60M' (nếu KHÔNG có chữ 'tháng' trong cụm)
      - '0 - 48 tháng tuổi'         -> '0-48M'
      - '0-6 tháng'                 -> '0-6M'
      - 'sơ sinh ... đến 2 tuổi'    -> '0-24M'
      - 'trẻ sơ sinh trở lên'       -> '0M+'
      - 'từ sơ sinh'                -> '0M+'
      - 'từ 1 ngày tuổi'            -> '1D+'
      - 'dưới 3 tuổi'               -> '0-36M'
      - 'sơ sinh' / 'trẻ sơ sinh' ĐƠN LẺ -> None (bỏ)
    """
    if not raw:
        return None

    s2 = raw.strip().lower()
    s2 = s2.replace("tháng tuổi", " tháng ")
    s2 = s2.replace("thang tuoi", " thang ")
    s2 = re.sub(r"\s+", " ", s2)

    # 0) '3m-5t'
    m_mt = re.search(
        r"(\d{1,2})\s*m\s*(?:-|–|—|đến|to)\s*(\d{1,2})\s*t",
        s2,
    )
    if m_mt:
        a_str, b_str = m_mt.group(1), m_mt.group(2)
        start_m = _to_months(a_str, "tháng")
        end_m   = _to_months(b_str, "tuổi")
        if start_m > end_m:
            start_m, end_m = end_m, start_m
        return f"{int(start_m)}-{int(end_m)}M"

    # 1) RANGE 2 ĐƠN VỊ: '6 tháng đến 5 tuổi', 'từ 1 tháng đến 2 tuổi'
    m_both = re.search(
        r"(?:từ\s*)?"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks)\s*"
        r"(?:-|–|—|đến|to)\s*"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks)",
        s2,
    )
    if m_both:
        a_str, u1, b_str, u2 = m_both.group(1), m_both.group(2), m_both.group(3), m_both.group(4)
        start_m = _to_months(a_str, u1)
        end_m   = _to_months(b_str, u2)
        if start_m > end_m:
            start_m, end_m = end_m, start_m
        return f"{int(start_m)}-{int(end_m)}M"

    # 2) RANGE 1 ĐƠN VỊ: '1-3 tuổi', 'từ 1-36 tháng'
    m_range_unit = re.search(
        r"(?:từ\s*)?"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(?:-|–|—|đến|to)\s*"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks)",
        s2,
    )
    if m_range_unit:
        a_str = m_range_unit.group(1)
        b_str = m_range_unit.group(2)
        unit  = m_range_unit.group(3)
        start_m = _to_months(a_str, unit)
        end_m   = _to_months(b_str, unit)
        if start_m > end_m:
            start_m, end_m = end_m, start_m
        return f"{int(start_m)}-{int(end_m)}M"

    # 3) 'độ tuổi từ 2 đến 6' (MẶC ĐỊNH NĂM, nếu KHÔNG chứa từ 'tháng')
    m_ageword = re.search(
        r"độ\s*tuổi[^0-9]{0,40}"
        r"(?:từ\s*)?"
        r"(\d{1,2}(?:[.,]\d+)?)\s*(?:-|–|—|đến|to)\s*"
        r"(\d{1,2}(?:[.,]\d+)?)",
        s2,
    )
    if m_ageword:
        sub = s2[m_ageword.start():m_ageword.end()]
        if not any(w in sub for w in ["tháng", "thang", "month", "months"]):
            a_str = m_ageword.group(1)
            b_str = m_ageword.group(2)
            start_m = _to_months(a_str, "tuổi")
            end_m   = _to_months(b_str, "tuổi")
            if start_m > end_m:
                start_m, end_m = end_m, start_m
            return f"{int(start_m)}-{int(end_m)}M"

    # 4) XỬ LÝ CÁC CASE CÓ 'SƠ SINH'
    if "sơ sinh" in s2:
        # 4.1. 'từ X ... đến Y ...' trong câu có 'sơ sinh' -> X-Y
        m_nb_range_xy = re.search(
            r"từ\s+(\d{1,2}(?:[.,]\d+)?)\s*"
            r"(tháng|thang|month|months|tuổi|year|years|y)\s*"
            r"(?:-|–|—|đến|to)\s*"
            r"(\d{1,2}(?:[.,]\d+)?)\s*"
            r"(tháng|thang|month|months|tuổi|year|years|y)",
            s2,
        )
        if m_nb_range_xy:
            a_str, u1, b_str, u2 = (
                m_nb_range_xy.group(1),
                m_nb_range_xy.group(2),
                m_nb_range_xy.group(3),
                m_nb_range_xy.group(4),
            )
            start_m = _to_months(a_str, u1)
            end_m   = _to_months(b_str, u2)
            if start_m > end_m:
                start_m, end_m = end_m, start_m
            return f"{int(start_m)}-{int(end_m)}M"

        # 4.2. 'sơ sinh ... đến ... N tháng/tuổi' -> 0-NM
        m_nb_range = re.search(
            r"(?:từ\s+giai\s*đoạn\s+)?sơ\s*sinh"
            r".{0,30}?(?:đến|tới|to|-).{0,30}?"
            r"(\d{1,2}(?:[.,]\d+)?)\s*"
            r"(tháng|thang|month|months|tuổi|year|years|y)",
            s2,
        )
        if m_nb_range:
            n_str = m_nb_range.group(1)
            unit  = m_nb_range.group(2)
            end_m = _to_months(n_str, unit)
            if end_m <= 0:
                return None
            return f"0-{int(end_m)}M"

        # 4.3. 'từ sơ sinh' / 'từ trẻ sơ sinh' -> 0M+
        m_nb_from0 = re.search(
            r"từ\s+(?:trẻ\s+)?sơ\s*sinh\b(?:\s*(trở lên|\+))?",
            s2,
        )
        if m_nb_from0:
            return "0M+"

        # 4.4. 'trẻ sơ sinh trở lên' -> 0M+
        m_nb_plus = re.search(
            r"(?:trẻ\s+)?sơ\s*sinh\s*(trở lên|\+)",
            s2,
        )
        if m_nb_plus:
            return "0M+"

        # 4.5. 'sơ sinh' / 'trẻ sơ sinh' ĐƠN LẺ -> bỏ (không fill)
        return None

    # 5) 'dưới N ...' -> '0-NM' hoặc '0-ND'
    m_under = re.search(
        r"(dưới|under|<)\s*(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks|ngày tuổi|ngày|ngay|day|days)",
        s2,
    )
    if m_under:
        n_str = m_under.group(2)
        unit  = m_under.group(3).lower()
        if unit in DAY_WORDS:
            val = float(n_str.replace(",", "."))
            end_d = int(round(val))
            if end_d <= 0:
                return None
            return f"0-{end_d}D"
        else:
            end_m = _to_months(n_str, unit)
            if end_m <= 0:
                return None
            return f"0-{int(end_m)}M"

    # 6) 'từ / trên / hơn / sau N ...' -> 'NM+' hoặc 'ND+'
    m_from = re.search(
        r"(từ|trên|hơn|sau|>=|over|more than)\s*"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks|ngày tuổi|ngày|ngay|day|days)"
        r"(?:\s*(trở lên|\+))?",
        s2,
    )
    if m_from:
        n_str = m_from.group(2)
        unit  = m_from.group(3).lower()
        if unit in DAY_WORDS:
            val = float(n_str.replace(",", "."))
            start_d = int(round(val))
            return f"{start_d}D+"
        else:
            start_m = _to_months(n_str, unit)
            return f"{int(start_m)}M+"

    # 7) 'N ... trở lên' -> 'NM+' hoặc 'ND+'
    m_suffix_plus = re.search(
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks|ngày tuổi|ngày|ngay|day|days)\s*"
        r"(trở lên|\+)",
        s2,
    )
    if m_suffix_plus:
        n_str = m_suffix_plus.group(1)
        unit  = m_suffix_plus.group(2).lower()
        if unit in DAY_WORDS:
            val = float(n_str.replace(",", "."))
            start_d = int(round(val))
            return f"{start_d}D+"
        else:
            start_m = _to_months(n_str, unit)
            return f

# %%
def normalize_age_phrase(raw: str) -> Optional[str]:
    """
    Chuẩn hóa 1 cụm tuổi/tháng/ngày về canonical:

      - 'từ 3 tháng tuổi'           -> '3M+'
      - 'từ 2-6 tuổi'               -> '24-72M'
      - 'trong độ tuổi từ 1 đến 5'  -> '12-60M' (nếu KHÔNG có chữ 'tháng' gần đó)
      - '0 - 48 tháng tuổi'         -> '0-48M'
      - 'sơ sinh ... đến 2 tuổi'    -> '0-24M'
      - 'trẻ sơ sinh trở lên'       -> '0M+'
      - 'từ sơ sinh'                -> '0M+'
      - 'từ 1 ngày tuổi'            -> '1D+'
      - 'dưới 3 tuổi'               -> '0-36M'
      - 'sơ sinh' / 'trẻ sơ sinh' ĐƠN LẺ -> None (bỏ)
    """
    if not raw:
        return None

    s2 = raw.strip().lower()
    s2 = s2.replace("tháng tuổi", " tháng ")
    s2 = s2.replace("thang tuoi", " thang ")
    s2 = re.sub(r"\s+", " ", s2)

    # 0) '3m-5t'
    m_mt = re.search(
        r"(\d{1,2})\s*m\s*(?:-|–|—|đến|to)\s*(\d{1,2})\s*t",
        s2,
    )
    if m_mt:
        a_str, b_str = m_mt.group(1), m_mt.group(2)
        start_m = _to_months(a_str, "tháng")
        end_m   = _to_months(b_str, "tuổi")
        if start_m > end_m:
            start_m, end_m = end_m, start_m
        return f"{int(start_m)}-{int(end_m)}M"

    # 1) RANGE 2 ĐƠN VỊ: '6 tháng đến 5 tuổi', 'từ 1 tháng đến 2 tuổi'
    m_both = re.search(
        r"(?:từ\s*)?"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks)\s*"
        r"(?:-|–|—|đến|to)\s*"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks)",
        s2,
    )
    if m_both:
        a_str, u1, b_str, u2 = m_both.group(1), m_both.group(2), m_both.group(3), m_both.group(4)
        start_m = _to_months(a_str, u1)
        end_m   = _to_months(b_str, u2)
        if start_m > end_m:
            start_m, end_m = end_m, start_m
        return f"{int(start_m)}-{int(end_m)}M"

    # 2) RANGE 1 ĐƠN VỊ: '1-3 tuổi', 'từ 1-36 tháng'
    m_range_unit = re.search(
        r"(?:từ\s*)?"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(?:-|–|—|đến|to)\s*"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks)",
        s2,
    )
    if m_range_unit:
        a_str = m_range_unit.group(1)
        b_str = m_range_unit.group(2)
        unit  = m_range_unit.group(3)
        start_m = _to_months(a_str, unit)
        end_m   = _to_months(b_str, unit)
        if start_m > end_m:
            start_m, end_m = end_m, start_m
        return f"{int(start_m)}-{int(end_m)}M"

    # 3) 'độ tuổi từ 2 đến 6' (MẶC ĐỊNH NĂM)
    m_ageword = re.search(
        r"độ\s*tuổi[^0-9]{0,40}"
        r"(?:từ\s*)?"
        r"(\d{1,2}(?:[.,]\d+)?)\s*(?:-|–|—|đến|to)\s*"
        r"(\d{1,2}(?:[.,]\d+)?)",
        s2,
    )
    if m_ageword:
        # Nếu ngay trong đoạn match có 'tháng' / 'month' -> đây là range theo THÁNG
        # đã/bị bắt bởi m_range_unit ở trên. Không ép sang NĂM nữa để tránh 0-576M.
        sub = s2[m_ageword.start():m_ageword.end()]
        if any(w in sub for w in ["tháng", "thang", "month", "months"]):
            # bỏ qua branch này, coi như không match theo 'tuổi'
            pass
        else:
            a_str = m_ageword.group(1)
            b_str = m_ageword.group(2)
            start_m = _to_months(a_str, "tuổi")
            end_m   = _to_months(b_str, "tuổi")
            if start_m > end_m:
                start_m, end_m = end_m, start_m
            return f"{int(start_m)}-{int(end_m)}M"

    # 4) XỬ LÝ CÁC CASE CÓ 'SƠ SINH'
    if "sơ sinh" in s2:
        # 4.1. 'từ X ... đến Y ...' trong câu có 'sơ sinh' -> X-Y
        m_nb_range_xy = re.search(
            r"từ\s+(\d{1,2}(?:[.,]\d+)?)\s*"
            r"(tháng|thang|month|months|tuổi|year|years|y)\s*"
            r"(?:-|–|—|đến|to)\s*"
            r"(\d{1,2}(?:[.,]\d+)?)\s*"
            r"(tháng|thang|month|months|tuổi|year|years|y)",
            s2,
        )
        if m_nb_range_xy:
            a_str, u1, b_str, u2 = (
                m_nb_range_xy.group(1),
                m_nb_range_xy.group(2),
                m_nb_range_xy.group(3),
                m_nb_range_xy.group(4),
            )
            start_m = _to_months(a_str, u1)
            end_m   = _to_months(b_str, u2)
            if start_m > end_m:
                start_m, end_m = end_m, start_m
            return f"{int(start_m)}-{int(end_m)}M"

        # 4.2. 'sơ sinh ... đến ... N tháng/tuổi' -> 0-NM
        m_nb_range = re.search(
            r"(?:từ\s+giai\s*đoạn\s+)?sơ\s*sinh"
            r".{0,30}?(?:đến|tới|to|-).{0,30}?"
            r"(\d{1,2}(?:[.,]\d+)?)\s*"
            r"(tháng|thang|month|months|tuổi|year|years|y)",
            s2,
        )
        if m_nb_range:
            n_str = m_nb_range.group(1)
            unit  = m_nb_range.group(2)
            end_m = _to_months(n_str, unit)
            if end_m <= 0:
                return None
            return f"0-{int(end_m)}M"

        # 4.3. 'từ sơ sinh' / 'từ trẻ sơ sinh' -> 0M+
        m_nb_from0 = re.search(
            r"từ\s+(?:trẻ\s+)?sơ\s*sinh\b(?:\s*(trở lên|\+))?",
            s2,
        )
        if m_nb_from0:
            return "0M+"

        # 4.4. 'trẻ sơ sinh trở lên' -> 0M+
        m_nb_plus = re.search(
            r"(?:trẻ\s+)?sơ\s*sinh\s*(trở lên|\+)",
            s2,
        )
        if m_nb_plus:
            return "0M+"

        # 4.5. 'sơ sinh' / 'trẻ sơ sinh' ĐƠN LẺ -> bỏ (không fill)
        return None

    # 5) 'dưới N ...' -> '0-NM' hoặc '0-ND'
    m_under = re.search(
        r"(dưới|under|<)\s*(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks|ngày tuổi|ngày|ngay|day|days)",
        s2,
    )
    if m_under:
        n_str = m_under.group(2)
        unit  = m_under.group(3).lower()
        if unit in DAY_WORDS:
            val = float(n_str.replace(",", "."))
            end_d = int(round(val))
            if end_d <= 0:
                return None
            return f"0-{end_d}D"
        else:
            end_m = _to_months(n_str, unit)
            if end_m <= 0:
                return None
            return f"0-{int(end_m)}M"

    # 6) 'từ / trên / hơn / sau N ...' -> 'NM+' hoặc 'ND+'
    m_from = re.search(
        r"(từ|trên|hơn|sau|>=|over|more than)\s*"
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks|ngày tuổi|ngày|ngay|day|days)"
        r"(?:\s*(trở lên|\+))?",
        s2,
    )
    if m_from:
        n_str = m_from.group(2)
        unit  = m_from.group(3).lower()
        if unit in DAY_WORDS:
            val = float(n_str.replace(",", "."))
            start_d = int(round(val))
            return f"{start_d}D+"
        else:
            start_m = _to_months(n_str, unit)
            return f"{int(start_m)}M+"

    # 7) 'N ... trở lên' -> 'NM+' hoặc 'ND+'
    m_suffix_plus = re.search(
        r"(\d{1,2}(?:[.,]\d+)?)\s*"
        r"(tháng|thang|month|months|tuổi|year|years|tuần|tuan|week|weeks|ngày tuổi|ngày|ngay|day|days)\s*"
        r"(trở lên|\+)",
        s2,
    )
    if m_suffix_plus:
        n_str = m_suffix_plus.group(1)
        unit  = m_suffix_plus.group(2).lower()
        if unit in DAY_WORDS:
            val = float(n_str.replace(",", "."))
            start_d = int(round(val))
            return f"{start_d}D+"
        else:
            start_m = _to_months(n_str, unit)
            return f"{int(start_m)}M+"

    # 8) không match gì có nghĩa -> bỏ
    return None

# %%
def normalize_age_phrase_list(raw_list: Optional[List[str]]) -> List[str]:
    """
    Chuẩn hoá list cụm tuổi và GIỮ TẤT CẢ các khoảng hợp lệ
    (chỉ loại bỏ trùng lặp exact-string, KHÔNG xoá khoảng con).
    """
    if raw_list is None:
        return []

    uniq: List[str] = []
    for raw in raw_list:
        norm = normalize_age_phrase(raw)
        if norm is not None and norm not in uniq:
            uniq.append(norm)

    return uniq

# %%
# df_unknown_desc đã được bạn tạo từ trước, gồm:
# item_id, description, description_new, age_group_final
# với điều kiện:
#   - age_group_final == "Không xác định"
#   - ít nhất 1 trong 2 description có thông tin

df_unknown = (
    df_unknown_desc
    .with_columns(
        pl.concat_str(
            [
                pl.col("description").fill_null(""),
                pl.col("description_new").fill_null(""),
            ],
            separator=" "
        ).alias("desc_all")
    )
    .with_columns(
        pl.col("desc_all").map_elements(
            extract_age_phrases,
            return_dtype=pl.List(pl.Utf8)
        ).alias("age_phrases_raw")
    )
    .with_columns(
        pl.col("age_phrases_raw").map_elements(
            normalize_age_phrase_list,
            return_dtype=pl.List(pl.Utf8)
        ).alias("age_ranges_norm")
    )
)

# Lấy tất cả canonical ranges đã detect
target_norm_list = (
    df_unknown
    .select(pl.col("age_ranges_norm"))
    .explode("age_ranges_norm")
    .filter(pl.col("age_ranges_norm").is_not_null())
    .unique()
    .to_series()
    .to_list()
)

print("Số lượng target_norm:", len(target_norm_list))
print(target_norm_list)

# Xuất ví dụ để review
pl.Config.set_fmt_str_lengths(100)
pl.Config.set_tbl_rows(50)

def wrap175(text):
    if text is None:
        return ""
    return textwrap.fill(str(text), width=175)

with open("output_age_norm.txt", "w", encoding="utf-8") as f:

    for tg in target_norm_list:
        f.write(f"\n=== VÍ DỤ CHO TARGET_NORM = {tg} ===\n\n")
        target_norm = tg

        examples = (
            df_unknown
            .filter(pl.col("age_ranges_norm").list.contains(target_norm))
            .select([
                "item_id",
                "age_group_final",
                "age_phrases_raw",
                "age_ranges_norm",
                "description",
                "description_new",
            ])
            .head(20)
        )

        for row in examples.iter_rows(named=True):
            f.write("======================================\n")
            f.write(f"item_id: {row['item_id']}\n")
            f.write(f"age_group_final: {row['age_group_final']}\n")
            f.write(f"age_phrases_raw: {row['age_phrases_raw']}\n")
            f.write(f"age_ranges_norm: {row['age_ranges_norm']}\n\n")

            f.write("description:\n")
            f.write(wrap175(row["description"]) + "\n\n")

            f.write("description_new:\n")
            f.write(wrap175(row["description_new"]) + "\n\n")

print("Đã xuất file: output_age_norm.txt")
# Out:
# Số lượng target_norm: 53
# ['3M+', '216M+', '12-36M', '0-24M', '12-72M', '36-72M', '24M+', '18-24M', '12-18M', '7-24M', '1-2M', '228M+', '0-3M', '24-72M', '0-12M', '0-7M', '48-60M', '0-144M', '156M+', '0M+', '24-36M', '12M+', '9M+', '9-36M', '1D+', '144M+', '36-144M', '0-48M', '60M+', '192M+', '480M+', '1-15M', '0-576M', '5D+', '9-15M', '1M+', '36-48M', '1-36M', '9-24M', '6-12M', '48M+', '0-36M', '84-144M', '12-24M', '4M+', '0-15M', '36M+', '36-120M', '24-60M', '6M+', '18M+', '0-72M', '0-6M']
# Đã xuất file: output_age_norm.txt

# %% [markdown]
# Fill các giá trị từ target_norm

# %%
import polars as pl

# df_unknown hiện đang có:
# - item_id
# - age_ranges_norm: List[str] (canonical, ví dụ: ["0-12M", "12-36M", "60M+"])

# 1) explode để mỗi dòng là 1 (item_id, age_range)
df_item_norm = (
    df_unknown
    .select(["item_id", "age_ranges_norm"])
    .explode("age_ranges_norm")
    .filter(pl.col("age_ranges_norm").is_not_null())
)

# 2) định nghĩa hàm chuyển "XM+" -> "Từ XM"
def convert_plus_list(lst: list[str]) -> list[str]:
    out = []
    for s in lst:
        if s.endswith("M+"):
            num = s[:-2]           # "60M+" -> "60"
            out.append(f"Từ {num}M")
        else:
            out.append(s)
    return out

# 3) group_by theo item_id, unique + sort, rồi apply convert_plus_list
df_item_age_dict = (
    df_item_norm
    .group_by("item_id")
    .agg(
        pl.col("age_ranges_norm").unique()  # list các canonical khác nhau
    )
    .with_columns(
        pl.col("age_ranges_norm").map_elements(
            convert_plus_list,
            return_dtype=pl.List(pl.Utf8)
        ).alias("age_dict_list")
    )
    # tạo thêm bản string dạng ["0-12M","Từ 12M"] để fill vào age_group_final
    .with_columns(
        pl.col("age_dict_list").map_elements(
            lambda lst: "[" + ", ".join(f'"{x}"' for x in lst) + "]",
            return_dtype=pl.Utf8
        ).alias("age_dict_str")
    )
)

# df_item_age_dict hiện có:
# - item_id
# - age_ranges_norm (list canonical gốc)
# - age_dict_list (list đã đổi M+ -> "Từ XM")
# - age_dict_str  (string để fill vào age_group_final)

# %%
# Tạo dictionary dùng cho việc debug / dùng ngoài Polars
item_to_age_dict = {
    row["item_id"]: row["age_dict_list"]
    for row in df_item_age_dict.select(["item_id", "age_dict_list"]).to_dicts()
}

# Giờ item_to_age_dict[item_id] sẽ là list, ví dụ:
# ["0-12M", "12-36M", "Từ 60M"]

# %%
# Join mapping theo item_id, chỉ fill cho các dòng "Không xác định"

df_age_filled = (
    df_age
    .join(
        df_item_age_dict.select(["item_id", "age_dict_str"]),
        on="item_id",
        how="left"
    )
    .with_columns(
        pl.when(
            (pl.col("age_group_final") == "Không xác định")
            & pl.col("age_dict_str").is_not_null()
        )
        .then(pl.col("age_dict_str"))         # dùng dictionary dạng ["...","..."]
        .otherwise(pl.col("age_group_final"))
        .alias("age_group_final_filled")
    )
    .drop("age_group_final", "age_dict_str")
    .rename({"age_group_final_filled": "age_group_final"})
)

# df_age_filled là dataframe cuối cùng sau khi fill.

# %%
import polars as pl

# df_unknown: item_id, age_ranges_norm

df_item_norm = (
    df_unknown
    .select(["item_id", "age_ranges_norm"])
    .explode("age_ranges_norm")
    .filter(pl.col("age_ranges_norm").is_not_null())
)

def convert_plus_list(lst):
    # lst có thể là list hoặc Series
    if isinstance(lst, pl.Series):
        lst = lst.to_list()

    out = []
    for s in lst:
        if not isinstance(s, str):
            out.append(s)
            continue

        s_clean = s.strip()

        # CASE 1: dạng "XM+"
        if s_clean.endswith("M+"):
            num = s_clean[:-2]
            out.append(f"Từ {num}M")
            continue

        # CASE 2: dạng chữ "trên 6M" / "Trên 6M" / "hơn 12M" / "Hơn 12M"
        m = re.match(r"(?i)^(trên|hơn)\s*(\d+)\s*m$", s_clean)
        if m:
            num = m.group(2)
            out.append(f"Từ {num}M")
            continue

        # giữ nguyên các dạng khác ("0-6M", "6-12M", ...)
        out.append(s_clean)

    return out

def build_age_fill_str(lst):
    if isinstance(lst, pl.Series):
        lst = lst.to_list()
    if lst is None or len(lst) == 0:
        return None
    if len(lst) == 1:
        # trả về string đơn
        return lst[0]
    # nhiều giá trị → JSON-like list với dấu "
    return "[" + ", ".join(f"\"{x}\"" for x in lst) + "]"

df_item_age_dict = (
    df_item_norm
    .group_by("item_id")
    .agg(pl.col("age_ranges_norm").unique().sort())
    .with_columns(
        pl.col("age_ranges_norm").map_elements(
            convert_plus_list,
            return_dtype=pl.List(pl.Utf8)
        ).alias("age_dict_list")
    )
    .with_columns(
        pl.col("age_dict_list").map_elements(
            build_age_fill_str,
            return_dtype=pl.Utf8
        ).alias("age_fill_str")
    )
)

# %%
# Thống kê trước khi fill
total_rows = df_age.height
unknown_before = df_age.filter(pl.col("age_group_final") == "Không xác định").height
ratio_before = unknown_before / total_rows * 100

print("=== TRƯỚC KHI FILL ===")
print(f"Số dòng 'Không xác định': {unknown_before}")
print(f"Tỉ lệ: {ratio_before:.2f}%")
print()


# Fill
df_age_filled = (
    df_age
    .with_columns(
        pl.col("age_group_final").alias("age_group_final_before")
    )
    .join(
        df_item_age_dict.select(["item_id", "age_fill_str"]),
        on="item_id",
        how="left"
    )
    .with_columns(
        pl.when(
            (pl.col("age_group_final_before") == "Không xác định")
            & pl.col("age_fill_str").is_not_null()
        )
        .then(pl.col("age_fill_str"))
        .otherwise(pl.col("age_group_final_before"))
        .alias("age_group_final")
    )
    .drop("age_fill_str")
)

# KHÔNG đổi dấu nháy nữa. Không .str.replace() gì thêm.


# Thống kê sau fill
unknown_after = df_age_filled.filter(pl.col("age_group_final") == "Không xác định").height
ratio_after = unknown_after / total_rows * 100

print("=== SAU KHI FILL ===")
print(f"Số dòng 'Không xác định': {unknown_after}")
print(f"Tỉ lệ: {ratio_after:.2f}%")
print()


# Lấy ra các dòng đã fill
df_filled_rows = (
    df_age_filled
    .filter(
        (pl.col("age_group_final_before") == "Không xác định")
        & (pl.col("age_group_final") != "Không xác định")
    )
    .select([
        "item_id",
        "description",
        "description_new",
        "age_group_final_before",
        "age_group_final",
    ])
)

pl.Config.set_fmt_str_lengths(120)
pl.Config.set_tbl_rows(100)

print("=== CÁC DÒNG ĐÃ FILL ===")
print(df_filled_rows)
# Out:
# === TRƯỚC KHI FILL ===
# Số dòng 'Không xác định': 10595
# Tỉ lệ: 38.78%
#
# === SAU KHI FILL ===
# Số dòng 'Không xác định': 10362
# Tỉ lệ: 37.92%
#
# === CÁC DÒNG ĐÃ FILL ===
# shape: (233, 5)
# ┌───────────────┬────────────────────┬────────────────────┬────────────────────┬───────────────────┐
# │ item_id       ┆ description        ┆ description_new    ┆ age_group_final_be ┆ age_group_final   │
# │ ---           ┆ ---                ┆ ---                ┆ fore               ┆ ---               │
# │ str           ┆ str                ┆ str                ┆ ---                ┆ str               │
# │               ┆                    ┆                    ┆ str                ┆                   │
# ╞═══════════════╪════════════════════╪════════════════════╪════════════════════╪═══════════════════╡
# │ 0020010000440 ┆ ﻿Sữa Meiji Growing  ┆ Không xác định     ┆ Không xác định     ┆ 12-36M            │
# │               ┆ up Formula 800g    ┆                    ┆                    ┆                   │
# │               ┆ (12-36 tháng)      ┆                    ┆                    ┆                   │
# │               ┆ thuộc thương hiệu  ┆                    ┆                    ┆                   │
# │               ┆ Meiji nổi tiếng    ┆                    ┆                    ┆                   │
# │               ┆ hàng đầu Nhật Bản, ┆                    ┆                    ┆                   │
# │               ┆ cung cấp các       ┆                    ┆                    ┆                   │
# │               ┆ vitam…             ┆                    ┆                    ┆                   │
# │ 0007390000008 ┆ Thau tắm Puku được ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ được làm từ chất   ┆ Tên sản phẩm: Thau ┆                    ┆                   │
# │               ┆ liệu nhựa PP, TPR  ┆ tắm lớn Puku       ┆                    ┆                   │
# │               ┆ cao cấp nên bố mẹ  ┆ P17003-299 (viền   ┆                    ┆                   │
# │               ┆ có thể yên tâm sử  ┆ màu xanh)          ┆                    ┆                   │
# │               ┆ dụng cho bé. Thiết ┆ Thương hiệu: Pu…   ┆                    ┆                   │
# │               ┆ kế thau tiệ…       ┆                    ┆                    ┆                   │
# │ 0031070000009 ┆ Nệm lưới Thái Toàn ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 0-24M             │
# │               ┆ hình thú (hồng)    ┆ Tên sản phẩm: Nệm  ┆                    ┆                   │
# │               ┆ 60x100cm cấu tạo   ┆ lưới Thái Toàn     ┆                    ┆                   │
# │               ┆ từ nhiều lớp lưới  ┆ hình thú (hồng)    ┆                    ┆                   │
# │               ┆ nên khả năng thoát ┆ 60x100cm           ┆                    ┆                   │
# │               ┆ hơi rất hiệu quả   ┆ Thương hiệu: Thá…  ┆                    ┆                   │
# │               ┆ mang lại cảm g…    ┆                    ┆                    ┆                   │
# │ 0007130040015 ┆ Thau tắm trẻ em    ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Nanny 3069/PK được ┆ Tên sản phẩm: Thau ┆                    ┆                   │
# │               ┆ làm từ chất liệu   ┆ tắm trẻ em Nanny   ┆                    ┆                   │
# │               ┆ nhựa PP cao cấp,   ┆ 3069/PK            ┆                    ┆                   │
# │               ┆ rất an toàn dùng   ┆ Loại sản phẩm:     ┆                    ┆                   │
# │               ┆ cho bé từ sơ sinh  ┆ Thau tắm       …   ┆                    ┆                   │
# │               ┆ trở lên. Được th…  ┆                    ┆                    ┆                   │
# │ 5957000000004 ┆ ﻿﻿Ưu điểm nổi bật .  ┆ Chi tiết sản       ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Dễ dàng gấp gọn    ┆ phẩmTên sản        ┆                    ┆                   │
# │               ┆ bằng một tay. Lưng ┆ phẩm:Xe đẩy trẻ em ┆                    ┆                   │
# │               ┆ ghế ngả phẳng phù  ┆ Joie Muze LX W/ FM ┆                    ┆                   │
# │               ┆ hợp cho trẻ từ sơ  ┆ (Coal)Thương hiệu: ┆                    ┆                   │
# │               ┆ sinh. Xe có thể tự ┆ JoieSản xuất tại:  ┆                    ┆                   │
# │               ┆ đứng vứng …        ┆ Trung QuốcĐộ tuổi  ┆                    ┆                   │
# │               ┆                    ┆ ph…                ┆                    ┆                   │
# │ 0020120000005 ┆ Sữa tắm gội toàn   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 1D+               │
# │               ┆ thân Johnson Baby  ┆ Tên sản phẩm: Sữa  ┆                    ┆                   │
# │               ┆ 200ml với công     ┆ tắm gội toàn thân  ┆                    ┆                   │
# │               ┆ thức đặc biệt có   ┆ Johnson Baby 200ml ┆                    ┆                   │
# │               ┆ hàm lượng dưỡng ẩm ┆ Loại sản phẩm: sữa ┆                    ┆                   │
# │               ┆ gấp 10 lần, giúp   ┆ …                  ┆                    ┆                   │
# │               ┆ duy trì độ ẩm cho… ┆                    ┆                    ┆                   │
# │ 5931000000011 ┆ ﻿Ghế ăn trẻ em Joie ┆ Chi tiết sản       ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Mimzy Recline      ┆ phẩmTên sản        ┆                    ┆                   │
# │               ┆ Arctic có thiết kế ┆ phẩm:Ghế ăn cho    ┆                    ┆                   │
# │               ┆ chắc chắn, an toàn ┆ trẻ em Joie Mimzy  ┆                    ┆                   │
# │               ┆ với 5 mức ngả lưng ┆ Recline            ┆                    ┆                   │
# │               ┆ phù hợp cho bé từ  ┆ ArcticThương hiệu: ┆                    ┆                   │
# │               ┆ sơ sinh, gi…       ┆ JoieĐộ tuổi phù    ┆                    ┆                   │
# │               ┆                    ┆ hợp: Dành cho bé   ┆                    ┆                   │
# │               ┆                    ┆ t…                 ┆                    ┆                   │
# │ 0007150000041 ┆ Tấm lót chống thấm ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 0-6M              │
# │               ┆ CEQ063 Đối với nhà ┆ Tên sản phẩm: Tấm  ┆                    ┆                   │
# │               ┆ có con nhỏ, các Bố ┆ lót chống thấm     ┆                    ┆                   │
# │               ┆ Mẹ luôn không thể  ┆ 69x92cm PAPA -     ┆                    ┆                   │
# │               ┆ tránh khỏi tình    ┆ CEQ063             ┆                    ┆                   │
# │               ┆ trạng bé tè một    ┆ Chất liệu:         ┆                    ┆                   │
# │               ┆ cách rất tự n…     ┆ cotton-n…          ┆                    ┆                   │
# │ 0006040000358 ┆ Bình sữa ConCung   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ ["0-6M", "Từ 0M", │
# │               ┆ Good Easy Start    ┆ Tên sản phẩm: Bình ┆                    ┆ "Từ 3M"]          │
# │               ┆ nhựa PP cổ thường  ┆ sữa ConCung Good   ┆                    ┆                   │
# │               ┆ (125ml, Xanh       ┆ Easy Start nhựa PP ┆                    ┆                   │
# │               ┆ dương) có chất     ┆ cổ thường (125ml,  ┆                    ┆                   │
# │               ┆ liệu an toàn (BPA  ┆ Xanh dương)    …   ┆                    ┆                   │
# │               ┆ Free), thiết kế    ┆                    ┆                    ┆                   │
# │               ┆ thân th…           ┆                    ┆                    ┆                   │
# │ 0006040000367 ┆ Bình sữa ConCung   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 3M             │
# │               ┆ Good Easy Start    ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ nhựa PP cổ rộng    ┆ sữa ConCung Good   ┆                    ┆                   │
# │               ┆ (250ml, Xanh       ┆ Easy Start nhựa PP ┆                    ┆                   │
# │               ┆ dương) có chất     ┆ cổ rộng (250ml,    ┆                    ┆                   │
# │               ┆ liệu an toàn (BPA  ┆ Xanh dương)…       ┆                    ┆                   │
# │               ┆ Free), thiết kế    ┆                    ┆                    ┆                   │
# │               ┆ thân thiệ…         ┆                    ┆                    ┆                   │
# │ 0007010001053 ┆ Bình sữa silicone  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Gluck premium      ┆ Tên sản phẩm:      ┆                    ┆                   │
# │               ┆ 240ml (Hồng) được  ┆ **Bình sữa         ┆                    ┆                   │
# │               ┆ sản xuất từ 100%   ┆ silicone Gluck     ┆                    ┆                   │
# │               ┆ silicone y tế,     ┆ premium 240ml      ┆                    ┆                   │
# │               ┆ không có BPA, kiểu ┆ (Hồng)**           ┆                    ┆                   │
# │               ┆ dáng đàn hồi và có ┆ Loại sản ph…       ┆                    ┆                   │
# │               ┆ …                  ┆                    ┆                    ┆                   │
# │ 0007131040017 ┆ Thau tắm trẻ em    ┆ Không xác định     ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Nanny 3073/PK được ┆                    ┆                    ┆                   │
# │               ┆ làm từ chất liệu   ┆                    ┆                    ┆                   │
# │               ┆ nhựa PP cao cấp,   ┆                    ┆                    ┆                   │
# │               ┆ rất an toàn dùng   ┆                    ┆                    ┆                   │
# │               ┆ cho bé từ sơ sinh  ┆                    ┆                    ┆                   │
# │               ┆ trở lên. Được th…  ┆                    ┆                    ┆                   │
# │ 0969104000004 ┆ Đối với bé không   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆ chỉ quần áo hay đồ ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# │               ┆ chơi mà mắt kính   ┆ kính bé trai CF    ┆                    ┆                   │
# │               ┆ cũng là phụ kiện   ┆ A019009 Xanh       ┆                    ┆                   │
# │               ┆ thời trang không   ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆ thể thiếu trong tủ ┆ Xuấ…               ┆                    ┆                   │
# │               ┆ đồ của bé.  Đư…    ┆                    ┆                    ┆                   │
# │ 0927104630002 ┆ Khăn choàng sơ     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ sinh CF I129007    ┆ Tên sản phẩm: Khăn ┆                    ┆                   │
# │               ┆ (NB,Xanh) được làm ┆ choàng sơ sinh CF  ┆                    ┆                   │
# │               ┆ từ chất liệu mềm   ┆ I129007 (NB,Xanh)  ┆                    ┆                   │
# │               ┆ mại, thấm hút tốt, ┆ Loại sản phẩm:     ┆                    ┆                   │
# │               ┆ thiết kế bắt mắt,  ┆ Khăn…              ┆                    ┆                   │
# │               ┆ họa tiết dễ thươ…  ┆                    ┆                    ┆                   │
# │ 5879000000003 ┆ ﻿﻿﻿﻿﻿﻿Giường cũi trẻ em  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ ["0-12M", "0-6M"] │
# │               ┆ Joie Commuter      ┆ Tên sản phẩm:      ┆                    ┆                   │
# │               ┆ Change & Snooze    ┆ Giường cũi trẻ em  ┆                    ┆                   │
# │               ┆ phù hợp cho bé từ  ┆ Joie Commuter      ┆                    ┆                   │
# │               ┆ sơ sinh đến 15kg.  ┆ Change & Snooze    ┆                    ┆                   │
# │               ┆ Sản phẩm tích hợp  ┆ Linen Gray         ┆                    ┆                   │
# │               ┆ đến 4 chức n…      ┆ Thương …           ┆                    ┆                   │
# │ 0952000000104 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 12M            │
# │               ┆                    ┆ Tên sản phẩm: Gấu  ┆                    ┆                   │
# │               ┆                    ┆ Pooh Xinh Xắn      ┆                    ┆                   │
# │               ┆                    ┆ Loại sản phẩm: Đồ  ┆                    ┆                   │
# │               ┆                    ┆ chơi         Đối   ┆                    ┆                   │
# │               ┆                    ┆ tượng s…           ┆                    ┆                   │
# │ 2890000000001 ┆ Sản phẩm kềm cắt   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 216M           │
# │               ┆ móng M.205 của Kềm ┆ Tên sản phẩm: Kềm  ┆                    ┆                   │
# │               ┆ Nghĩa được xem là  ┆ cắt móng thép      ┆                    ┆                   │
# │               ┆ một trong những sự ┆ M-205              ┆                    ┆                   │
# │               ┆ lựa chọn hàng đầu  ┆ Thương hiệu: Kềm   ┆                    ┆                   │
# │               ┆ của khách hàng.    ┆ Nghĩa         Xuất ┆                    ┆                   │
# │               ┆ Đây là một tr…     ┆ …                  ┆                    ┆                   │
# │ 2890000000003 ┆ Ra đời từ những    ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 216M           │
# │               ┆ năm 1980, Kềm      ┆ Tên sản phẩm: Kéo  ┆                    ┆                   │
# │               ┆ Nghĩa từ lâu đã    ┆ tỉa lông mày       ┆                    ┆                   │
# │               ┆ trở thành thương   ┆ KM-601 Nghĩa       ┆                    ┆                   │
# │               ┆ hiệu mà người tiêu ┆ Thương hiệu: Kềm   ┆                    ┆                   │
# │               ┆ dùng tin tưởng sử  ┆ Nghĩa        …     ┆                    ┆                   │
# │               ┆ dụng. Các sản phẩm ┆                    ┆                    ┆                   │
# │               ┆ c…                 ┆                    ┆                    ┆                   │
# │ 0037000000028 ┆ ﻿Bình sữa ConCung   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 3M             │
# │               ┆ Good có chất liệu  ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ an toàn (BPA       ┆ sữa ConCung Good   ┆                    ┆                   │
# │               ┆ Free), thiết kế    ┆ cổ thường 125ml    ┆                    ┆                   │
# │               ┆ thân thiện với môi ┆ Dung tích: 125ml,  ┆                    ┆                   │
# │               ┆ trường, núm ty     ┆ 250m…              ┆                    ┆                   │
# │               ┆ bằng silicone mềm  ┆                    ┆                    ┆                   │
# │               ┆ giú…               ┆                    ┆                    ┆                   │
# │ 0087000000013 ┆ ﻿﻿﻿﻿﻿Ưu điểm nổi bật .  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 12-36M            │
# │               ┆ Bình tritan Diller ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ có tay cầm cho bé  ┆ tritan Diller có   ┆                    ┆                   │
# │               ┆ được làm từ chất   ┆ tay cầm cho bé     ┆                    ┆                   │
# │               ┆ liệu cao cấp; .    ┆ 550ml- Hồng        ┆                    ┆                   │
# │               ┆ Sản phẩm đảm bảo   ┆ Thương hiệu…       ┆                    ┆                   │
# │               ┆ an toàn ch…        ┆                    ┆                    ┆                   │
# │ 3793000000008 ┆ ﻿﻿Bình giữ nhiệt em  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 12-36M            │
# │               ┆ bé Diller 260ml    ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ (304ss+ 316ss,     ┆ giữ nhiệt em bé    ┆                    ┆                   │
# │               ┆ xanh dương) được   ┆ Diller 260ml       ┆                    ┆                   │
# │               ┆ làm từ chất liệu   ┆ (304ss+ 316ss,     ┆                    ┆                   │
# │               ┆ cao cấp, giúp giữ  ┆ xanh dương)        ┆                    ┆                   │
# │               ┆ đồ uống của bé má… ┆ …                  ┆                    ┆                   │
# │ 0007130040020 ┆ Chăn cuốn bé ngủ   ┆ Không xác định     ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Puku, P26319-300   ┆                    ┆                    ┆                   │
# │               ┆ (Hồng) có chất     ┆                    ┆                    ┆                   │
# │               ┆ liệu 100% cotton   ┆                    ┆                    ┆                   │
# │               ┆ mềm mại, an toàn   ┆                    ┆                    ┆                   │
# │               ┆ cho da bé cùng họa ┆                    ┆                    ┆                   │
# │               ┆ tiết dễ thương,    ┆                    ┆                    ┆                   │
# │               ┆ bắ…                ┆                    ┆                    ┆                   │
# │ 0969016000001 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆                    ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# │               ┆                    ┆ kính bé trai CF    ┆                    ┆                   │
# │               ┆                    ┆ A019008 Trắng      ┆                    ┆                   │
# │               ┆                    ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆                    ┆ Xu…                ┆                    ┆                   │
# │ 0007130000052 ┆ Thau Tắm lớn Duy   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Tân (trắng) là sản ┆ Tên sản phẩm: Thau ┆                    ┆                   │
# │               ┆ phẩm hỗ trợ đắc    ┆ Tắm lớn Duy Tân    ┆                    ┆                   │
# │               ┆ lực cho Mẹ khi tắm ┆ (trắng)            ┆                    ┆                   │
# │               ┆ và vệ sinh cho bé  ┆ Thương hiệu: Duy   ┆                    ┆                   │
# │               ┆ yêu. Với những     ┆ Tân         Sả…    ┆                    ┆                   │
# │               ┆ thau tắm dạng tr…  ┆                    ┆                    ┆                   │
# │ 4466000000002 ┆ Nước Cocomong      ┆ Không xác định     ┆ Không xác định     ┆ Từ 6M             │
# │               ┆ Yogurt táo là sản  ┆                    ┆                    ┆                   │
# │               ┆ phẩm nước lợi      ┆                    ┆                    ┆                   │
# │               ┆ khuẩn kết hợp      ┆                    ┆                    ┆                   │
# │               ┆ hương vị sữa và    ┆                    ┆                    ┆                   │
# │               ┆ đào, thiết kế nắp  ┆                    ┆                    ┆                   │
# │               ┆ chống sặc an toàn  ┆                    ┆                    ┆                   │
# │               ┆ dành cho…          ┆                    ┆                    ┆                   │
# │ 0165000000011 ┆ Ghế ngồi ô tô trẻ  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ em Joie Gemm       ┆ Tên sản phẩm: Ghế  ┆                    ┆                   │
# │               ┆ Pebble phù hợp cho ┆ ngồi ô tô trẻ em   ┆                    ┆                   │
# │               ┆ bé từ sơ sinh và   ┆ Joie Gemm Pebble   ┆                    ┆                   │
# │               ┆ nặng dưới 13kg.    ┆ Thương hiệu: JOIE  ┆                    ┆                   │
# │               ┆ Sản phẩm đảm bảo   ┆ …                  ┆                    ┆                   │
# │               ┆ an toàn cho bé khi ┆                    ┆                    ┆                   │
# │               ┆ đ…                 ┆                    ┆                    ┆                   │
# │ 0165000000012 ┆ Ghế ngồi ô tô trẻ  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ em Joie i-Gemm 2   ┆ Tên sản phẩm: Ghế  ┆                    ┆                   │
# │               ┆ Pavement phù hợp   ┆ ngồi ô tô trẻ em   ┆                    ┆                   │
# │               ┆ cho bé từ sơ sinh  ┆ Joie i-Gemm 2      ┆                    ┆                   │
# │               ┆ và nặng dưới 13kg. ┆ Pavement           ┆                    ┆                   │
# │               ┆ Đạt tiêu chuẩn an  ┆ Thương hiệu: JOI…  ┆                    ┆                   │
# │               ┆ toàn i-Size, …     ┆                    ┆                    ┆                   │
# │ 0011000000050 ┆ Chăn xô 2 lớp cho  ┆ Chi tiết sản       ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ bé Animo           ┆ phẩmTên sản phẩm:  ┆                    ┆                   │
# │               ┆ B2204_MN003 với    ┆ Chăn xô 2 lớp cho  ┆                    ┆                   │
# │               ┆ chất liệu Cotton   ┆ bé Animo           ┆                    ┆                   │
# │               ┆ mềm mại, ấm áp.    ┆ B2204_MN003Thương  ┆                    ┆                   │
# │               ┆ Chăn đắp tiện lợi  ┆ hiệu: AnimoĐộ tuổi ┆                    ┆                   │
# │               ┆ xếp gọn khi đi     ┆ sử dụng: từ 0      ┆                    ┆                   │
# │               ┆ xa. Dùng để…       ┆ tháng tuổi …       ┆                    ┆                   │
# │ 0422000000008 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 36M            │
# │               ┆                    ┆ Tên sản phẩm: Kính ┆                    ┆                   │
# │               ┆                    ┆ bơi Mickey Xanh    ┆                    ┆                   │
# │               ┆                    ┆ D702031-A          ┆                    ┆                   │
# │               ┆                    ┆ Thương hiệu:       ┆                    ┆                   │
# │               ┆                    ┆ Mesuca         X…  ┆                    ┆                   │
# │ 5052000000001 ┆ Ưu điểm nổi bật    ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ của sản phẩm - Gối ┆ Tên sản phẩm: Gối  ┆                    ┆                   │
# │               ┆ ôm Animo được      ┆ ôm nhỏ cho bé      ┆                    ┆                   │
# │               ┆ thiết kế với kích  ┆ Animo B2203_HV011  ┆                    ┆                   │
# │               ┆ thước phù hợp với  ┆ (17x38cm,Hồng)     ┆                    ┆                   │
# │               ┆ trẻ sơ sinh, tạo   ┆ Thương hi…         ┆                    ┆                   │
# │               ┆ cảm giác an toàn,  ┆                    ┆                    ┆                   │
# │               ┆ …                  ┆                    ┆                    ┆                   │
# │ 0010291040066 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 0-36M             │
# │               ┆                    ┆ Tên sản phẩm: Bộ   ┆                    ┆                   │
# │               ┆                    ┆ đồ bơi bé gái CF   ┆                    ┆                   │
# │               ┆                    ┆ G127027 xanh       ┆                    ┆                   │
# │               ┆                    ┆ Thương hiệu:       ┆                    ┆                   │
# │               ┆                    ┆ Concung (Việt …    ┆                    ┆                   │
# │ 0031050000005 ┆ Gối cho bé Kuku    ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ KU2065 được sản    ┆ Tên sản phẩm: Gối  ┆                    ┆                   │
# │               ┆ xuất bằng chất     ┆ Sơ Sinh Kuku       ┆                    ┆                   │
# │               ┆ liệu vải mềm và    ┆ KU2065             ┆                    ┆                   │
# │               ┆ bông cao cấp, mang ┆ Loại sản phẩm: Gối ┆                    ┆                   │
# │               ┆ lại cảm giác mềm   ┆ cho bé         Đố… ┆                    ┆                   │
# │               ┆ mại, và an toàn    ┆                    ┆                    ┆                   │
# │               ┆ khi s…             ┆                    ┆                    ┆                   │
# │ 0148000000004 ┆ Xe đẩy Evenflo     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ dưới đây sẽ là sự  ┆ Tên sản phẩm: Xe   ┆                    ┆                   │
# │               ┆ lựa chọn tuyệt vời ┆ đẩy Evenflo D661 - ┆                    ┆                   │
# │               ┆ cho bố mẹ và yêu   ┆ Junbaby            ┆                    ┆                   │
# │               ┆ trong mỗi lần đi   ┆ Loại sản phẩm: Xe  ┆                    ┆                   │
# │               ┆ dạo phố hoặc đi dã ┆ đẩy         …      ┆                    ┆                   │
# │               ┆ ngoại dài ngày.…   ┆                    ┆                    ┆                   │
# │ 0007270000004 ┆ Đặc điểm sản phẩm: ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ - Nước rửa đồ      ┆ Tên sản phẩm: Nước ┆                    ┆                   │
# │               ┆ chơi, bàn ăn, xe   ┆ rửa đồ chơi, bàn   ┆                    ┆                   │
# │               ┆ đẩy kháng khuẩn    ┆ ăn, xe đẩy kháng   ┆                    ┆                   │
# │               ┆ Babyganics         ┆ khuẩn Babyganics   ┆                    ┆                   │
# │               ┆ 502ml giúp các bé  ┆ 502ML       …      ┆                    ┆                   │
# │               ┆ có thể vừa chơi    ┆                    ┆                    ┆                   │
# │               ┆ đùa với c…         ┆                    ┆                    ┆                   │
# │ 6678000000010 ┆ ﻿﻿﻿﻿﻿﻿﻿Ưu điểm nổi bật .  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 3M             │
# │               ┆ Bình sữa làm từ    ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ chất lượng nhựa    ┆ sữa Moyuum thế hệ  ┆                    ┆                   │
# │               ┆ PPSU cao cấp, an   ┆ 3 PPSU 270ml (trái ┆                    ┆                   │
# │               ┆ toàn cho bé.. Núm  ┆ tim hồng)          ┆                    ┆                   │
# │               ┆ ty silicone siêu   ┆ Thương h…          ┆                    ┆                   │
# │               ┆ mềm được là…       ┆                    ┆                    ┆                   │
# │ 6280000000001 ┆ ﻿﻿Sản phẩm xua muỗi  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 48M            │
# │               ┆ dạng xịt hương     ┆ Tên sản phẩm: Sản  ┆                    ┆                   │
# │               ┆ Lavender           ┆ phẩm xua muỗi dạng ┆                    ┆                   │
# │               ┆ (Mentholatum       ┆ xịt hương Lavender ┆                    ┆                   │
# │               ┆ Remos) với mùi     ┆ (Mentholatum       ┆                    ┆                   │
# │               ┆ hương lavender tự  ┆ Remos) 70ml        ┆                    ┆                   │
# │               ┆ nhiên, dễ chịu     ┆ …                  ┆                    ┆                   │
# │               ┆ giúp xua đuổi m…   ┆                    ┆                    ┆                   │
# │ 0165000000010 ┆ Ghế ngồi ô tô trẻ  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ em Joie Gemm Shale ┆ Tên sản phẩm: Ghế  ┆                    ┆                   │
# │               ┆ phù hợp cho bé từ  ┆ ngồi ô tô trẻ em   ┆                    ┆                   │
# │               ┆ sơ sinh và nặng    ┆ Joie Gemm Shale    ┆                    ┆                   │
# │               ┆ dưới 13kg. Sản     ┆ Thương hiệu: JOIE  ┆                    ┆                   │
# │               ┆ phẩm đảm bảo an    ┆ …                  ┆                    ┆                   │
# │               ┆ toàn cho bé khi    ┆                    ┆                    ┆                   │
# │               ┆ đi…                ┆                    ┆                    ┆                   │
# │ 2854000000004 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 12M            │
# │               ┆                    ┆ Tên sản phẩm: Nước ┆                    ┆                   │
# │               ┆                    ┆ Rửa Tay Kháng      ┆                    ┆                   │
# │               ┆                    ┆ Khuẩn Antabax      ┆                    ┆                   │
# │               ┆                    ┆ Fresh 500Ml        ┆                    ┆                   │
# │               ┆                    ┆ Thương hiệu: AN…   ┆                    ┆                   │
# │ 0014510170005 ┆ Ba lô CF A038003   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 36-120M           │
# │               ┆ Vàng không chỉ là  ┆ Tên sản phẩm: Ba   ┆                    ┆                   │
# │               ┆ vật dụng để Mẹ     ┆ lô CF A038003 Vàng ┆                    ┆                   │
# │               ┆ đựng đồ khi ra     ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆ ngoài cho bé yêu   ┆ Sản xuất tại: …    ┆                    ┆                   │
# │               ┆ như: quần áo, sữa, ┆                    ┆                    ┆                   │
# │               ┆ tã... mà còn là    ┆                    ┆                    ┆                   │
# │               ┆ ngư…               ┆                    ┆                    ┆                   │
# │ 6678000000005 ┆ ﻿Ưu điểm nổi bật .  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 1M             │
# │               ┆ Bình sữa làm từ    ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ chất lượng nhựa    ┆ sữa Moyuum thế hệ  ┆                    ┆                   │
# │               ┆ PPSU cao cấp, an   ┆ 3 PPSU 170ml       ┆                    ┆                   │
# │               ┆ toàn cho bé.. Núm  ┆ (Beige)            ┆                    ┆                   │
# │               ┆ ty silicone siêu   ┆ Thương hiệu: Moy…  ┆                    ┆                   │
# │               ┆ mềm được làm từ c… ┆                    ┆                    ┆                   │
# │ 0007240000043 ┆ Khăn choàng tắm    ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ cho bé ConCung     ┆ Tên sản phẩm: Khăn ┆                    ┆                   │
# │               ┆ Good (màu xanh)    ┆ choàng tắm cho bé  ┆                    ┆                   │
# │               ┆ Chất liệu mềm mại, ┆ ConCung Good (màu  ┆                    ┆                   │
# │               ┆ thấm hút tốt,      ┆ xanh)         Loại ┆                    ┆                   │
# │               ┆ thiết kế bắt mắt,  ┆ sản phẩm…          ┆                    ┆                   │
# │               ┆ họa tiết dễ thương ┆                    ┆                    ┆                   │
# │               ┆ Đặc…               ┆                    ┆                    ┆                   │
# │ 0422000000009 ┆ - Kính bơi công    ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 36M            │
# │               ┆ chúa Hồng          ┆ Tên sản phẩm: Kính ┆                    ┆                   │
# │               ┆ D702031-D là sản   ┆ bơi công chúa      ┆                    ┆                   │
# │               ┆ phẩm hỗ trợ bảo vệ ┆ (Hồng) D702031-D   ┆                    ┆                   │
# │               ┆ đôi mắt bé, giúp   ┆ Thương hiệu:       ┆                    ┆                   │
# │               ┆ bé tha hồ tận      ┆ Mesuca     …       ┆                    ┆                   │
# │               ┆ hưởng không gian   ┆                    ┆                    ┆                   │
# │               ┆ mát mẻ và …        ┆                    ┆                    ┆                   │
# │ 0422000000014 ┆ Kính bơi công chúa ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 36M            │
# │               ┆ DEA52970-Y là sản  ┆ Tên sản phẩm: Kính ┆                    ┆                   │
# │               ┆ phẩm hỗ trợ bảo vệ ┆ bơi công chúa      ┆                    ┆                   │
# │               ┆ đôi mắt bé, giúp   ┆ DEA52970-Y         ┆                    ┆                   │
# │               ┆ bé tha hồ tận      ┆ Thương hiệu:       ┆                    ┆                   │
# │               ┆ hưởng không gian   ┆ Mesuca         Xu… ┆                    ┆                   │
# │               ┆ mát mẻ và không …  ┆                    ┆                    ┆                   │
# │ 0966004000001 ┆ Đối với bé không   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆ chỉ quần áo hay đồ ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# │               ┆ chơi mà mắt kính   ┆ kính bé gái CF     ┆                    ┆                   │
# │               ┆ cũng là phụ kiện   ┆ A019003 Hồng       ┆                    ┆                   │
# │               ┆ thời trang không   ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆ thể thiếu trong tủ ┆ Nhà …              ┆                    ┆                   │
# │               ┆ đồ của bé.  Đư…    ┆                    ┆                    ┆                   │
# │ 0969104000005 ┆ Đối với bé không   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆ chỉ quần áo hay đồ ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# │               ┆ chơi mà mắt kính   ┆ kính bé trai CF    ┆                    ┆                   │
# │               ┆ cũng là phụ kiện   ┆ A019011 Xanh       ┆                    ┆                   │
# │               ┆ thời trang không   ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆ thể thiếu trong tủ ┆ Xuấ…               ┆                    ┆                   │
# │               ┆ đồ của bé.  Đư…    ┆                    ┆                    ┆                   │
# │ 0966104000001 ┆ Đối với bé không   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆ chỉ quần áo hay đồ ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# │               ┆ chơi mà mắt kính   ┆ kính bé gái CF     ┆                    ┆                   │
# │               ┆ cũng là phụ kiện   ┆ A019012 Xanh       ┆                    ┆                   │
# │               ┆ thời trang không   ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆ thể thiếu trong tủ ┆ Xuất…              ┆                    ┆                   │
# │               ┆ đồ của bé.  Đư…    ┆                    ┆                    ┆                   │
# │ 0966104000002 ┆ Đối với bé không   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆ chỉ quần áo hay đồ ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# │               ┆ chơi mà mắt kính   ┆ kính bé gái CF     ┆                    ┆                   │
# │               ┆ cũng là phụ kiện   ┆ A019014 Xanh       ┆                    ┆                   │
# │               ┆ thời trang không   ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆ thể thiếu trong tủ ┆ Xuất…              ┆                    ┆                   │
# │               ┆ đồ của bé.  Đư…    ┆                    ┆                    ┆                   │
# │ 0966002000001 ┆ Đối với bé không   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆ chỉ quần áo hay đồ ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# │               ┆ chơi mà mắt kính   ┆ kính bé gái CF     ┆                    ┆                   │
# │               ┆ cũng là phụ kiện   ┆ A019019 Cam        ┆                    ┆                   │
# │               ┆ thời trang không   ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆ thể thiếu trong tủ ┆ Xuất …             ┆                    ┆                   │
# │               ┆ đồ của bé.  Đư…    ┆                    ┆                    ┆                   │
# │ 0012000000030 ┆ ﻿﻿﻿﻿﻿Chăn lưới cho bé   ┆ Chi tiết sản       ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Animo B2201_BR001  ┆ phẩmTên sản        ┆                    ┆                   │
# │               ┆ (70x90cm,Xanh) với ┆ phẩm:Chăn lưới cho ┆                    ┆                   │
# │               ┆ chất liệu 100%     ┆ bé Animo           ┆                    ┆                   │
# │               ┆ cotton mềm mại, ấm ┆ B2201_BR001 (70x90 ┆                    ┆                   │
# │               ┆ áp. Chăn lưới tiện ┆ cm,Xanh)Thương     ┆                    ┆                   │
# │               ┆ lợi xếp …          ┆ hiệu: AnimoXuất    ┆                    ┆                   │
# │               ┆                    ┆ xứ: Trung QuốcĐộ   ┆                    ┆                   │
# │               ┆                    ┆ t…                 ┆                    ┆                   │
# │ 0969285000002 ┆ Đối với bé không   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆ chỉ quần áo hay đồ ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# │               ┆ chơi mà mắt kính   ┆ kính bé trai CF    ┆                    ┆                   │
# │               ┆ cũng là phụ kiện   ┆ A019022 Nhiều màu  ┆                    ┆                   │
# │               ┆ thời trang không   ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆ thể thiếu trong tủ ┆ …                  ┆                    ┆                   │
# │               ┆ đồ của bé.  Đư…    ┆                    ┆                    ┆                   │
# │ …             ┆ …                  ┆ …                  ┆ …                  ┆ …                 │
# │ 7010000000037 ┆ ﻿﻿﻿Set 2 Bodysuit     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 0-12M             │
# │               ┆ modal kháng khuẩn  ┆ Tên sản phẩm: Set  ┆                    ┆                   │
# │               ┆ đùi Animo          ┆ 2 Bodysuit modal   ┆                    ┆                   │
# │               ┆ VD0225021 được làm ┆ kháng khuẩn đùi    ┆                    ┆                   │
# │               ┆ từ vải sợi thiên   ┆ Animo VD0225021    ┆                    ┆                   │
# │               ┆ nhiên nên an toàn  ┆ Thương …           ┆                    ┆                   │
# │               ┆ và lành tính đối   ┆                    ┆                    ┆                   │
# │               ┆ với…               ┆                    ┆                    ┆                   │
# │ 1678000000003 ┆ Hướng dẫn sử       ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 5D+               │
# │               ┆ dụngLàm sạch, lau  ┆ Tên sản phẩm: Kem  ┆                    ┆                   │
# │               ┆ khô và thoa đều    ┆ bôi dịu da cho bé  ┆                    ┆                   │
# │               ┆ kem lên vùng da bị ┆ dịu mẩn ngứa, ngừa ┆                    ┆                   │
# │               ┆ tổn thương. Có thể ┆ thâm sẹo Kutieskin ┆                    ┆                   │
# │               ┆ dùng nhiều lần     ┆ 30g     …          ┆                    ┆                   │
# │               ┆ trong ngày. Dùng   ┆                    ┆                    ┆                   │
# │               ┆ đượ…               ┆                    ┆                    ┆                   │
# │ 0502020000003 ┆ THÔNG TIN SẢN PHẨM ┆ Chi tiết sản       ┆ Không xác định     ┆ ["Từ 0M", "Từ     │
# │               ┆ Tên sản phẩm :Núm  ┆ phẩmTên sản        ┆                    ┆ 9M"]              │
# │               ┆ ty bình sữa cổ hẹp ┆ phẩm:Núm ty Dr     ┆                    ┆                   │
# │               ┆ Dr Brown's 2 cái,  ┆ brown's Option cổ  ┆                    ┆                   │
# │               ┆ Y cut Xuất xứ      ┆ hẹp ( set 2        ┆                    ┆                   │
# │               ┆ : USA.             ┆ chiếc)Chất liệu:   ┆                    ┆                   │
# │               ┆                    ┆ Silicon cao cấp    ┆                    ┆                   │
# │               ┆                    ┆ nhập khẩu Đức, si… ┆                    ┆                   │
# │ 0159000000005 ┆ ﻿Địu có bệ khí cho  ┆ Chi tiết sản       ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ bé AXT05 BeBéar    ┆ phẩmTên sản phẩm:  ┆                    ┆                   │
# │               ┆ được làm từ chất   ┆ Địu có bệ đỡ cho   ┆                    ┆                   │
# │               ┆ liệu vải Polyester ┆ bé AXT05 BeBéar    ┆                    ┆                   │
# │               ┆ dày dặn, chắc chắn ┆ (hồng)Chất liệu:   ┆                    ┆                   │
# │               ┆ nhưng thoáng       ┆ Polyester dày dặn, ┆                    ┆                   │
# │               ┆ khí, vải mềm mại,… ┆ chắc chắn nhưng    ┆                    ┆                   │
# │               ┆                    ┆ thoá…              ┆                    ┆                   │
# │ 0007040000089 ┆ Thông số kỹ thuật: ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Chất liệu: Khung   ┆ Tên sản phẩm: Ghế  ┆                    ┆                   │
# │               ┆ thép và vải bố     ┆ rung cho bé sơ     ┆                    ┆                   │
# │               ┆ Trọng lượng: 2.4kg ┆ sinh         Chất  ┆                    ┆                   │
# │               ┆ - 3.1 kg Kích      ┆ liệu: Khung thép   ┆                    ┆                   │
# │               ┆ thước sản phẩm:    ┆ và vải bố     …    ┆                    ┆                   │
# │               ┆ 41* 69* 55cm Kích  ┆                    ┆                    ┆                   │
# │               ┆ th…                ┆                    ┆                    ┆                   │
# │ 0007090000344 ┆ Đọc kỹ hướng dẫn   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ sử dụng in trên    ┆ Tên sản phẩm: Sữa  ┆                    ┆                   │
# │               ┆ bao bì sản phẩm    ┆ tắm cho bé Perfect ┆                    ┆                   │
# │               ┆                    ┆ Purity KD-01 354ml ┆                    ┆                   │
# │               ┆                    ┆ Thể tích: 354ml    ┆                    ┆                   │
# │               ┆                    ┆ …                  ┆                    ┆                   │
# │ 0041000000048 ┆ ﻿Ưu điểm nổi bật .  ┆ Chi tiết sản       ┆ Không xác định     ┆ 0-3M              │
# │               ┆ Sử dụng núm ty     ┆ phẩmTên sản        ┆                    ┆                   │
# │               ┆ Pigeon Softouch    ┆ phẩm:Bình Sữa      ┆                    ┆                   │
# │               ┆ III. Chứa van      ┆ Pigeon PPSU        ┆                    ┆                   │
# │               ┆ thông khí chống    ┆ Softouch           ┆                    ┆                   │
# │               ┆ đầy hơi. Chứa      ┆ Baby-Friendly      ┆                    ┆                   │
# │               ┆ đường khớp ngậm    ┆ World 160ml, muông ┆                    ┆                   │
# │               ┆ giúp bé xá…        ┆ thú SSThương hiệu: ┆                    ┆                   │
# │               ┆                    ┆ PigeonSả…          ┆                    ┆                   │
# │ 2588000000004 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 192M           │
# │               ┆                    ┆ Tên sản phẩm: Kem  ┆                    ┆                   │
# │               ┆                    ┆ đánh Splat Organic ┆                    ┆                   │
# │               ┆                    ┆ thảo mộc 75ml      ┆                    ┆                   │
# │               ┆                    ┆ Loại sản phẩm: Kem ┆                    ┆                   │
# │               ┆                    ┆ đánh…              ┆                    ┆                   │
# │ 1678000000004 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 5D+               │
# │               ┆                    ┆ Tên sản phẩm: Kem  ┆                    ┆                   │
# │               ┆                    ┆ bôi cho bé         ┆                    ┆                   │
# │               ┆                    ┆ Kutieskin giúp dịu ┆                    ┆                   │
# │               ┆                    ┆ da, giảm kích ứng  ┆                    ┆                   │
# │               ┆                    ┆ (30g)         Th…  ┆                    ┆                   │
# │ 0007240000004 ┆ Khăn tắm           ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Mollis mềm mại,    ┆ Tên sản phẩm:      ┆                    ┆                   │
# │               ┆ bền đẹp, với tính  ┆ Combo Khăn tắm     ┆                    ┆                   │
# │               ┆ năng an toàn,      ┆ Mollis cho bé BM6A ┆                    ┆                   │
# │               ┆ không gây mẫn cảm, ┆ 50x100cm (Hồng) +  ┆                    ┆                   │
# │               ┆ và được ứng dụng   ┆ Khăn mặt HE57/58…  ┆                    ┆                   │
# │               ┆ những quy trình    ┆                    ┆                    ┆                   │
# │               ┆ công nghệ h…       ┆                    ┆                    ┆                   │
# │ 0009040000368 ┆ Vớ trẻ em Amigo Vớ ┆ Không xác định     ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ trẻ em Amigo       ┆                    ┆                    ┆                   │
# │               ┆ thương hiệu Ánh    ┆                    ┆                    ┆                   │
# │               ┆ Minh với thành     ┆                    ┆                    ┆                   │
# │               ┆ phần 100% cotton,  ┆                    ┆                    ┆                   │
# │               ┆ mềm mại, thoáng    ┆                    ┆                    ┆                   │
# │               ┆ mát, thấm hút mồ   ┆                    ┆                    ┆                   │
# │               ┆ hôi, k…            ┆                    ┆                    ┆                   │
# │ 0969104000003 ┆ Đối với bé không   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆ chỉ quần áo hay đồ ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# │               ┆ chơi mà mắt kính   ┆ kính bé trai CF    ┆                    ┆                   │
# │               ┆ cũng là phụ kiện   ┆ A019007 Xanh       ┆                    ┆                   │
# │               ┆ thời trang không   ┆ Thương hiệu: CF    ┆                    ┆                   │
# │               ┆ thể thiếu trong tủ ┆ Xuấ…               ┆                    ┆                   │
# │               ┆ đồ của bé.  Đư…    ┆                    ┆                    ┆                   │
# │ 1958000000004 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 144M           │
# │               ┆                    ┆ Tên sản phẩm: Sữa  ┆                    ┆                   │
# │               ┆                    ┆ Chống Nắng Senka   ┆                    ┆                   │
# │               ┆                    ┆ Dưỡng Ẩm Da        ┆                    ┆                   │
# │               ┆                    ┆ SPF50/PA++++ 40ml  ┆                    ┆                   │
# │               ┆                    ┆ Thương hi…         ┆                    ┆                   │
# │ 0969285000003 ┆ Đối với bé không   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 24-72M            │
# │               ┆ chỉ quần áo hay đồ ┆ Tên sản phẩm: Mắt  ┆                    ┆                   │
# ...
# │               ┆ vừa giúp bé có…    ┆                    ┆                    ┆                   │
# │ 0018000000001 ┆ ﻿﻿Thành phần : Thép, ┆ Chi tiết sản       ┆ Không xác định     ┆ ["0-12M", "0-6M"] │
# │               ┆ Polypropylene, ABS ┆ phẩmTên sản phẩm:  ┆                    ┆                   │
# │               ┆ resin, Polyamide,  ┆ Giường cũi Joie    ┆                    ┆                   │
# │               ┆ Polyester. - Khung ┆ Commuter Change    ┆                    ┆                   │
# │               ┆ cũi với độ an toàn ┆ &amp; Sooner Linen ┆                    ┆                   │
# │               ┆ cao, chịu lực tốt. ┆ GrayThương hiệu:   ┆                    ┆                   │
# │               ┆ - Đệm…             ┆ JoieXuất xứ: Trung ┆                    ┆                   │
# │               ┆                    ┆ Qu…                ┆                    ┆                   │
# │ 7437000000001 ┆ ﻿Ưu điểm nổi bật .  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Sử dụng chất liệu  ┆ Tên sản phẩm: Khăn ┆                    ┆                   │
# │               ┆ vải 100% sợi tự    ┆ tắm Mamamy         ┆                    ┆                   │
# │               ┆ nhiên & rayon siêu ┆ Tropical           ┆                    ┆                   │
# │               ┆ mềm mại với cả da  ┆ (700x1000mm)       ┆                    ┆                   │
# │               ┆ nhạy cảm. Độ thấm  ┆ Thương hiệu:       ┆                    ┆                   │
# │               ┆ nước siêu nh…      ┆ Mamamy   …         ┆                    ┆                   │
# │ 0048000000018 ┆ ﻿ Ưu điểm vượt trội ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ ["0-6M", "Từ 3M"] │
# │               ┆ của sản phẩm Với   ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ mong muốn mang tới ┆ sữa Olababy 240ml  ┆                    ┆                   │
# │               ┆ những trải nghiệm  ┆ Xanh dương         ┆                    ┆                   │
# │               ┆ bú sữa bình tự     ┆ Xuất xứ: Trung     ┆                    ┆                   │
# │               ┆ nhiên nhất cho em  ┆ Quốc       …       ┆                    ┆                   │
# │               ┆ bé, Olababy t…     ┆                    ┆                    ┆                   │
# │ 0214000000007 ┆ Ưu điểm nổi bật    ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ của sản phẩm Với   ┆ Tên sản phẩm: Rơ   ┆                    ┆                   │
# │               ┆ đầu bàn chải là    ┆ lưỡi silicone      ┆                    ┆                   │
# │               ┆ những sợi lông     ┆ Loại sản phẩm: Rơ  ┆                    ┆                   │
# │               ┆ bằng silicone mềm  ┆ lưỡi         Đối   ┆                    ┆                   │
# │               ┆ mại, không làm đau ┆ tượng sử…          ┆                    ┆                   │
# │               ┆ bé sẽ giúp mẹ vệ   ┆                    ┆                    ┆                   │
# │               ┆ si…                ┆                    ┆                    ┆                   │
# │ 0070000000002 ┆ ﻿ Ưu điểm nổi bật.  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Kháng tia UV,      ┆ Tên sản phẩm: Yếm  ┆                    ┆                   │
# │               ┆ kháng khuẩn vượt   ┆ Ăn Dặm (22 x 28cm) ┆                    ┆                   │
# │               ┆ trội đến 75%.      ┆ - MamaRu           ┆                    ┆                   │
# │               ┆ Không sử dụng hóa  ┆ Kích thước: 22 x   ┆                    ┆                   │
# │               ┆ chất độc hại. Độ   ┆ 28 cm      …       ┆                    ┆                   │
# │               ┆ thấm hút cao, tạo  ┆                    ┆                    ┆                   │
# │               ┆ cảm…               ┆                    ┆                    ┆                   │
# │ 0048000000031 ┆ Đặc điểm sản phẩm: ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 0-6M              │
# │               ┆ - Chất liệu an     ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ toàn (BPA Free) -  ┆ sữa cổ rộng Milk   ┆                    ┆                   │
# │               ┆ Núm ty silicone    ┆ Safe 250ml         ┆                    ┆                   │
# │               ┆ mềm, giảm đầy hơi, ┆ Chất liệu: Nhựa    ┆                    ┆                   │
# │               ┆ sặc - Thân bình:   ┆ PP, Silicon…       ┆                    ┆                   │
# │               ┆ Nhựa PP - Nắp đậ…  ┆                    ┆                    ┆                   │
# │ 0012000000016 ┆ ﻿﻿﻿﻿﻿Chăn lưới cho bé   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ ConCung Good       ┆ Tên sản phẩm: Chăn ┆                    ┆                   │
# │               ┆ (100x120cm,        ┆ lưới cho bé        ┆                    ┆                   │
# │               ┆ Hồng)với chất liệu ┆ ConCung Good       ┆                    ┆                   │
# │               ┆ 100% cotton mềm    ┆ (100x120cm, Hồng)  ┆                    ┆                   │
# │               ┆ mại, ấm áp. Chăn   ┆ Thương hiệu:…      ┆                    ┆                   │
# │               ┆ lưới tiện lợi xếp  ┆                    ┆                    ┆                   │
# │               ┆ gọn…               ┆                    ┆                    ┆                   │
# │ 4458000000001 ┆ Không xác định     ┆ Chi tiết sản       ┆ Không xác định     ┆ Từ 0M             │
# │               ┆                    ┆ phẩmTên sản        ┆                    ┆                   │
# │               ┆                    ┆ phẩm:Dầu Mù u Nam  ┆                    ┆                   │
# │               ┆                    ┆ Thái DươngThương   ┆                    ┆                   │
# │               ┆                    ┆ hiệu: Nam Thái     ┆                    ┆                   │
# │               ┆                    ┆ DươngXuất xứ: Việt ┆                    ┆                   │
# │               ┆                    ┆ NamThể tích:       ┆                    ┆                   │
# │               ┆                    ┆ 10mlĐộ tuổi p…     ┆                    ┆                   │
# │ 0092000000010 ┆ Máy Hâm Sữa Và     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 1-2M              │
# │               ┆ Thức Ăn Siêu Tốc   ┆ Tên sản phẩm: Máy  ┆                    ┆                   │
# │               ┆ Bằng Điện Philips  ┆ hâm sữa và thức ăn ┆                    ┆                   │
# │               ┆ Avent 355.00 - Sản ┆ siêu tốc Philips   ┆                    ┆                   │
# │               ┆ phẩm được sản xuất ┆ Avent (SCF 355.07) ┆                    ┆                   │
# │               ┆ với công nghệ mới  ┆ T…                 ┆                    ┆                   │
# │               ┆ giúp sữa trong…    ┆                    ┆                    ┆                   │
# │ 0011000000033 ┆ Ưu điểm nổi bật    ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ của sản phẩm  Gối  ┆ Tên sản phẩm: Gối  ┆                    ┆                   │
# │               ┆ Nu Bông với thành  ┆ xô nằm cho bé NOUS ┆                    ┆                   │
# │               ┆ phần 100% cotton   ┆ T2112_NU010 (Hồng) ┆                    ┆                   │
# │               ┆ cao cấp kết hợp    ┆ Thương hiệu: Nous  ┆                    ┆                   │
# │               ┆ công nghệ dệt mở,  ┆ …                  ┆                    ┆                   │
# │               ┆ cùng kết cấu 3 lớ… ┆                    ┆                    ┆                   │
# │ 0150000000008 ┆ Litetrax 4 DLX là  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ dòng xe đẩy của    ┆ Tên sản phẩm: Xe   ┆                    ┆                   │
# │               ┆ Joie – thương hiệu ┆ đẩy trẻ em Joie    ┆                    ┆                   │
# │               ┆ đến từ Anh Quốc.   ┆ Litetrax 4 DLX W/  ┆                    ┆                   │
# │               ┆ Với phiên bản      ┆ RC Deep Sea        ┆                    ┆                   │
# │               ┆ Litetrax 4 DLX mới ┆ Thương hiệu: Joie… ┆                    ┆                   │
# │               ┆ này, được nâng cấ… ┆                    ┆                    ┆                   │
# │ 0076000000036 ┆ Bình Uống Nước Có  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 0-6M              │
# │               ┆ Tay Cầm Nhựa PPSU  ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ KU5881A- 140ml     ┆ Uống Nước Có Tay   ┆                    ┆                   │
# │               ┆ được chế tạo từ    ┆ Cầm Nhựa PPSU      ┆                    ┆                   │
# │               ┆ chất liệu nhựa     ┆ KU5881A- 140ml     ┆                    ┆                   │
# │               ┆ PPSU cao cấp,      ┆ Thương hi…         ┆                    ┆                   │
# │               ┆ không chứa BPA và  ┆                    ┆                    ┆                   │
# │               ┆ chịu n…            ┆                    ┆                    ┆                   │
# │ 0151000000021 ┆ Xe đẩy Combi       ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 1-36M             │
# │               ┆ CrossGo 4 bánh     ┆ Tên sản phẩm: Xe   ┆                    ┆                   │
# │               ┆ quay tự động Kẻ    ┆ đẩy Combi CrossGo  ┆                    ┆                   │
# │               ┆ Ghi là sản phẩm    ┆ 4 bánh quay tự     ┆                    ┆                   │
# │               ┆ phù hợp với các bé ┆ động Kẻ Ghi        ┆                    ┆                   │
# │               ┆ từ 1-36 tháng      ┆ Thương hiệu:…      ┆                    ┆                   │
# │               ┆ tuổi. Trang bị đệm ┆                    ┆                    ┆                   │
# │               ┆ Eggshock…          ┆                    ┆                    ┆                   │
# │ 1604000000004 ┆ Nước giặt Arau     ┆ Tên sản phẩm: Nước ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Baby được sản xuất ┆ giặt Arau Baby     ┆                    ┆                   │
# │               ┆ tại Nhật Bản với   ┆ dạng túi 720ml     ┆                    ┆                   │
# │               ┆ 100% thành phần tự ┆ Thương hiệu:       ┆                    ┆                   │
# │               ┆ nhiên và không     ┆ Danh mục:          ┆                    ┆                   │
# │               ┆ chứa chất phụ gia  ┆ Từ khóa:           ┆                    ┆                   │
# │               ┆ tổng hợp. Sản phẩ… ┆                    ┆                    ┆                   │
# │ 5995000000003 ┆ ﻿﻿Hộp chia sữa và    ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 0-6M              │
# │               ┆ thực phẩm Animo    ┆ Tên sản phẩm: Hộp  ┆                    ┆                   │
# │               ┆ 400ml (xanh,       ┆ chia sữa Animo     ┆                    ┆                   │
# │               ┆ XTQ6332, TJJ) sở   ┆ 400ml (xanh,       ┆                    ┆                   │
# │               ┆ hữu thiết kế nhỏ   ┆ XTQ6332, TJJ)      ┆                    ┆                   │
# │               ┆ gọn, thích hợp để  ┆ Thương hiệu: Animo ┆                    ┆                   │
# │               ┆ mang theo cho bé   ┆ …                  ┆                    ┆                   │
# │               ┆ ra n…              ┆                    ┆                    ┆                   │
# │ 6892000000001 ┆ ﻿﻿Thực phẩm bảo vệ   ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ sức khỏe Zeambi    ┆ Tên sản phẩm: Thực ┆                    ┆                   │
# │               ┆ K2D3 Spray dùng    ┆ phẩm bảo vệ sức    ┆                    ┆                   │
# │               ┆ được từ sơ sinh    ┆ khỏe Zeambi K2D3   ┆                    ┆                   │
# │               ┆ đến khi lớn. Sản   ┆ Spray              ┆                    ┆                   │
# │               ┆ phẩm bổ sung       ┆ Thương hiệu: Zea…  ┆                    ┆                   │
# │               ┆ vitamin D3 và      ┆                    ┆                    ┆                   │
# │               ┆ vitamin K…         ┆                    ┆                    ┆                   │
# │ 5957000000005 ┆ ﻿﻿Ưu điểm nổi bật •  ┆ Chi tiết sản       ┆ Không xác định     ┆ Từ 0M             │
# │               ┆ Lưng ghế có thể    ┆ phẩmTên sản        ┆                    ┆                   │
# │               ┆ ngả phẳng, phù hợp ┆ phẩm:Xe đẩy trẻ em ┆                    ┆                   │
# │               ┆ cho bé từ sơ sinh• ┆ Joie Pact Pro W/   ┆                    ┆                   │
# │               ┆ Tương thích với    ┆ RC & ADPT          ┆                    ┆                   │
# │               ┆ ghế ngồi ô tô Joie ┆ AbyssThương hiệu:  ┆                    ┆                   │
# │               ┆ hoặc các lo…       ┆ JoieSản xuất tại:  ┆                    ┆                   │
# │               ┆                    ┆ Trung QuốcĐộ …     ┆                    ┆                   │
# │ 5957000000006 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ Từ 0M             │
# │               ┆                    ┆ Tên sản phẩm: Xe   ┆                    ┆                   │
# │               ┆                    ┆ đẩy Joie Chrome W/ ┆                    ┆                   │
# │               ┆                    ┆ RC & ADPT Pebble   ┆                    ┆                   │
# │               ┆                    ┆ Đối tượng sử dụng: ┆                    ┆                   │
# │               ┆                    ┆ tr…                ┆                    ┆                   │
# │ 7205000000010 ┆ Không xác định     ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 9-15M             │
# │               ┆                    ┆ Tên sản phẩm: Giày ┆                    ┆                   │
# │               ┆                    ┆ tập đi siêu nhẹ BG ┆                    ┆                   │
# │               ┆                    ┆ Animo A2410_MN004  ┆                    ┆                   │
# │               ┆                    ┆ Loại sản phẩm:     ┆                    ┆                   │
# │               ┆                    ┆ già…               ┆                    ┆                   │
# │ 6034000000326 ┆ ﻿Bộ bé gái ngắn     ┆ Chi tiết sản       ┆ Không xác định     ┆ Từ 12M            │
# │               ┆ Animo Easy         ┆ phẩmTên sản phẩm:  ┆                    ┆                   │
# │               ┆ TX0525035 tô điểm  ┆ Bộ bé gái ngắn     ┆                    ┆                   │
# │               ┆ giúp vẻ ngoài của  ┆ Animo Easy         ┆                    ┆                   │
# │               ┆ bé thêm xinh và dễ ┆ TX0525035Thương    ┆                    ┆                   │
# │               ┆ thương. Đặc biệt,  ┆ hiệu: AnimoXuất xứ ┆                    ┆                   │
# │               ┆ với chất liệu vải  ┆ thương hiệu: Việt  ┆                    ┆                   │
# │               ┆ ca…                ┆ NamChất li…        ┆                    ┆                   │
# │ 0502021160016 ┆ Loại bỏ hoàn toàn  ┆ Chi tiết sản phẩm  ┆ Không xác định     ┆ 1-2M              │
# │               ┆ bọt khí trong sữa. ┆ Tên sản phẩm: Bình ┆                    ┆                   │
# │               ┆ Giúp trẻ không bị  ┆ sữa cổ thường      ┆                    ┆                   │
# │               ┆ đau thắt dạ dày,   ┆ không chứa BPA Dr  ┆                    ┆                   │
# │               ┆ sặc sữa, đầy hơi,  ┆ Brown's, 60ml      ┆                    ┆                   │
# │               ┆ trẻ hay khóc       ┆ Xuất xứ: USA   …   ┆                    ┆                   │
# │               ┆ đêm... Không làm … ┆                    ┆                    ┆                   │
# └───────────────┴────────────────────┴────────────────────┴────────────────────┴───────────────────┘
