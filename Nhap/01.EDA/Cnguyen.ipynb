# %% [markdown]
# # Import thư viện + Load data

# %%
import os
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def read_parquet_by_type(train_path: str):
    # Lấy tất cả các file parquet trong thư mục
    files = [os.path.join(train_path, f) for f in os.listdir(train_path) if f.endswith('.parquet')]
    
    # Phân loại các file theo loại tên
    user_chunk_files = [file for file in files if 'user_chunk' in file]
    purchase_history_chunk_files = [file for file in files if 'purchase_history_daily_chunk' in file]
    item_chunk_files = [file for file in files if 'item_chunk' in file]
    
    # Đọc các file riêng biệt thành DataFrame
    user_chunk_df = pl.concat([pl.read_parquet(file) for file in user_chunk_files]) if user_chunk_files else None
    purchase_history_chunk_df = pl.concat([pl.read_parquet(file) for file in purchase_history_chunk_files]) if purchase_history_chunk_files else None
    item_chunk_df = pl.concat([pl.read_parquet(file) for file in item_chunk_files]) if item_chunk_files else None
    
    # Trả về một dictionary chứa các DataFrame
    return {
        "user_chunk": user_chunk_df,
        "purchase_history_chunk": purchase_history_chunk_df,
        "item_chunk": item_chunk_df
    }

# %%
data = read_parquet_by_type("C:/Users/tncn2/Downloads/recommendation dataset")

# history_df = data["purchase_history_chunk"]
# user_df = data["user_chunk"]
item_df = data["item_chunk"]

# %% [markdown]
# # Kiểm tra

# %%
cols_to_show = [
    "description_new", "color", "size", "origin",
    "volume", "material", "gender_target"
]

# --- Cấu hình để hiển thị đầy đủ text ---
pl.Config.set_tbl_cols(-1)           # Hiển thị tất cả các cột
pl.Config.set_tbl_width_chars(2000)  # Tăng độ rộng bảng để tránh bị '...'

# --- Lấy 5 hàng đầu ---
subset_df = item_df.select(cols_to_show).head(5)

# --- In ra ---
print(subset_df)
# Out:
# shape: (5, 7)
# ┌─────────────────────────────────┬────────────────┬────────────────┬────────────────────┬────────────────┬─────────────────────────────────┬────────────────┐
# │ description_new                 ┆ color          ┆ size           ┆ origin             ┆ volume         ┆ material                        ┆ gender_target  │
# │ ---                             ┆ ---            ┆ ---            ┆ ---                ┆ ---            ┆ ---                             ┆ ---            │
# │ str                             ┆ str            ┆ str            ┆ str                ┆ str            ┆ str                             ┆ str            │
# ╞═════════════════════════════════╪════════════════╪════════════════╪════════════════════╪════════════════╪═════════════════════════════════╪════════════════╡
# │ Chi tiết sản phẩm             … ┆ Không xác định ┆ Không xác định ┆ Không xác định     ┆ Không xác định ┆ Không xác định                  ┆ Không xác định │
# │ Không xác định                  ┆ Không xác định ┆ Không xác định ┆ Không xác định     ┆ Không xác định ┆ Không xác định                  ┆ Bé Gái         │
# │ Chi tiết sản phẩm             … ┆ Không xác định ┆ Không xác định ┆ Không xác định     ┆ Không xác định ┆ Không xác định                  ┆ Không xác định │
# │ Không xác định                  ┆ Không xác định ┆ Không xác định ┆ Nhật Bản, Nhật Bản ┆ Không xác định ┆ Giấy, bột giấy, vải không dệt,… ┆ Không xác định │
# │ Không xác định                  ┆ Không xác định ┆ Không xác định ┆ Nhật Bản, Nhật Bản ┆ Không xác định ┆ Giấy, bột giấy, vải không dệt,… ┆ Không xác định │
# └─────────────────────────────────┴────────────────┴────────────────┴────────────────────┴────────────────┴─────────────────────────────────┴────────────────┘

# %% [markdown]
# ### Xem thử 2 cột

# %%
pl.Config.set_tbl_rows(50)             # số dòng tối đa hiển thị
pl.Config.set_tbl_cols(10)             # số cột tối đa hiển thị
pl.Config.set_tbl_width_chars(200)     # tổng chiều rộng bảng ký tự
pl.Config.set_fmt_str_lengths(2000)     # độ dài chuỗi tối đa hiển thị (quan trọng nhất!)

item_df.select(["description", "description_new", "item_type"]).head(10)
# Out:
# shape: (10, 3)
# ┌──────────────────────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────┬────────────────┐
# │ description                                                                              ┆ description_new                                                                          ┆ item_type      │
# │ ---                                                                                      ┆ ---                                                                                      ┆ ---            │
# │ str                                                                                      ┆ str                                                                                      ┆ str            │
# ╞══════════════════════════════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════════════════════════════╪════════════════╡
# │ Không xác định                                                                           ┆ Chi tiết sản phẩm                     Tên sản phẩm: Hộp 2 núm ty DrBrown's Options Plus  ┆ Không xác định │
# │                                                                                          ┆ cổ rộng Y cut (Trên 9 tháng)         Loại sản phẩm: Núm ty         Đối tượng sử dụng:    ┆                │
# │                                                                                          ┆ Trẻ trên 9 tháng         Thương hiệu: DrBrown's         Điểm nổi bật: Núm vú silicon     ┆                │
# │                                                                                          ┆ siêu mềm giúp phát triển cơ hàm của bé thông qua sự cử động lưỡi tự nhiên.               ┆                │
# │                                                                                          ┆ Hộp 2 núm ty DrBrown's Options Plus cổ rộng Y cut (Trên 9 tháng) là núm ty dành cho trẻ  ┆                │
# │                                                                                          ┆ trên 9 tháng của thương hiệu DrBrown's đến từ Mỹ. Núm vú silicon siêu mềm giúp phát      ┆                │
# │                                                                                          ┆ triển cơ hàm của bé thông qua sự cử động lưỡi một cách tự nhiên.                         ┆                │
# │                                                                                          ┆ Núm ty silicon mềm mại            Núm vú silicon siêu mềm giúp phát triển cơ hàm của bé  ┆                │
# │                                                                                          ┆ thông qua sự cử động lưỡi một cách tự nhiên. Thiết kế đầu núm vừa vặn với vòm miệng bé,  ┆                │
# │                                                                                          ┆ mang lại sự thoải mái khi sử dụng.               Thiết kế thông minh            Núm ty   ┆                │
# │                                                                                          ┆ DrBrown's Options Plus được thiết kế với lỗ tiết sữa Y cut, phù hợp với nhu cầu ăn cháo  ┆                │
# │                                                                                          ┆ đặc của bé trên 9 tháng tuổi, từ đó giúp bé có cảm giác gần gũi hơn trong từng lần bú.   ┆                │
# │                                                                                          ┆ Hướng dẫn sử dụng               Rửa sạch núm ty bằng nước rửa chuyên dụng trước khi sử   ┆                │
# │                                                                                          ┆ dụng lần đầu.         Đun sôi núm vú trong vòng 3-5 phút để tiệt trùng sau mỗi lần sử    ┆                │
# │                                                                                          ┆ dụng.         Kiểm tra núm vú trước khi cho bé sử dụng, đảm bảo không có dấu hiệu rách   ┆                │
# │                                                                                          ┆ hoặc thủng.         Không cho trẻ bú bình khi không có sự giám sát của người lớn.        ┆                │
# │                                                                                          ┆ Hướng dẫn bảo quản               Bảo quản ở nhiệt độ phòng, nơi khô ráo, thoáng mát.     ┆                │
# │                                                                                          ┆ Tránh ánh nắng mặt trời trực tiếp.         Thay núm ty mới sau khi sử dụng từ 1 - 2      ┆                │
# │                                                                                          ┆ tháng để đảm bảo vệ sinh cho trẻ.                     Lưu ý               Không rửa núm  ┆                │
# │                                                                                          ┆ ty bằng xà phòng hoặc nước tẩy rửa.         Không tiệt trùng núm ty bằng lò vi sóng.     ┆                │
# │                                                                                          ┆ Kiểm tra núm vú thường xuyên trước khi sử dụng.                     Thành phần           ┆                │
# │                                                                                          ┆ Silicon cao cấp         Không chứa BPA         Chất đàn hồi tốt                          ┆                │
# │ Không xác định                                                                           ┆ Không xác định                                                                           ┆ Bộ quần áo     │
# │ - Chất liệu: Sản phẩm được làm bằng chất liệu silicone mềm, dẻo và nước đã được chưng    ┆ Chi tiết sản phẩm                     Tên sản phẩm: Miếng Gặm Nướu Papa (CEQ004) (Cá     ┆ Không xác định │
# │ cất đảm bảo an toàn cho bé. - Dành cho các bé trong giai đoạn mọc răng, giúp làm giảm    ┆ hồng)         Chất liệu: Silicone mềm, dẻo và nước đã được chưng cất         Đối tượng   ┆                │
# │ đau, ngứa lợi cho bé. - Bề mặt có các núm mát-xa nhỏ, mềm mịn, tạo cảm giác dễ chịu cho  ┆ sử dụng: Dành cho các bé trong giai đoạn mọc răng         Thương hiệu: Papa         Xuất ┆                │
# │ bé. - Có độ đàn hồi tốt, dễ dàng uốn dẻo, bền đẹp không gây ảnh hưởng tới sức khỏe cho   ┆ xứ: Thái Lan         Giá: 45.000₫                     **Miếng Gặm Nướu Papa (CEQ004) (Cá ┆                │
# │ bé. - Thiết kế dạng hình các con vật đồ dùng ngộ nghỉnh, đặc biệt có tay cầm, giúp bé dễ ┆ hồng)** là một sản phẩm giúp bé giảm đau trong giai đoạn mọc răng của thương hiệu **Papa ┆                │
# │ cầm nắm. - Trước khi cho bé sử dụng, bạn có thể cho vào tủ lạnh tạo cảm giác mát lạnh bé ┆ đến từ Thái Lan**. Sản phẩm được thiết kế đặc biệt để tạo cảm giác dễ chịu cho bé khi    ┆                │
# │ thích thú Lưu ý: Không sử dụng nước sôi để khử trùng sản phẩm. Xuất xứ: Thái Lan﻿﻿         ┆ nhai.                        Chất liệu an toàn: Silicone mềm, dẻo           Miếng gặm    ┆                │
# │                                                                                          ┆ nướu được làm bằng chất liệu silicone mềm, dẻo và nước đã được chưng cất, đảm bảo an     ┆                │
# │                                                                                          ┆ toàn tuyệt đối cho sức khỏe của bé.            Cảm giác dễ chịu: Bề mặt núm mát-xa       ┆                │
# │                                                                                          ┆ Bề mặt có các núm mát-xa nhỏ, mềm mịn, tạo cảm giác dễ chịu và thích thú khi bé sử dụng. ┆                │
# │                                                                                          ┆ Thiết kế ngộ nghĩnh: Hình động vật với tay cầm           Sản phẩm được thiết kế dạng     ┆                │
# │                                                                                          ┆ hình các con vật đồ dùng ngộ nghĩnh, đặc biệt có tay cầm giúp bé dễ cầm nắm và chơi đùa. ┆                │
# │                                                                                          ┆ Độ đàn hồi tốt: Bền đẹp và dễ sử dụng           Miếng gặm nướu có độ đàn hồi tốt, dễ     ┆                │
# │                                                                                          ┆ dàng uốn dẻo, bền đẹp mà không gây ảnh hưởng đến sức khỏe cho bé.            Cảm giác    ┆                │
# │                                                                                          ┆ mát lạnh: Hỗ trợ giảm đau           Trước khi cho bé sử dụng, bạn có thể cho vào tủ lạnh ┆                │
# │                                                                                          ┆ tạo cảm giác mát lạnh, giúp bé thích thú và giảm đau nướu.               Hướng dẫn sử    ┆                │
# │                                                                                          ┆ dụng               Rửa sạch sản phẩm trước khi cho bé sử dụng.         Để sản phẩm trong ┆                │
# │                                                                                          ┆ tủ lạnh trước khi cho bé sử dụng để tạo cảm giác mát lạnh.         Giám sát bé khi sử    ┆                │
# │                                                                                          ┆ dụng để đảm bảo an toàn.                     Hướng dẫn bảo quản               Bảo quản   ┆                │
# │                                                                                          ┆ sản phẩm ở nơi khô ráo, thoáng mát.         Không sử dụng nước sôi để khử trùng sản      ┆                │
# │                                                                                          ┆ phẩm.         Thường xuyên kiểm tra sản phẩm để đảm bảo không bị hư hỏng.                ┆                │
# │                                                                                          ┆ Lưu ý               Sản phẩm chỉ dành cho bé trong giai đoạn mọc răng.         Khi sản   ┆                │
# │                                                                                          ┆ phẩm có dấu hiệu hư hỏng, không nên cho bé sử dụng.  …                                   ┆                │
# │ ﻿﻿Tã dán Merries size S 82 miếng là sản phẩm dành cho bé 4-8kg đến từ thương hiệu uy tín   ┆ Không xác định                                                                           ┆ Không xác định │
# │ Merries của Nhật Bản. Ra đời với công nghệ "4 siêu" - siêu mềm mại, siêu thông thoáng,   ┆                                                                                          ┆                │
# │ siêu thấm hút, siêu linh hoạt, tã dán Merries trở thành "người bạn" của hàng ngàn em bé  ┆                                                                                          ┆                │
# │ trên toàn thế giới.﻿﻿﻿Ưu điểm nổi bật. Siêu mềm mại: được làm từ bông siêu mỏng và các hạt  ┆                                                                                          ┆                │
# │ thấm hút nhanh, có bề mặt mềm mại, xốp mịn, tiếp xúc nhẹ nhàng, không gây hằn đỏ trên da ┆                                                                                          ┆                │
# │ bé.. Siêu thông thoáng: dựa vào công nghệ siêu thoát khí từ chất liệu màng đáy thoát khí ┆                                                                                          ┆                │
# │ đặc biệt giúp bé yêu cảm thấy luôn dễ chịu, thoải mái. Cha mẹ có thể xóa tan nỗi lo nóng ┆                                                                                          ┆                │
# │ ẩm và hầm hơi do nước tiểu và mồ hôi cũng như kích ứng da do các tác nhân gây hại.. Siêu ┆                                                                                          ┆                │
# │ thấm hút: thiết kế chống tràn khóa chặt chất lỏng đến 6-8 tiếng và không vón cục. Các    ┆                                                                                          ┆                │
# │ hạt thấm hút kép cùng với bề mặt tiếp xúc điểm xốp mịn tạo ra những khoảng trống giúp    ┆                                                                                          ┆                │
# │ thấm chất lỏng cực nhanh và không bị lan ra khắp bề mặt tã.. Siêu linh hoạt: thiết kế    ┆                                                                                          ┆                │
# │ vừa vặn với cơ thể bé với vách chống tràn co dãn và phần eo mềm mại ôm khít, thiết kế    ┆                                                                                          ┆                │
# │ phần đáy hình chữ "W" không gây cảm giác vướng víu và linh hoạt theo từng chuyển động    ┆                                                                                          ┆                │
# │ của bé.. Vạch báo thời gian thay tã thông minh: thay đổi sang màu xanh lá đậm sẽ giúp bố ┆                                                                                          ┆                │
# │ mẹ dễ dàng nhận biết thời điểm cần thiết để thay tã cho bé.Hướng dẫn sử dụng             ┆                                                                                          ┆                │
# │ ﻿﻿﻿Bỉm tã quần Merries size M 58 miếng là sản phẩm dành cho bé từ 6-11kg đến từ thương hiệu ┆ Không xác định                                                                           ┆ Không xác định │
# │ uy tín Merries của Nhật Bản. ﻿﻿﻿﻿Tã quần Merries – một sản phẩm mang tính đột phá đến từ     ┆                                                                                          ┆                │
# │ Nhật Bản, khác biệt hoàn toàn so với những loại tã giấy khác trên thị trường, đặc biệt   ┆                                                                                          ┆                │
# │ mỏng nhẹ giúp bé tung tăng chạy nhảy suốt 24h mà vẫn khô thoáng và êm dịu.Ưu điểm nổi    ┆                                                                                          ┆                │
# │ bật﻿. Siêu mềm mại với bề mặt tiếp xúc điểm xốp mịn và chất liệu mỏng nhẹ, không gây kích ┆                                                                                          ┆                │
# │ ứng lên làn da mỏng manh của bé.. Siêu thông thoáng với chất liệu màng đáy thoát khí đặc ┆                                                                                          ┆                │
# │ biệt. Các đường thun được thiết kế để không khí dễ dàng thổi qua giữa miếng tã và da. Bé ┆                                                                                          ┆                │
# │ sẽ luôn cảm thấy khô ráo ngay cả khi vân động nhiều.. Siêu thấm hút với lõi siêu thấm    ┆                                                                                          ┆                │
# │ trung tâm độc đáo giúp thấm hút và khoá chặt một lượng lớn chất lỏng ngay lập tức. Đặc   ┆                                                                                          ┆                │
# │ biệt tã không bị vón cục sau khi thấm hút.. Siêu linh hoạt trong chuyển động với thiết   ┆                                                                                          ┆                │
# │ kế chữ “W” biến đổi linh hoạt với đáy quần thích ứng theo chuyển động của bé. Đường thun ┆                                                                                          ┆                │
# │ ôm vừa vặn không để lại vết hằn trên da.. Vạch báo thời gian thay tã thông minh: Thay tã ┆                                                                                          ┆                │
# │ khi vạch đổi sang màu xanh lá đậmHướng dẫn sử dụng ﻿﻿                                      ┆                                                                                          ┆                │
# │ Áo thun bé trai tay ngắn CF B078010 Xanh  là sản phẩm với chất liệu cotton mềm mại, thấm ┆ Không xác định                                                                           ┆ Áo             │
# │ hút mồ hôi, đường may kỹ lưỡng chắc chắn sẽ giúp bé thoải mái vận động. Bên cạnh đó, sản ┆                                                                                          ┆                │
# │ phẩm có kiểu dáng cá tính cùng họa tiết đáng yêu sẽ giúp bé thêm phần thời trang. ĐẶC    ┆                                                                                          ┆                │
# │ ĐIỂM NỔI BẬT Chất liệu cotton mềm mại Sản phẩm được may từ vải cotton mềm mại cho phép   ┆                                                                                          ┆                │
# │ bé thoải mái chơi đùa, vận động mà không cảm thấy khó chịu. Bên cạnh đó, chất liệu       ┆                                                                                          ┆                │
# │ cotton không gây kích ứng da và có khả năng thấm hút mồ hôi tốt nên Mẹ không phải lo     ┆                                                                                          ┆                │
# │ lắng bé yêu bị nổi rôm, tuyệt đối an toàn khi sử dụng. Thiết kế thoải mái, đáng yêu      ┆                                                                                          ┆                │
# │ Thiết kế thoải mái phối cùng họa tiết cá tính sẽ mang đến phong cách thoải mái và không  ┆                                                                                          ┆                │
# │ kém phần thời trang cho bé của bạn. Ngoài ra, các đường nối, đường cuốn biên trên sản    ┆                                                                                          ┆                │
# │ phẩm không bị nổi cộm gây khó chịu và ngứa da bé cho phép bé vận động dễ dàng. THÔNG TIN ┆                                                                                          ┆                │
# │ SẢN PHẨM Tên sản phẩm: Áo thun bé trai tay ngắn CF B078010 Xanh Thương hiệu: CF Sản xuất ┆                                                                                          ┆                │
# │ tại: CÔNG TY TNHH MAY MẶC HẢI NAM , Việt Nam Chất liệu: 95% Cotton5% Spandex BẢO QUẢN    ┆                                                                                          ┆                │
# │ SẢN PHẨM - Hạn chế dùng sản phẩm giặt tẩy - Không ngâm, giặt chung với sản phẩm ra màu - ┆                                                                                          ┆                │
# │ Không giặt trong nước nóng trên 40°C - Nên ủi/là mặt trái sản phẩm                       ┆                                                                                          ┆                │
# │ - Sản phẩm dành cho bé từ 3 - 36 tháng tuổi. - Nguyên liệu được làm bằng cao su có tính  ┆ Chi tiết sản phẩm                     Tên sản phẩm: Thảm xốp hình chữ 30x30cm, 26 miếng  ┆ Không xác định │
# │ đàn hồi tốt, dùng lót sàn. Giúp bé vừa học vừa chơi mà không lo bị bé yêu bị va đập. -   ┆ Chất liệu: Cao su         Kích thước: 30x30x1cm/miếng         Khối lượng tịnh: 58g/miếng ┆                │
# │ Thảm có nhiều màu sắc, hình các chữ cái và số kích thích bé vừa học vừa chơi, mẹ yên tâm ┆ Xuất xứ: Việt Nam         Năm sản xuất: 2018         Sản xuất tại: Công Ty TNHH SX-TM    ┆                │
# │ làm việc nhà. Hướng dẫn sử dụng: Nối các tấm xốp với nhau bằng răng nối. Cảnh báo: Không ┆ THOẠI TÂN THÀNH (28/36/23 Lương Thế Vinh, P.Tân Thới Hoà, Q.Tân phú, TP.HCM)             ┆                │
# │ nên cho bé ngậm, cắn hay đưa sản phẩm vào miệng. Thông tin sản phẩm - Tên sản phẩm: Thảm ┆ Chịu trách nhiệm hàng hóa: CÔNG TY CỔ PHẦN CON CƯNG (101-103 Trần Quang Khải, P.Tân      ┆                │
# │ xốp hình chữ 30x30cm, 26 miếng - Chất liệu: Cao su - Kích thước: 30x30x1cm/ miếng. -     ┆ Định, Q.1, HCM)                        **Thảm xốp hình chữ 30x30cm, 26 miếng** là thảm   ┆                │
# │ Khối lượng tịnh: 58g/miếng. - Xuất xứ: Việt Nam - Năm sản xuất: 2018 Sản xuất tại:       ┆ xốp dành cho bé từ 3 - 36 tháng tuổi của Con Cưng đến từ Việt Nam. Sản phẩm được làm từ  ┆                │
# │ - Công Ty TNHH SX-TM THOẠI TÂN THÀNH (28/36/23 Lương Thế Vinh, P.Tân Thới Hoà, Q.Tân     ┆ cao su có tính đàn hồi tốt, giúp bé học chơi mà không lo bị va đập.                      ┆                │
# │ phú, TP.HCM) Chịu trách nhiệm hàng hóa: - CÔNG TY CỔ PHẦN CON CƯNG (101-103 Trần Quang   ┆ Thảm xốp hình chữ - Nguyên liệu cao su, tính đàn hồi tốt           Thảm xốp hình chữ với ┆                │
# │ Khải, P.Tân Định, Q.1, HCM) Lưu ý: Họa tiết và màu sắc có thể thay đổi tùy vào đợt hàng  ┆ thiết kế nhiều màu sắc, hình các chữ cái và số, giúp bé vừa học vừa chơi, tạo điều kiện  ┆                │
# │ về﻿                                                                                       ┆ cho sự phát triển trí tuệ và thể chất mà mẹ có thể yên tâm làm việc nhà.            Cảnh ┆                │
# │                                                                                          ┆ báo an toàn - Bé không nên ngậm hay cắn           Để đảm bảo an toàn cho trẻ, không nên  ┆                │
# │                                                                                          ┆ cho bé ngậm, cắn hoặc đưa sản phẩm vào miệng trong quá trình vui chơi.                   ┆                │
# │                                                                                          ┆ Hướng dẫn sử dụng               Nối các tấm xốp với nhau bằng răng nối.                  ┆                │
# │                                                                                          ┆ Hướng dẫn bảo quản               Để sản phẩm ở nơi khô ráo, thoáng mát.         Tránh    ┆                │
# │                                                                                          ┆ ánh nắng mặt trời trực tiếp.         Vệ sinh bề mặt sản phẩm bằng vải ẩm khi cần thiết.  ┆                │
# │                                                                                          ┆ Lưu ý               Họa tiết và màu sắc có thể thay đổi tùy vào đợt hàng về.             ┆                │
# │                                                                                          ┆ Thành phần               Cao su                                                          ┆                │
# │ ﻿﻿﻿Dòng sản phẩm tã quần Huggies Dry với tinh chất tràm trà tự nhiên sẽ mang đến cho da con ┆ Không xác định                                                                           ┆ Không xác định │
# │ cảm giác dễ chịu. Đặc biệt, sản phẩm cũng được chứng minh lâm sàng giúp ngừa hăm tã hiệu ┆                                                                                          ┆                │
# │ quả. Ưu điểm nổi bật. Tã quần Huggies Dry cải tiến mới với công nghệ lưng thun đệm mây,  ┆                                                                                          ┆                │
# │ chống hằn da;. Bề mặt tã quần Huggies được bổ sung tinh chất tràm trà tự nhiên giúp mang ┆                                                                                          ┆                │
# │ đến cảm giác dịu da;. Khả năng thoáng khí được chứng minh lâm sàng giúp ngăn ngừa hăm    ┆                                                                                          ┆                │
# │ tã, giữ mông bé luôn khô thoáng;. Nhờ chất liệu mềm mại, bỉm Huggies giúp nâng niu làn   ┆                                                                                          ┆                │
# │ da nhạy cảm của bé.Hướng dẫn thay tã. Mặt tã như mặt quần của bé với chữ "SAU-BACK" ở    ┆                                                                                          ┆                │
# │ mặt sau.. Chỉnh tã ôm vừa chân, tránh bị gập vào để chống tràn hiệu quả.. Khi tã bị bẩn, ┆                                                                                          ┆                │
# │ xé đường thun 2 bên hông để cởi bỏ.Hướng dẫn chọn size tã* Sản phẩm sẽ được giao hàng    ┆                                                                                          ┆                │
# │ với bao bì ngẫu nhiên. ﻿                                                                  ┆                                                                                          ┆                │
# │ Không xác định                                                                           ┆ null                                                                                     ┆ Không xác định │
# │ Sản phẩm Tã dán sơ sinh Moony dưới 5kg, 90 miếng với đặc điểm nổi bật: VIỀN ĐIỀU HÒA     ┆ Chi tiết sản phẩm                     Tên sản phẩm: Bỉm - Tã dán Moony newborn 90 miếng  ┆ Không xác định │
# │ THÔNG MINH giúp tã cong ôm vừa vặn cơ thể bé, chống trào hiệu quả. MÀNG VẢI LƯNG THUN 3  ┆ (         Thương hiệu: Unicharm         Xuất xứ thương hiệu: Nhật Bản         Kích cỡ    ┆                │
# │ VÒNG CO GIÃN 360° giúp khô thoáng cả ngày dài, không lo bị hầm bí và hăm đỏ RÃNH RỐN     ┆ (size): Newborn,          Số miếng: 90                     Bỉm - Tã dán Moony newborn 90 ┆                │
# │ OHESO giúp bảo vệ phần rốn non nớt của bé sơ sinh SỢI NANO SIÊU MỀM MỊN nhẹ nhàng nâng   ┆ miếng ( là bỉm tã dán dành cho bé sơ sinh của thương hiệu Moony đến từ Nhật Bản. Với     ┆                │
# │ niu làn da nhạy cảm, mong manh của bé LÕI BÔNG CAO CẤP siêu chống trào CHỈ THỊ ƯỚT giúp  ┆ viền điều hòa thông minh, sản phẩm giúp bé thoải mái mà không lo trào tã.                ┆                │
# │ báo hiệu cho mẹ thời điểm thay tã cho bé - Bỉm tã Moony là loại bỉm nổi tiếng tại Nhật   ┆ Viền điều hòa thông minh giúp sản phẩm ôm vừa vặn cơ thể bé, chống trào hiệu quả.        ┆                │
# │ Bản được sản xuất bởi tập đoàn Unicharm danh tiếng. - Thấm hút rất tốt, với lớp bông mềm ┆ Viền điều hòa thông minh là tính năng giúp tã Moony cong ôm vừa vặn cơ thể bé, ngăn ngừa ┆                │
# │ và lớp thoáng khí, tạo cảm giác thoải mái, khô thoáng, dễ chịu cho bé. - Đặc biệt Bỉm tã ┆ nguy cơ trào tã, mang lại sự thoải mái tốt nhất cho trẻ nhỏ.               Màng vải lưng ┆                │
# │ Moony có chất dưỡng da và Vitamin E giúp chống hăm cho bé. - Lưng thun được thiết kế co  ┆ thun 3 vòng co giãn 360° giúp khô thoáng cả ngày dài.           Màng vải này giúp tã     ┆                │
# │ dãn rất hợp lí, chống trào ngược lên áo khi bé nằm. Các bé sẽ được hưởng cảm giác vừa    ┆ không bị hầm bí và hăm đỏ, cho bé thoải mái tiếp xúc với không khí, mỗi cử động đều dễ   ┆                │
# │ vặn, êm ái đặc biệt với những bé còn nhỏ phải dùng bỉm 24/24h. - Độ thấm hút cao, tuyệt  ┆ dàng và không bị cản trở.               Rãnh rốn Oheso bảo vệ phần rốn non nớt của bé sơ ┆                │
# │ đối an toàn cho bé Moony với thiết kế chống tràn ra ngoài, bảo vệ bé tốt nhất. - Tã bỉm  ┆ sinh.           Rãnh rốn OHESO được thiết kế riêng, giúp bảo vệ phần rốn nhạy cảm của    ┆                │
# │ Moony Nhật có cả miếng dán và quần, rất tiện dụng. THÔNG TIN SẢN PHẨM: Hướng dẫn sử      ┆ trẻ, tạo cảm giác thoải mái nhất cho các bé ngay từ những ngày đầu đời.                  ┆                │
# │ dụng: - Mặt sau tã có miếng dán cố định. Mở miếng tã mới và tròng vào chân bé, kéo CAO   ┆ Sợi Nano siêu mềm mịn nhẹ nhàng nâng niu làn da nhạy cảm.           Chất liệu sợi Nano   ┆                │
# │ ngang hông. - Kéo chắc tay phần băng dính để tã vừa thật khít phần LƯNG hoàn toàn có thể ┆ giúp tã Moony siêu nhẹ, mang lại cảm giác mềm mại và dễ chịu cho làn da của bé yêu, giảm ┆                │
# │ co giãn nên mẹ không phải lo tã ôm quá chặt. Lưu ý: - Đảm bảo vùng đai lưng tã nằm trên  ┆ thiểu tình trạng kích ứng da.            Lõi bông cao cấp siêu chống trào.           Lõi ┆                │
# │ rốn bé - Khi dán, nên căng phần băng dính sao cho vùng chống tràn sau lưng được kéo ra   ┆ bông được thiết kế để thấm hút cực tốt, giúp sản phẩm giữ cho bé luôn khô thoáng, mà     ┆                │
# │ Hướng dẫn bảo quản: - Bảo quản nơi khô ráo, thoáng mát, tránh ánh nắng trực tiếp, để xa  ┆ không lo bị tràn ra ngoài.            Chỉ thị ướt báo hiệu thời điểm thay tã cho bé.     ┆                │
# │ tầm tay trẻ em. ﻿                                                                         ┆ Thêm vào đó, chỉ thị ướt tiện lợi giúp mẹ nhanh chóng nhận biết khi nào cần thay tã cho  ┆                │
# │                                                                                          ┆ bé, mang lại sự tiện lợi và chăm sóc tốt nhất.               Hướng dẫn chọn size         ┆                │
# │                                                                                          ┆ Chọn đúng size tã cho bé là rất quan trọng. Với tã Moony, size Newborn (                 ┆                │
# │                                                                                          ┆ Hướng dẫn sử dụng               Mặt sau tã có miếng dán cố định. Mở miếng tã mới và      ┆                │
# │                                                                                          ┆ tròng vào chân bé, kéo CAO ngang hông.         Kéo ch…                                   ┆                │
# └──────────────────────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────┴────────────────┘

# %% [markdown]
# **Độ phủ hai cột mô tả: `description_new` vs `description`**
#
# **Bảng tóm tắt (đếm theo NULL thuần):**
#
# | Trường hợp | Số dòng | Tỷ lệ (%) |
# |---|---:|---:|
# | **Cả hai đều có** (`both_present`) | **6,308** | **23.08** |
# | **Chỉ có `description_new`** | **3,194** | **11.69** |
# | **Chỉ có `description`** | **2,395** | **8.76** |
# | **Không có cả hai** (`neither_present`) | **15,435** | **56.47** |
# | **Tổng** | **27,332** | **100.00** |
#
# - Hàng **có `description_new`** = 6,308 + 3,194 = **9,502** (**34.77%**).
#   ⟶ **Thiếu `description_new`** ≈ **17,830**.
# - Hàng **có `description`** = 6,308 + 2,395 = **8,703** (**31.84%**).
#   ⟶ **Thiếu `description`** ≈ **18,629**.
# - Hàng **có ít nhất một** mô tả = 27,332 − 15,435 = **11,897** (**43.53%**).
#   ⟶ Dù **gộp/điền qua lại**, vẫn còn **56.47%** dòng **không có mô tả**.
#
#
# ### Gợi ý tiền xử lý
# - Tạo cột hợp nhất **`description_merged`**: ưu tiên `description_new`, nếu thiếu thì dùng `description`.
# - Với nhóm **thiếu cả hai**:
#   - Loại/giảm trọng số nếu mô hình cần văn bản, **hoặc**
#   - Bổ sung đặc trưng từ metadata (brand, material, category, …), **hoặc**
#   - Sinh mô tả tóm tắt từ metadata (nếu phù hợp).

# %%
kxd_list = ["không xác định","null"]

s_new = pl.col("description_new").cast(pl.Utf8).str.to_lowercase().str.strip_chars()
s_old = pl.col("description").cast(pl.Utf8).str.to_lowercase().str.strip_chars()

new_has_text = pl.col("description_new").is_not_null() & (s_new.str.len_chars() > 0) & (~s_new.is_in(kxd_list))
old_has_text = pl.col("description").is_not_null() & (s_old.str.len_chars() > 0) & (~s_old.is_in(kxd_list))

counts_value = (
    item_df.select(
        (new_has_text & old_has_text).sum().alias("both_present"),
        (new_has_text & ~old_has_text).sum().alias("only_description_new"),
        (~new_has_text & old_has_text).sum().alias("only_description"),
        (~new_has_text & ~old_has_text).sum().alias("neither_present"),
    )
    .with_columns(
        total = pl.sum_horizontal(pl.all())
    )
    .with_columns(
        *[(pl.col(c) / pl.col("total") * 100).round(2).alias(f"{c}_pct")
          for c in ["both_present","only_description_new","only_description","neither_present"]]
    )
)
print(counts_value)
# Out:
# shape: (1, 9)
# ┌──────────────┬──────────────────────┬──────────────────┬─────────────────┬───────┬──────────────────┬──────────────────────────┬──────────────────────┬─────────────────────┐
# │ both_present ┆ only_description_new ┆ only_description ┆ neither_present ┆ total ┆ both_present_pct ┆ only_description_new_pct ┆ only_description_pct ┆ neither_present_pct │
# │ ---          ┆ ---                  ┆ ---              ┆ ---             ┆ ---   ┆ ---              ┆ ---                      ┆ ---                  ┆ ---                 │
# │ u32          ┆ u32                  ┆ u32              ┆ u32             ┆ u32   ┆ f64              ┆ f64                      ┆ f64                  ┆ f64                 │
# ╞══════════════╪══════════════════════╪══════════════════╪═════════════════╪═══════╪══════════════════╪══════════════════════════╪══════════════════════╪═════════════════════╡
# │ 6308         ┆ 3194                 ┆ 2395             ┆ 15435           ┆ 27332 ┆ 23.08            ┆ 11.69                    ┆ 8.76                 ┆ 56.47               │
# └──────────────┴──────────────────────┴──────────────────┴─────────────────┴───────┴──────────────────┴──────────────────────────┴──────────────────────┴─────────────────────┘

# %%
# df_item = item_df.with_columns(
#     pl.when(pl.col("description_new").is_not_null() & (pl.col("description_new").str.len_chars()>0))
#       .then(pl.col("description_new"))
#       .otherwise(pl.col("description"))
#       .alias("description_merged")
# )

# %% [markdown]
# #### Tính Cramer's V giữa des_new và des với một số feature có thể liên quan

# %%
import polars as pl
from math import sqrt

def cramers_v_fast_pl(df: pl.DataFrame, x: str, y: str):
    """
    Cramér's V (raw) giữa 2 cột phân loại x, y.
    - Chỉ drop NULL ở x,y (giữ nguyên dữ liệu gốc).
    - Không tạo cross-join r*c nên rất nhẹ.
    Trả về: (V, n, r, c)
    """
    d = df.select([x, y]).drop_nulls()
    n = d.height
    if n == 0:
        return float("nan"), 0, 0, 0

    # O_ij
    obs = d.group_by([x, y]).len().rename({"len": "obs"})
    # Tổng hàng & cột
    row = d.group_by(x).len().rename({"len": "row"})
    col = d.group_by(y).len().rename({"len": "col"})
    t = obs.join(row, on=x, how="left").join(col, on=y, how="left")

    # Chi-square: sum(O^2 / E) - N, với E = row_i * col_j / N
    term_sum = t.select(
        ((pl.col("obs") ** 2) / (pl.col("row") * pl.col("col") / n)).sum()
    ).to_series()[0]
    chi2 = term_sum - n
    r, c = d.select(pl.col(x).n_unique().alias("r"),
                    pl.col(y).n_unique().alias("c")).row(0)
    if r < 2 or c < 2:
        return float("nan"), n, r, c
    phi2 = chi2 / n
    V = sqrt(phi2 / min(r - 1, c - 1))
    return float(V), n, r, c

def compare_feature_pl(df: pl.DataFrame, feature: str) -> pl.DataFrame:
    rows = []
    for txt in ["description_new", "description"]:
        v, n, r, c = cramers_v_fast_pl(df, txt, feature)
        rows.append({"feature": feature, "text_col": txt,
                     "n_used": n, "x_levels": r, "y_levels": c,
                     "cramers_v": None if v != v else round(v, 3)})
    return pl.DataFrame(rows)

# %%
# 1 feature
print(compare_feature_pl(item_df, "material"))

# Nhiều feature
features = ["material","origin","size","color","item_type",
            "age_group","gender_target","brand","manufacturer","category"]
res = pl.concat([compare_feature_pl(item_df, f) for f in features])
print(res.select(["feature","text_col","cramers_v"])
         .pivot(values="cramers_v", index="feature", columns="text_col")
         .sort("feature"))
# Out:
# shape: (2, 6)
# ┌──────────┬─────────────────┬────────┬──────────┬──────────┬───────────┐
# │ feature  ┆ text_col        ┆ n_used ┆ x_levels ┆ y_levels ┆ cramers_v │
# │ ---      ┆ ---             ┆ ---    ┆ ---      ┆ ---      ┆ ---       │
# │ str      ┆ str             ┆ i64    ┆ i64      ┆ i64      ┆ f64       │
# ╞══════════╪═════════════════╪════════╪══════════╪══════════╪═══════════╡
# │ material ┆ description_new ┆ 22317  ┆ 9501     ┆ 583      ┆ 0.884     │
# │ material ┆ description     ┆ 27332  ┆ 8583     ┆ 583      ┆ 0.964     │
# └──────────┴─────────────────┴────────┴──────────┴──────────┴───────────┘
# shape: (10, 3)
# ┌───────────────┬─────────────────┬─────────────┐
# │ feature       ┆ description_new ┆ description │
# │ ---           ┆ ---             ┆ ---         │
# │ str           ┆ f64             ┆ f64         │
# ╞═══════════════╪═════════════════╪═════════════╡
# │ age_group     ┆ 0.762           ┆ 0.818       │
# │ brand         ┆ 0.867           ┆ 0.837       │
# │ category      ┆ 0.838           ┆ 0.813       │
# │ color         ┆ 0.623           ┆ 0.755       │
# │ gender_target ┆ 0.612           ┆ 0.597       │
# │ item_type     ┆ 0.868           ┆ 0.83        │
# │ manufacturer  ┆ 0.889           ┆ 0.951       │
# │ material      ┆ 0.884           ┆ 0.964       │
# │ origin        ┆ 0.821           ┆ 0.869       │
# │ size          ┆ 0.654           ┆ 0.84        │
# └───────────────┴─────────────────┴─────────────┘
# C:\Users\tncn2\AppData\Local\Temp\ipykernel_16480\1476810371.py:9: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   .pivot(values="cramers_v", index="feature", columns="text_col")

# %% [markdown]
# ### Tính contain_ratio cho những dòng both present des_new và des

# %%
import polars as pl
import re

# =======================
# 1) Tham số có thể chỉnh
# =======================
LEVEL = "word"   # "word" (theo từ) hoặc "char" (theo ký tự)
N     = 2        # n-gram: word bigram (2) / trigram (3) ; hoặc char-gram (ví dụ 5)

# =======================
# 2) Hàm tiện ích
# =======================
def tokenize(s: str):
    # Tách từ đơn giản, giữ unicode (phù hợp TV/TViệt)
    return re.findall(r"\w+", s.lower())

def ngrams(tokens, n=2):
    if len(tokens) < n: 
        return []
    return [" ".join(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

def build_set(s: str, level="word", n=2):
    if not s:
        return set()
    if level == "char":
        s_norm = re.sub(r"\s+", " ", s.lower())
        if len(s_norm) < n:
            return set()
        return set(s_norm[i:i+n] for i in range(len(s_norm)-n+1))
    elif level == "word":
        toks = tokenize(s)
        if n == 1:
            return set(toks)
        else:
            return set(ngrams(toks, n))
    else:
        raise ValueError("LEVEL phải là 'word' hoặc 'char'.")

def contain_ratio_sets(A_set: set, B_set: set) -> float:
    return 0.0 if not A_set else len(A_set & B_set) / len(A_set)

def contain_pair(a: str, b: str, level="word", n=2):
    """
    Trả về (recall=A|B, precision=B|A, F1, sizeA, sizeB)
    """
    A = build_set(a, level=level, n=n)
    B = build_set(b, level=level, n=n)
    r = contain_ratio_sets(A, B)  # A nằm trong B bao nhiêu %
    p = contain_ratio_sets(B, A)  # B nằm trong A bao nhiêu %
    f1 = 0.0 if (p + r) == 0 else 2 * p * r / (p + r)
    return (r, p, f1, len(A), len(B))

# ===========================================
# 3) Mask both_present & báo cáo tình trạng null
# ===========================================
mask_both = (
    pl.col("description").is_not_null() & pl.col("description_new").is_not_null() &
    (pl.col("description").str.len_chars() > 0) &
    (pl.col("description_new").str.len_chars() > 0)
)

null_report = item_df.select([
    (pl.col("description").is_null() & pl.col("description_new").is_null()).mean().alias("both_null_frac"),
    (pl.col("description").is_null() & pl.col("description_new").is_not_null()).mean().alias("desc_null_only_frac"),
    (pl.col("description").is_not_null() & pl.col("description_new").is_null()).mean().alias("desc_new_null_only_frac"),
    mask_both.mean().alias("both_present_frac"),
])
print("=== Null report (fraction) ===")
print(null_report)

# ===========================================
# 4) Tính contain trên tập both_present
# ===========================================
both_df = item_df.filter(mask_both)

# Thêm 3 cột: recall(A|B), precision(B|A), F1
res = both_df.with_columns([
    pl.struct(["description", "description_new"]).map_elements(
        lambda row: contain_pair(row["description"], row["description_new"], level=LEVEL, n=N)[0]
    ).alias("contain_desc_in_descnew"),  # recall: A|B

    pl.struct(["description", "description_new"]).map_elements(
        lambda row: contain_pair(row["description"], row["description_new"], level=LEVEL, n=N)[1]
    ).alias("contain_descnew_in_desc"),  # precision: B|A

    pl.struct(["description", "description_new"]).map_elements(
        lambda row: contain_pair(row["description"], row["description_new"], level=LEVEL, n=N)[2]
    ).alias("contain_f1"),
])

# Tóm tắt nhanh
summary = res.select([
    pl.len().alias("n_both_present"),
    pl.col("contain_desc_in_descnew").mean().alias("mean_contain(A|B)"),
    pl.col("contain_descnew_in_desc").mean().alias("mean_contain(B|A)"),
    pl.col("contain_f1").mean().alias("mean_contain_F1"),
    pl.col("contain_desc_in_descnew").quantile(0.5).alias("median_contain(A|B)"),
    pl.col("contain_desc_in_descnew").quantile(0.9).alias("p90_contain(A|B)"),
])
print("=== Containment summary (LEVEL={}, N={}) ===".format(LEVEL, N))
print(summary)

# (Tuỳ chọn) xem vài dòng có F1 cao để sanity-check
print(res.select(["description", "description_new", "contain_desc_in_descnew", "contain_descnew_in_desc", "contain_f1"])
        .sort("contain_f1", descending=True)
        .head(10))
# Out:
# === Null report (fraction) ===
# shape: (1, 4)
# ┌────────────────┬─────────────────────┬─────────────────────────┬───────────────────┐
# │ both_null_frac ┆ desc_null_only_frac ┆ desc_new_null_only_frac ┆ both_present_frac │
# │ ---            ┆ ---                 ┆ ---                     ┆ ---               │
# │ f64            ┆ f64                 ┆ f64                     ┆ f64               │
# ╞════════════════╪═════════════════════╪═════════════════════════╪═══════════════════╡
# │ 0.0            ┆ 0.0                 ┆ 0.183485                ┆ 0.816515          │
# └────────────────┴─────────────────────┴─────────────────────────┴───────────────────┘
# === Containment summary (LEVEL=word, N=2) ===
# shape: (1, 6)
# ┌────────────────┬───────────────────┬───────────────────┬─────────────────┬─────────────────────┬──────────────────┐
# │ n_both_present ┆ mean_contain(A|B) ┆ mean_contain(B|A) ┆ mean_contain_F1 ┆ median_contain(A|B) ┆ p90_contain(A|B) │
# │ ---            ┆ ---               ┆ ---               ┆ ---             ┆ ---                 ┆ ---              │
# │ u32            ┆ f64               ┆ f64               ┆ f64             ┆ f64                 ┆ f64              │
# ╞════════════════╪═══════════════════╪═══════════════════╪═════════════════╪═════════════════════╪══════════════════╡
# │ 22317          ┆ 0.644364          ┆ 0.559282          ┆ 0.581978        ┆ 0.795139            ┆ 1.0              │
# └────────────────┴───────────────────┴───────────────────┴─────────────────┴─────────────────────┴──────────────────┘
# shape: (10, 5)
# ┌────────────────┬─────────────────┬─────────────────────────┬─────────────────────────┬────────────┐
# │ description    ┆ description_new ┆ contain_desc_in_descnew ┆ contain_descnew_in_desc ┆ contain_f1 │
# │ ---            ┆ ---             ┆ ---                     ┆ ---                     ┆ ---        │
# │ str            ┆ str             ┆ f64                     ┆ f64                     ┆ f64        │
# ╞════════════════╪═════════════════╪═════════════════════════╪═════════════════════════╪════════════╡
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# │ Không xác định ┆ Không xác định  ┆ 1.0                     ┆ 1.0                     ┆ 1.0        │
# └────────────────┴─────────────────┴─────────────────────────┴─────────────────────────┴────────────┘

# %% [markdown]
# Ở trên chưa bỏ Không xác định -> sai

# %%
import polars as pl
import re

# ===== 1) Cấu hình =====
LEVEL = "word"   # "word" hoặc "char"
N = 2            # n-gram: 1/2/3... ; ví dụ word-bigram = 2

# Các giá trị được coi là "thiếu"
PLACEHOLDERS = [
    "", "-", "--",
    "không xác định", "khong xac dinh", "không xac dinh",
    "không rõ", "chưa rõ", "không có thông tin",
    "n/a", "na", "none", "null", "unk", "unknown"
]

# ===== 2) Hàm tiện ích =====
def tokenize(s: str):
    return re.findall(r"\w+", s.lower())

def ngrams(tokens, n=2):
    if len(tokens) < n: 
        return []
    return [" ".join(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

def build_set(s: str, level="word", n=2):
    if not s:
        return set()
    if level == "char":
        s_norm = re.sub(r"\s+", " ", s.lower()).strip()
        if len(s_norm) < n:
            return set()
        return set(s_norm[i:i+n] for i in range(len(s_norm)-n+1))
    else:
        toks = tokenize(s)
        return set(toks) if n == 1 else set(ngrams(toks, n))

def contain_ratio_sets(A_set: set, B_set: set) -> float:
    return 0.0 if not A_set else len(A_set & B_set) / len(A_set)

def contain_pair(a: str, b: str, level="word", n=2):
    A = build_set(a, level=level, n=n)
    B = build_set(b, level=level, n=n)
    r = contain_ratio_sets(A, B)  # Contain(A|B)
    p = contain_ratio_sets(B, A)  # Contain(B|A)
    f1 = 0.0 if (p + r) == 0 else 2 * p * r / (p + r)
    return (r, p, f1, len(A), len(B))

# Chuẩn hoá text để so đối chiếu placeholder
def norm_expr(colname: str):
    return (
        pl.col(colname).cast(pl.Utf8)
        .str.to_lowercase()
        .str.replace_all(r"\s+", " ")
        .str.strip_chars(" .,-:;—–_/\\|\"'`")  # bỏ dấu câu ở đầu/cuối
        .str.strip_chars()                     # bỏ khoảng trắng thừa
    )

def is_missing(colname: str):
    n = norm_expr(colname)
    return pl.col(colname).is_null() | n.is_in(PLACEHOLDERS)

# ===== 3) Mask both_present với định nghĩa "thiếu" mới =====
miss_desc     = is_missing("description")
miss_desc_new = is_missing("description_new")
both_present  = (~miss_desc) & (~miss_desc_new)

# Báo cáo thiếu dữ liệu (fraction)
null_report = item_df.select([
    (miss_desc & miss_desc_new).mean().alias("both_null_frac"),
    (miss_desc & (~miss_desc_new)).mean().alias("desc_null_only_frac"),
    ((~miss_desc) & miss_desc_new).mean().alias("desc_new_null_only_frac"),
    both_present.mean().alias("both_present_frac"),
])
print("=== Null report (fraction) — placeholders treated as null ===")
print(null_report)

# ===== 4) Tính containment chỉ trên both_present =====
both_df = item_df.filter(both_present)

res = both_df.with_columns([
    pl.struct(["description", "description_new"]).map_elements(
        lambda row: contain_pair(row["description"], row["description_new"], level=LEVEL, n=N)[0]
    ).alias("contain_desc_in_descnew"),   # recall: A|B

    pl.struct(["description", "description_new"]).map_elements(
        lambda row: contain_pair(row["description"], row["description_new"], level=LEVEL, n=N)[1]
    ).alias("contain_descnew_in_desc"),   # precision: B|A

    pl.struct(["description", "description_new"]).map_elements(
        lambda row: contain_pair(row["description"], row["description_new"], level=LEVEL, n=N)[2]
    ).alias("contain_f1"),
])

summary = res.select([
    pl.len().alias("n_both_present"),
    pl.col("contain_desc_in_descnew").mean().alias("mean_contain(A|B)"),
    pl.col("contain_descnew_in_desc").mean().alias("mean_contain(B|A)"),
    pl.col("contain_f1").mean().alias("mean_contain_F1"),
    pl.col("contain_desc_in_descnew").quantile(0.5).alias("median_contain(A|B)"),
    pl.col("contain_desc_in_descnew").quantile(0.9).alias("p90_contain(A|B)"),
])
print(f"=== Containment summary (LEVEL={LEVEL}, N={N}) — after placeholder filtering ===")
print(summary)

# (Tuỳ chọn) kiểm tra vài dòng F1 cao
print(res.select(["description", "description_new", "contain_desc_in_descnew", "contain_descnew_in_desc", "contain_f1"])
        .sort("contain_f1", descending=True)
        .head(10))
# Out:
# === Null report (fraction) — placeholders treated as null ===
# shape: (1, 4)
# ┌────────────────┬─────────────────────┬─────────────────────────┬───────────────────┐
# │ both_null_frac ┆ desc_null_only_frac ┆ desc_new_null_only_frac ┆ both_present_frac │
# │ ---            ┆ ---                 ┆ ---                     ┆ ---               │
# │ f64            ┆ f64                 ┆ f64                     ┆ f64               │
# ╞════════════════╪═════════════════════╪═════════════════════════╪═══════════════════╡
# │ 0.564723       ┆ 0.116859            ┆ 0.087626                ┆ 0.230792          │
# └────────────────┴─────────────────────┴─────────────────────────┴───────────────────┘
# === Containment summary (LEVEL=word, N=2) — after placeholder filtering ===
# shape: (1, 6)
# ┌────────────────┬───────────────────┬───────────────────┬─────────────────┬─────────────────────┬──────────────────┐
# │ n_both_present ┆ mean_contain(A|B) ┆ mean_contain(B|A) ┆ mean_contain_F1 ┆ median_contain(A|B) ┆ p90_contain(A|B) │
# │ ---            ┆ ---               ┆ ---               ┆ ---             ┆ ---                 ┆ ---              │
# │ u32            ┆ f64               ┆ f64               ┆ f64             ┆ f64                 ┆ f64              │
# ╞════════════════╪═══════════════════╪═══════════════════╪═════════════════╪═════════════════════╪══════════════════╡
# │ 6308           ┆ 0.623212          ┆ 0.324248          ┆ 0.40546         ┆ 0.62                ┆ 0.807292         │
# └────────────────┴───────────────────┴───────────────────┴─────────────────┴─────────────────────┴──────────────────┘
# shape: (10, 5)
# ┌──────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────┬─────────────────────────┬─────────────────────────┬────────────┐
# │ description                                                      ┆ description_new                                                  ┆ contain_desc_in_descnew ┆ contain_descnew_in_desc ┆ contain_f1 │
# │ ---                                                              ┆ ---                                                              ┆ ---                     ┆ ---                     ┆ ---        │
# │ str                                                              ┆ str                                                              ┆ f64                     ┆ f64                     ┆ f64        │
# ╞══════════════════════════════════════════════════════════════════╪══════════════════════════════════════════════════════════════════╪═════════════════════════╪═════════════════════════╪════════════╡
# │ Chất liệu nhựa an toàn - Xe đẩy quầy thức ăn 33pcs TOYCITY được  ┆ Chi tiết sản phẩm                     Tên sản phẩm: Xe đẩy quầy  ┆ 0.966361                ┆ 0.940476                ┆ 0.953243   │
# │ làm từ chất liệu nhựa cao cấp, rất nhẹ, có độ bền cao .Với chất  ┆ thức ăn 33pcs TOYCITY         Thương hiệu: Toycity         Xuất  ┆                         ┆                         ┆            │
# │ liệu nhựa cao cấp, tuyệt đối an toàn cho sức khỏe của bé và thân ┆ xứ: Trung Quốc         Chi tiết sản phẩm: Nhựa HIPS              ┆                         ┆                         ┆            │
# │ thiện với môi trường. - Bề mặt các chi tiết cua bộ đồ chơi nhẵn  ┆ Trọng lượng: 0.83 kg         Kích thước: Dài x Rộng x Cao:       ┆                         ┆                         ┆            │
# │ mịn, không có các vi ba sắc nhọn không làm trầy xước làn da nhạy ┆ 24x20x10(cm)                        Xe đẩy quầy thức ăn 33pcs    ┆                         ┆                         ┆            │
# │ cảm của bé khi tiếp xúc, giúp mẹ an tâm mỗi khi bé chơi. Phát    ┆ TOYCITY là xe đẩy quầy thức ăn dành cho bé từ 3 tuổi của thương  ┆                         ┆                         ┆            │
# │ huy trí tưởng tượng - Bộ đồ chơi quầy thức ăn gồm những chai gia ┆ hiệu Toycity xuất xứ Trung Quốc. Được làm từ chất liệu nhựa cao  ┆                         ┆                         ┆            │
# │ vị, menu, đồ ăn...  có màu sắc nổi bật, bắt mắt tạo cho bé cảm   ┆ cấp, sản phẩm tuyệt đối an toàn cho sức khỏe của bé.             ┆                         ┆                         ┆            │
# │ giác thích thú và hứng khởi hơn khi chơi, đồng thời kích thích   ┆ Chất liệu nhựa an toàn            Xe đẩy quầy thức ăn 33pcs      ┆                         ┆                         ┆            │
# │ thị giác bé phát triển. Mẹ có thể hướng dẫn cho bé cách nhận     ┆ TOYCITY được làm từ chất liệu nhựa cao cấp, rất nhẹ, có độ bền   ┆                         ┆                         ┆            │
# │ biết màu sắc từ các dụng và hỏi lại giúp tăng khả năng ghi nhớ   ┆ cao. Với chất liệu nhựa cao cấp, sản phẩm tuyệt đối an toàn cho  ┆                         ┆                         ┆            │
# │ của bé. Bộ đồ chơi mang tính chất hướng nghiệp - Đây là một trò  ┆ sức khỏe của bé và thân thiện với môi trường. Bề mặt các chi     ┆                         ┆                         ┆            │
# │ chơi thật sự bổ ích giúp bé hiểu thêm và yêu thích công việc bán ┆ tiết của bộ đồ chơi nhẵn mịn, không có các vi ba sắc nhọn không  ┆                         ┆                         ┆            │
# │ đồ ăn cũng là những bước khởi đầu trong việc định hướng nghề     ┆ làm trầy xước làn da nhạy cảm của bé khi tiếp xúc, giúp mẹ an    ┆                         ┆                         ┆            │
# │ nghiệp tương lai cho bé. Bé có thể hình dung được công việc nấu  ┆ tâm mỗi khi bé chơi.            Phát huy trí tưởng tượng         ┆                         ┆                         ┆            │
# │ ăn và có thể ý thức để phụ giúp bố mẹ trong việc lấy dụng cụ nấu ┆ Bộ đồ chơi quầy thức ăn gồm những chai gia vị, menu, đồ ăn... có ┆                         ┆                         ┆            │
# │ bếp hay gia vị cho bố mẹ. - Không chỉ vậy bộ đồ chơi quầy thức   ┆ màu sắc nổi bật, bắt mắt tạo cho bé cảm giác thích thú và hứng   ┆                         ┆                         ┆            │
# │ ăn được  đựng trong hộp xe đẩy  gọn nhẹ và xinh xắn, giúp bé có  ┆ khởi hơn khi chơi, đồng thời kích thích thị giác bé phát triển.  ┆                         ┆                         ┆            │
# │ ý thức xếp gọn đồ sau khi chơi, rèn tính ngăn nắp cho bé ngay từ ┆ Mẹ có thể hướng dẫn cho bé cách nhận biết màu sắc từ các dụng cụ ┆                         ┆                         ┆            │
# │ khi còn nhỏ. Và bé dễ dàng mang theo khi ra ngoài đi chơi. - Bộ  ┆ và hỏi lại giúp tăng khả năng ghi nhớ của bé.            Bộ đồ   ┆                         ┆                         ┆            │
# │ sản phẩm có nhãn dán kèm theo để bé trang trí cho hộp đồ chơi    ┆ chơi mang tính chất hướng nghiệp           Đây là một trò chơi   ┆                         ┆                         ┆            │
# │ của mình thêm phần sinh động hơn. THÔNG TIN SẢN PHẨM - Tên sản   ┆ thật sự bổ ích giúp bé hiểu thêm và yêu thích công việc bán đồ   ┆                         ┆                         ┆            │
# │ phẩm : Xe đẩy quầy thức ăn 33pcs TOYCITY - Thương hiệu : Toycity ┆ ăn, đồng thời cũng là những bước khởi đầu trong việc định hướng  ┆                         ┆                         ┆            │
# │ - Xuất Xứ:  Trung Quốc - Chi tiết sản phẩm : Nhựa HIPS - Trọng   ┆ nghề nghiệp tương lai cho bé. Bé có thể hình dung được công việc ┆                         ┆                         ┆            │
# │ lượng :0.83 kg - Kích thước: Dài x Rộng X Cao: 24x20x10(cm)      ┆ nấu ăn và ý thức để phụ giúp bố mẹ trong việc lấy dụng cụ nấu    ┆                         ┆                         ┆            │
# │ HƯỚNG DẪN BẢO QUẢN - Vệ sinh sản phẩm trước và sau khi sử dụng.  ┆ bếp hay gia vị cho bố mẹ. Không chỉ vậy, bộ đồ chơi quầy thức ăn ┆                         ┆                         ┆            │
# │ - Cảnh báo : không sử dụng sản phẩm cho bé dưới 3 tuổi.          ┆ được đựng trong hộp xe đẩy gọn nhẹ và xinh xắn, giúp bé có ý     ┆                         ┆                         ┆            │
# │                                                                  ┆ thức xếp gọn đồ sau khi chơi, rèn tính ngăn nắp cho bé ngay từ   ┆                         ┆                         ┆            │
# │                                                                  ┆ khi còn nhỏ, và bé dễ dàng mang theo khi ra ngoài đi chơi. Bộ    ┆                         ┆                         ┆            │
# │                                                                  ┆ sản phẩm có nhãn dán kèm theo để bé trang trí cho hộp đồ chơi    ┆                         ┆                         ┆            │
# │                                                                  ┆ của mình thêm phần sinh động hơn.               Hướng dẫn bảo    ┆                         ┆                         ┆            │
# │                                                                  ┆ quản               Vệ sinh s…                                    ┆                         ┆                         ┆            │
# │ Chất liệu nhựa an toàn Xẻng nhựa RFD276556 được làm từ chất liệu ┆ Chi tiết sản phẩm                     Tên sản phẩm: Xẻng nhựa    ┆ 0.976331                ┆ 0.926966                ┆ 0.951009   │
# │ nhựa an toàn, không độc hại, không gây ảnh hưởng đến sức khỏe    ┆ RFD276556         Thương hiệu: YUANHONG TOYS         Xuất xứ:    ┆                         ┆                         ┆            │
# │ của bé. Chất liệu nhựa cứng cáp được sơn phủ sáng bóng đem đến   ┆ Trung Quốc         Trọng lượng: 0.1 kg         Nguyên liệu: Nhựa ┆                         ┆                         ┆            │
# │ độ bền đẹp theo thời gian sử dụng. - Bề mặt các chi tiết trơn    ┆ PP         Dành cho: Bé 3 tuổi trở lên         Kích thước chiều  ┆                         ┆                         ┆            │
# │ tru láng mịn không có các cạnh sắc nhọn, do đó không làm trầy    ┆ dài: 50cm                        Xẻng nhựa RFD276556 là đồ chơi  ┆                         ┆                         ┆            │
# │ xước làn da nhạy cảm của bé khi tiếp xúc, bố mẹ có thể hoàn toàn ┆ dành cho bé 3 tuổi trở lên của thương hiệu YUANHONG TOYS xuất xứ ┆                         ┆                         ┆            │
# │ an tâm khi bé chơi. Màu sắc nổi bật, thiết kế bắt mắt - Chi tiết ┆ từ Trung Quốc. Sản phẩm được làm từ chất liệu nhựa an toàn,      ┆                         ┆                         ┆            │
# │ được thiết kế với kiểu dáng vô cùng dễ thương chắc chắn sẽ thu   ┆ không độc hại, đảm bảo sức khỏe cho bé.                          ┆                         ┆                         ┆            │
# │ hút sự chú ý của các bé ngay từ cái nhìn đầu tiên. Không chỉ vậy ┆ Chất liệu nhựa an toàn            Xẻng nhựa RFD276556 được làm   ┆                         ┆                         ┆            │
# │ đồ chơi có màu sắc sinh động, bắt mắt sẽ làm bé thích thú và     ┆ từ chất liệu nhựa an toàn, không độc hại, không gây ảnh hưởng    ┆                         ┆                         ┆            │
# │ hứng khởi khi chơi. - Kích thước vừa tay bé, giúp bé dễ dàng cầm ┆ đến sức khỏe của bé. Chất liệu nhựa cứng cáp được sơn phủ sáng   ┆                         ┆                         ┆            │
# │ nắm để thực hiện các thao tác khi chơi. Giúp bé phát triển các   ┆ bóng đem đến độ bền đẹp theo thời gian sử dụng. Bề mặt các chi   ┆                         ┆                         ┆            │
# │ kỹ năng - Thông qua các thao tác: đào cát, xúc cát các kỹ năng   ┆ tiết trơn tru láng mịn không có các cạnh sắc nhọn, do đó không   ┆                         ┆                         ┆            │
# │ của bé sẽ dần được phát triển và hoàn thiện hơn. Bên cạnh đó,    ┆ làm trầy xước làn da nhạy cảm của bé khi tiếp xúc, bố mẹ có thể  ┆                         ┆                         ┆            │
# │ việc xúc cát cũng như vui chơi bên ngoài giúp bé tăng khả năng   ┆ hoàn toàn an tâm khi bé chơi.               Màu sắc nổi bật,     ┆                         ┆                         ┆            │
# │ vận động để cơ thể khỏe mạnh và nhanh nhẹn hơn. - Mỗi dụng cụ    ┆ thiết kế bắt mắt            Chi tiết được thiết kế với kiểu dáng ┆                         ┆                         ┆            │
# │ của bộ đồ chơi có màu sắc và công dụng khác nhau, mẹ có thể      ┆ vô cùng dễ thương chắc chắn sẽ thu hút sự chú ý của các bé ngay  ┆                         ┆                         ┆            │
# │ hướng dẫn bé nhận biết và phân biệt màu sắc, cũng như học cách   ┆ từ cái nhìn đầu tiên. Không chỉ vậy đồ chơi có màu sắc sinh      ┆                         ┆                         ┆            │
# │ sử dụng dựa trên công dụng của từng dụng cụ và sau đó hỏi lại,   ┆ động, bắt mắt sẽ làm bé thích thú và hứng khởi khi chơi. Kích    ┆                         ┆                         ┆            │
# │ từ đó giúp tăng khả năng học hỏi và ghi nhớ của bé. - Với đồ     ┆ thước vừa tay bé, giúp bé dễ dàng cầm nắm để thực hiện các thao  ┆                         ┆                         ┆            │
# │ chơi này bé có thể vui chơi cùng bố mẹ hay bạn bè từ đó tăng khả ┆ tác khi chơi.               Giúp bé phát triển các kỹ năng       ┆                         ┆                         ┆            │
# │ năng giao tiếp và gắn kết tình cảm. THÔNG TIN SẢN PHẨM - Thương  ┆ Thông qua các thao tác: đào cát, xúc cát, các kỹ năng của bé sẽ  ┆                         ┆                         ┆            │
# │ hiệu: YUANHONG TOYS - Xuất xứ: Trung Quốc - Trọng lượng : 0.1 kg ┆ dần được phát triển và hoàn thiện hơn. Bên cạnh đó, việc xúc cát ┆                         ┆                         ┆            │
# │ - Nguyên liệu: Nhựa PP - Dành cho bé 3 tuổi trở lên - Kích thước ┆ cũng như vui chơi bên ngoài giúp bé tăng khả năng vận động để cơ ┆                         ┆                         ┆            │
# │ chiều dài : 50cm HƯỚNG DẪN BẢO QUẢN - Vệ sinh trước và sau sử    ┆ thể khỏe mạnh và nhanh nhẹn hơn. Mỗi dụng cụ của bộ đồ chơi có   ┆                         ┆                         ┆            │
# │ dụng, tránh va đập mạnh. - Tránh xa nguồn nhiệt. Cảnh báo :      ┆ màu sắc và công dụng khác nhau, mẹ có thể hướng dẫn bé nhận biết ┆                         ┆                         ┆            │
# │ + Sản phẩm có chi tiết nhỏ, không phù hợp với trẻ em dưới 3      ┆ và phân biệt màu sắc, cũng như học cách sử dụng dựa trên công    ┆                         ┆                         ┆            │
# │ tuổi. + Sử dụng dưới sự giám sát của người lớn.                  ┆ dụng của từng dụng cụ và sau đó hỏi lại, từ đó giúp tăng khả     ┆                         ┆                         ┆            │
# │                                                                  ┆ năng học hỏi và ghi nhớ của bé. Với đồ chơi này bé có thể vui    ┆                         ┆                         ┆            │
# │                                                                  ┆ chơi cùng bố mẹ hay bạn bè từ đó tăng khả năng giao tiếp và gắn  ┆                         ┆                         ┆            │
# │                                                                  ┆ kết tình cảm.               Hướng dẫn bảo quản               Vệ  ┆                         ┆                         ┆            │
# │                                                                  ┆ sinh trước và sau sử dụng, tránh va đập mạ…                      ┆                         ┆                         ┆            │
# │ Chất liệu bền đẹp, an toàn - Áo phao bơi Z802007-T được làm từ   ┆ Chi tiết sản phẩm                     Tên sản phẩm: Áo phao bơi  ┆ 0.982323                ┆ 0.900463                ┆ 0.939614   │
# │ chất liệu cao cấp, đảm bảo đạt tiêu chuẩn an toàn với độ đàn hồi ┆ Z802007-T         Thương hiệu: Mesuca         Xuất xứ: Trung     ┆                         ┆                         ┆            │
# │ rất tốt, ít bị biến dạng cùng bề mặt mềm mại, láng mịn, bảo vệ   ┆ Quốc         Kích thước: 40x35x25(cm)         Dành cho bé khoảng ┆                         ┆                         ┆            │
# │ làn da bé và không gây kích ứng cho da, giúp bé thoải mái khi    ┆ từ: 12-16kg         Phù hợp cho bé từ: 3 tuổi trở lên            ┆                         ┆                         ┆            │
# │ vui chơi. Thiết kế thông minh - Áo phao bơi Z802007-T sử dụng    ┆ **Áo phao bơi Z802007-T** là áo phao bơi dành cho bé từ 3 tuổi   ┆                         ┆                         ┆            │
# │ van 1 chiều thông minh nên hơi bên trong rất khó thoát ra ngoài. ┆ trở lên của thương hiệu Mesuca đến từ Trung Quốc. Sản phẩm nổi   ┆                         ┆                         ┆            │
# │ Áo được chia làm 3 phần với 3 van độc lập, phân cách bằng các    ┆ bật với chất liệu bền đẹp, an toàn.                              ┆                         ┆                         ┆            │
# │ đường hàn, giúp bố mẹ dễ dàng và nhanh chóng bơm từng phần, có   ┆ **Chất liệu bền đẹp, an toàn**           Áo phao bơi Z802007-T   ┆                         ┆                         ┆            │
# │ thể sử dụng bơm hơi bằng tay tiện lợi. Hai lần khóa cài và van   ┆ được làm từ chất liệu cao cấp, đảm bảo đạt tiêu chuẩn an toàn    ┆                         ┆                         ┆            │
# │ khí 1 chiều chắc chắn - Thiết kế cổ và lỗ khoác tay áo rộng rãi  ┆ với độ đàn hồi rất tốt, ít bị biến dạng cùng bề mặt mềm mại,     ┆                         ┆                         ┆            │
# │ tạo sự thoải mái khi vận động. - Phần móc khóa có dây đai có thể ┆ láng mịn, bảo vệ làn da bé và không gây kích ứng cho da, giúp bé ┆                         ┆                         ┆            │
# │ điều chỉnh độ dài ngắn để phù hợp với kích cỡ người trẻ. Hai móc ┆ thoải mái khi vui chơi.             **Thiết kế thông minh**      ┆                         ┆                         ┆            │
# │ khóa cài bản to chắc chắn đảm bảo an toàn tuyệt đối cho trẻ khi  ┆ Áo phao bơi Z802007-T sử dụng van 1 chiều thông minh nên hơi bên ┆                         ┆                         ┆            │
# │ sử dụng giúp phao không tuột khỏi người bé khi đang bơi. Màu sắc ┆ trong rất khó thoát ra ngoài. Áo được chia làm 3 phần với 3 van  ┆                         ┆                         ┆            │
# │ nổi bật - Kích thước nhỏ gọn, kiểu dáng áo phao thời trang được  ┆ độc lập, phân cách bằng các đường hàn, giúp bố mẹ dễ dàng và     ┆                         ┆                         ┆            │
# │ thiết kế xinh xắn với màu vàng tươi sáng, rực rỡ cùng họa tiết   ┆ nhanh chóng bơm từng phần, có thể sử dụng bơm hơi bằng tay tiện  ┆                         ┆                         ┆            │
# │ ngộ nghĩnh, đầy ấn tượng cho bé thêm phần nổi bật khi đi tham    ┆ lợi.            **Hai lần khóa cài và van khí 1 chiều chắc       ┆                         ┆                         ┆            │
# │ quan trên thuyền, khi tắm biển hay ở bể bơi, công viên nước... - ┆ chắn**           Thiết kế cổ và lỗ khoác tay áo rộng rãi tạo sự  ┆                         ┆                         ┆            │
# │ Sản phẩm sẽ là món quà vô cùng ý nghĩa và lý thú cho những đợt   ┆ thoải mái khi vận động. Phần móc khóa có dây đai có thể điều     ┆                         ┆                         ┆            │
# │ du lịch sắp tới của bé cùng cả nhà. THÔNG TIN SẢN PHẨM - Tên sản ┆ chỉnh độ dài ngắn để phù hợp với kích cỡ người trẻ. Hai móc khóa ┆                         ┆                         ┆            │
# │ phẩm : Áo phao bơi Z802007-T - Thương hiệu: Mesuca - Xuất xứ:    ┆ cài bản to chắc chắn đảm bảo an toàn tuyệt đối cho trẻ khi sử    ┆                         ┆                         ┆            │
# │ Trung Quốc - Chất liệu: Nhựa PVC - Kích thước :40x35x25(cm) -    ┆ dụng giúp phao không tuột khỏi người bé khi đang bơi.            ┆                         ┆                         ┆            │
# │ Dành cho bé khoảng từ 12-16kg - Phù hợp cho bé từ: 3 tuổi trở    ┆ **Màu sắc nổi bật**           Kích thước nhỏ gọn, kiểu dáng áo   ┆                         ┆                         ┆            │
# │ lên. HƯỚNG DẪN SỬ DỤNG - Dùng bơm chuyên dụng để thổi không khí  ┆ phao thời trang được thiết kế xinh xắn với màu vàng tươi sáng,   ┆                         ┆                         ┆            │
# │ vào cho sản phẩm căng lên. Hoặc bố mẹ có thể bóp tay ở phần van  ┆ rực rỡ cùng họa tiết ngộ nghĩnh, đầy ấn tượng cho bé thêm phần   ┆                         ┆                         ┆            │
# │ 1 chiều và thổi bằng miệng. Sau khi thổi không khí vào ba mẹ đậy ┆ nổi bật khi đi tham quan trên thuyền, khi tắm biển hay ở bể bơi, ┆                         ┆                         ┆            │
# │ kín phần van lại và ấn phần van chìm và bên trong lật đật để van ┆ công viên nước. Sản phẩm sẽ là món quà vô cùng ý nghĩa và lý thú ┆                         ┆                         ┆            │
# │ không bị vướng bên ngoài. - Bố mẹ dùng 1 tay bóp phần van 1      ┆ cho những đợt du lịch sắp tới của bé cùng cả nhà.                ┆                         ┆                         ┆            │
# │ chiều, đồng thời dùng tay còn lại ấn chặt lật đật để xả hơi ra   ┆ Hướng dẫn sử dụng               Dùng bơm chuyên dụng để thổi     ┆                         ┆                         ┆            │
# │ ngoài. - Cho bé đeo dùng bơi dưới nước. - Sử dụng dưới sự giám   ┆ không khí vào cho sản phẩm căng lên. Hoặc bố mẹ có thể bóp tay ở ┆                         ┆                         ┆            │
# │ sát của người lớn trong lúc bơi. HƯỚNG DẪN BẢO QUẢN - Vệ sinh    ┆ phần van 1 chiều và thổi bằng miệng. Sau khi thổi không khí vào  ┆                         ┆                         ┆            │
# │ trước và sau sử dụng, tránh va đập …                             ┆ ba mẹ đậy kín phần van l…                                        ┆                         ┆                         ┆            │
# │ Chất liệu bền đẹp, an toàn - Áo phao bơi Minion 50*45cm          ┆ Chi tiết sản phẩm                     Tên sản phẩm: Áo phao bơi  ┆ 0.967822                ┆ 0.890661                ┆ 0.927639   │
# │ XMA5045 được làm từ chất liệu cao cấp, đảm bảo đạt tiêu chuẩn an ┆ Minion 50*45cm XMA5045         Thương hiệu: Mesuca         Xuất  ┆                         ┆                         ┆            │
# │ toàn với độ đàn hồi rất tốt, ít bị biến dạng cùng bề mặt mềm     ┆ xứ: Trung Quốc         Chất liệu: Nhựa PVC         Trọng lượng:  ┆                         ┆                         ┆            │
# │ mại, láng mịn, bảo vệ làn da bé và không gây kích ứng cho da,    ┆ 0.27 kg         Kích thước: 50x45(cm)         Dành cho bé khoảng ┆                         ┆                         ┆            │
# │ giúp bé thoải mái khi vui chơi. Thiết kế thông minh - Áo phao    ┆ từ: 12-16kg         Phù hợp cho bé từ: 3 tuổi trở lên            ┆                         ┆                         ┆            │
# │ bơi Minion 50*45cm XMA5045 sử dụng van 1 chiều thông minh nên    ┆ Áo phao bơi Minion 50*45cm XMA5045 là áo phao bơi dành cho trẻ   ┆                         ┆                         ┆            │
# │ hơi bên trong rất khó thoát ra ngoài. Áo được chia làm 3 phần    ┆ từ 3 tuổi trở lên của thương hiệu Mesuca xuất xứ từ Trung Quốc.  ┆                         ┆                         ┆            │
# │ với 3 van độc lập, phân cách bằng các đường hàn, giúp bố mẹ dễ   ┆ Sản phẩm nổi bật với chất liệu cao cấp, độ đàn hồi tốt, giúp bảo ┆                         ┆                         ┆            │
# │ dàng và nhanh chóng bơm từng phần, có thể sử dụng bơm hơi bằng   ┆ vệ làn da bé và không gây kích ứng khi vui chơi.                 ┆                         ┆                         ┆            │
# │ tay tiện lợi. Hai lần khóa cài và van khí 1 chiều chắc chắn -    ┆ Chất liệu bền đẹp, an toàn            Áo phao bơi Minion 50*45cm ┆                         ┆                         ┆            │
# │ Thiết kế cổ và lỗ khoác tay áo rộng rãi tạo sự thoải mái khi vận ┆ XMA5045 được làm từ chất liệu cao cấp, đảm bảo đạt tiêu chuẩn an ┆                         ┆                         ┆            │
# │ động. - Phần móc khóa có dây đai có thể điều chỉnh độ dài ngắn   ┆ toàn với độ đàn hồi rất tốt, ít bị biến dạng cùng bề mặt mềm     ┆                         ┆                         ┆            │
# │ để phù hợp với kích cỡ người trẻ. Hai móc khóa cài bản to chắc   ┆ mại, láng mịn, bảo vệ làn da bé và không gây kích ứng cho da,    ┆                         ┆                         ┆            │
# │ chắn đảm bảo an toàn tuyệt đối cho trẻ khi sử dụng giúp phao     ┆ giúp bé thoải mái khi vui chơi.               Thiết kế thông     ┆                         ┆                         ┆            │
# │ không tuột khỏi người bé khi đang bơi. Màu sắc nổi bật - Kích    ┆ minh      Áo phao sử dụng van 1 chiều thông minh nên hơi bên     ┆                         ┆                         ┆            │
# │ thước nhỏ gọn, kiểu dáng áo phao thời trang được thiết kế xinh   ┆ trong rất khó thoát ra ngoài. Áo được chia làm 3 phần với 3 van  ┆                         ┆                         ┆            │
# │ xắn với màu vàng tươi sáng, rực rỡ cùng họa tiết Minion ngộ      ┆ độc lập, phân cách bằng các đường hàn, giúp bố mẹ dễ dàng và     ┆                         ┆                         ┆            │
# │ nghĩnh, đầy ấn tượng cho bé thêm phần nổi bật khi đi tham quan   ┆ nhanh chóng bơm từng phần, có thể sử dụng bơm hơi bằng tay tiện  ┆                         ┆                         ┆            │
# │ trên thuyền, khi tắm biển hay ở bể bơi, công viên nước... - Sản  ┆ lợi.               Hai lần khóa cài và van khí 1 chiều chắc chắn ┆                         ┆                         ┆            │
# │ phẩm sẽ là món quà vô cùng ý nghĩa và lý thú cho những đợt du    ┆ Thiết kế cổ và lỗ khoác tay áo rộng rãi tạo sự thoải mái khi vận ┆                         ┆                         ┆            │
# │ lịch sắp tới của bé cùng cả nhà. THÔNG TIN SẢN PHẨM - Tên sản    ┆ động. Phần móc khóa có dây đai điều chỉnh độ dài ngắn tùy theo   ┆                         ┆                         ┆            │
# │ phẩm : Áo phao bơi Minion 50*45cm XMA5045 - Thương hiệu: Mesuca  ┆ kích cỡ người trẻ. Hai móc khóa cài bản to chắc chắn đảm bảo an  ┆                         ┆                         ┆            │
# │ - Xuất xứ: Trung Quốc - Chất liệu: Nhựa PVC - Trọng lượng :0.27  ┆ toàn tuyệt đối cho trẻ khi sử dụng, giúp phao không tuột khỏi    ┆                         ┆                         ┆            │
# │ kg - Kích thước : 50x45(cm) - Dành cho bé khoảng từ 12-16kg -    ┆ người bé khi đang bơi.               Màu sắc nổi bật      Kích   ┆                         ┆                         ┆            │
# │ Phù hợp cho bé từ: 3 tuổi trở lên. HƯỚNG DẪN SỬ DỤNG - Dùng bơm  ┆ thước nhỏ gọn, kiểu dáng áo phao thời trang được thiết kế xinh   ┆                         ┆                         ┆            │
# │ chuyên dụng để thổi không khí vào cho sản phẩm căng lên. Hoặc bố ┆ xắn với màu vàng tươi sáng, rực rỡ cùng họa tiết Minion ngộ      ┆                         ┆                         ┆            │
# │ mẹ có thể bóp tay ở phần van 1 chiều và thổi bằng miệng. Sau khi ┆ nghĩnh, đầy ấn tượng cho bé thêm phần nổi bật khi đi tham quan   ┆                         ┆                         ┆            │
# │ thổi không khí vào ba mẹ đậy kín phần van lại và ấn phần van     ┆ trên thuyền, khi tắm biển hay ở bể bơi, công viên nước. Sản phẩm ┆                         ┆                         ┆            │
# │ chìm và bên trong lật đật để van không bị vướng bên ngoài. - Bố  ┆ sẽ là món quà vô cùng ý nghĩa và lý thú cho những đợt du lịch    ┆                         ┆                         ┆            │
# │ mẹ dùng 1 tay bóp phần van 1 chiều, đồng thời dùng tay còn lại   ┆ sắp tới của bé cùng cả nhà.                  Hướng dẫn sử dụng   ┆                         ┆                         ┆            │
# │ ấn chặt lật đật để xả hơi ra ngoài. - Cho bé đeo dùng bơi dưới   ┆ Dùng bơm chuyên dụng để thổi không khí vào cho sản phẩm căng …   ┆                         ┆                         ┆            │
# │ nước. - Sử dụng dưới sự giám sát của người lớn trong lúc bơ…     ┆                                                                  ┆                         ┆                         ┆            │
# │ Ưu điểm nổi bật của sản phẩm Chất liệu nhựa an toàn- Máy bay     ┆ Chi tiết sản phẩm                     Tên sản phẩm: Máy bay nhập ┆ 0.94052                 ┆ 0.887719                ┆ 0.913357   │
# │ nhập vai bác sĩ JS035052  được làm từ chất liệu nhựa cao cấp,    ┆ vai bác sĩ JS035052         Thương hiệu: VANYEH TOYS             ┆                         ┆                         ┆            │
# │ rất nhẹ, có độ bền cao. Với chất liệu nhựa cao cấp, an toàn cho  ┆ Xuất xứ: Trung Quốc         Thành phần: Nhựa PP PE               ┆                         ┆                         ┆            │
# │ sức khỏe của bé và thân thiện với môi trường.- Bề mặt các chi    ┆ Máy bay nhập vai bác sĩ JS035052 là đồ chơi nhập vai dành cho    ┆                         ┆                         ┆            │
# │ tiết của bộ đồ chơi nhẵn mịn, không có các vi ba sắc nhọn không  ┆ trẻ em từ 3 tuổi của thương hiệu VANYEH TOYS đến từ Trung Quốc.  ┆                         ┆                         ┆            │
# │ làm trầy xước làn da nhạy cảm của bé khi tiếp xúc, giúp mẹ an    ┆ Sản phẩm giúp bé phát huy trí tưởng tượng và khám phá thế giới   ┆                         ┆                         ┆            │
# │ tâm mỗi khi bé chơi.Phát huy trí tưởng tượng- Đồ chơi có màu sắc ┆ nghề nghiệp.                        Chất liệu nhựa an toàn       ┆                         ┆                         ┆            │
# │ nổi bật, bắt mắt tạo cho bé cảm giác thích thú và hứng khởi hơn  ┆ Máy bay nhập vai bác sĩ JS035052 được làm từ chất liệu nhựa cao  ┆                         ┆                         ┆            │
# │ khi chơi, đồng thời kích thích thị giác bé phát triển. Mẹ có thể ┆ cấp, rất nhẹ, có độ bền cao. Với chất liệu nhựa an toàn cho sức  ┆                         ┆                         ┆            │
# │ hướng dẫn cho bé cách nhận biết màu sắc từ các chi tiết sản phẩm ┆ khỏe của bé và thân thiện với môi trường, bề mặt các chi tiết    ┆                         ┆                         ┆            │
# │ và hỏi lại bé giúp tăng khả năng ghi nhớ của bé.Bộ đồ chơi mang  ┆ của bộ đồ chơi nhẵn mịn không có các vi ba sắc nhọn, không làm   ┆                         ┆                         ┆            │
# │ tính chất hướng nghiệp- Đây là một trò chơi thật sự bổ ích giúp  ┆ trầy xước làn da nhạy cảm của bé, giúp mẹ an tâm mỗi khi bé      ┆                         ┆                         ┆            │
# │ bé hiểu thêm và yêu thích công việc bác sĩ cũng là những bước    ┆ chơi.               Phát huy trí tưởng tượng           Đồ chơi   ┆                         ┆                         ┆            │
# │ khởi đầu trong việc định hướng nghề nghiệp tương lai cho bé.- Bộ ┆ có màu sắc nổi bật, bắt mắt tạo cho bé cảm giác thích thú và     ┆                         ┆                         ┆            │
# │ đồ chơi được đựng trong một chiếc máy bay hiện đại và xinh xắn,  ┆ hứng khởi hơn khi chơi, đồng thời kích thích thị giác bé phát    ┆                         ┆                         ┆            │
# │ giúp bé có ý thức xếp gọn đồ sau khi chơi, rèn tính ngăn nắp cho ┆ triển. Mẹ có thể hướng dẫn cho bé cách nhận biết màu sắc từ các  ┆                         ┆                         ┆            │
# │ bé ngay từ khi còn nhỏ.- Sản phẩm có nhãn dán kèm theo cho bé    ┆ chi tiết sản phẩm và hỏi lại bé giúp tăng khả năng ghi nhớ của   ┆                         ┆                         ┆            │
# │ thỏa trí dán lên các vị trí theo hướng dẫn trên bao bì sản       ┆ bé.               Bộ đồ chơi mang tính chất hướng nghiệp         ┆                         ┆                         ┆            │
# │ phẩm. HƯỚNG DẪN BẢO QUẢN- Vệ sinh sản phẩm trước và sau khi sử   ┆ Đây là một trò chơi thật sự bổ ích giúp bé hiểu thêm và yêu      ┆                         ┆                         ┆            │
# │ dụng. Cảnh báo : không sử dụng sản phẩm cho bé dưới 3            ┆ thích công việc bác sĩ, cũng là những bước khởi đầu trong việc   ┆                         ┆                         ┆            │
# │ tuổi. THÔNG TIN SẢN PHẨM - Tên sản phẩm : Máy bay nhập vai bác   ┆ định hướng nghề nghiệp tương lai cho bé. Bộ đồ chơi được đựng    ┆                         ┆                         ┆            │
# │ sĩ JS035052 - Thương hiệu : VANYEH TOYS- Xuất xứ : Trung Quốc-   ┆ trong một chiếc máy bay hiện đại và xinh xắn, giúp bé có ý thức  ┆                         ┆                         ┆            │
# │ Thành phần : Nhựa PP PE                                          ┆ xếp gọn đồ sau khi chơi, rèn tính ngăn nắp cho bé ngay từ khi    ┆                         ┆                         ┆            │
# │                                                                  ┆ còn nhỏ. Sản phẩm có nhãn dán kèm theo cho bé thỏa sức dán lên   ┆                         ┆                         ┆            │
# │                                                                  ┆ các vị trí theo hướng dẫn trên bao bì sản phẩm.                  ┆                         ┆                         ┆            │
# │                                                                  ┆ Hướng dẫn bảo quản               Vệ sinh sản phẩm trước và sau   ┆                         ┆                         ┆            │
# │                                                                  ┆ khi sử dụng.                     Lưu ý               Cảnh báo:   ┆                         ┆                         ┆            │
# │                                                                  ┆ không sử dụng sản phẩm cho bé dưới 3 tuổi.                       ┆                         ┆                         ┆            │
# │                                                                  ┆ Thành phần               Nhựa PP         Nhựa PE                 ┆                         ┆                         ┆            │
# │ Địu ConCung Good 4 trong 1 (Đỏ) đa năng có thể địu bé ở 4 tư thế ┆ Chi tiết sản phẩm                     Tên sản phẩm: Địu ConCung  ┆ 0.942693                ┆ 0.882038                ┆ 0.911357   │
# │ khác nhau, rất thuận tiện để cùng bé dạo phố, đi chơi. Đặc điểm  ┆ Good 4 trong 1 (Đỏ)         Loại sản phẩm: Địu em bé đa năng     ┆                         ┆                         ┆            │
# │ sản phẩm: - Địu ConCung Good đa năng có thể địu bé ở 4 tư thế    ┆ Đối tượng sử dụng: Trẻ từ 3 đến 18 tháng         Thương hiệu:    ┆                         ┆                         ┆            │
# │ khác nhau, giúp bạn thuận tiện hơn khi cùng bé dạo phố, đi chơi. ┆ ConCung Good         Xuất xứ: Trung Quốc         Màu sắc: Đỏ,    ┆                         ┆                         ┆            │
# │ - Dây đai có thể điều chỉnh dễ dàng giúp bé thoải mái hơn. Hướng ┆ Xanh dương                     Địu ConCung Good 4 trong 1 (Đỏ)   ┆                         ┆                         ┆            │
# │ dẫn sử dụng: -  Kiểm tra kĩ lại các khóa, dây cài, dây đai và    ┆ là địu em bé đa năng dành cho trẻ từ 3 đến 18 tháng của thương   ┆                         ┆                         ┆            │
# │ các bộ phận khác thật đảm bảo trước khi sử dụng. - Luôn đảm bảo  ┆ hiệu ConCung Good đến từ Trung Quốc. Sản phẩm này có thể địu bé  ┆                         ┆                         ┆            │
# │ mũi và miệng bé không bị cản trở bởi địu hoặc quần áo để bé      ┆ ở 4 tư thế khác nhau, rất thuận tiện để cùng bé dạo phố, đi      ┆                         ┆                         ┆            │
# │ thoải mái. - Luôn để bé hướng mặt về phía bạn cho đến khi nào bé ┆ chơi.                     Địu ConCung Good đa năng với 4 tư thế  ┆                         ┆                         ┆            │
# │ đủ cứng cáp và đầu bé tự giữ thẳng được. - Luôn giữ chặt bé cho  ┆ địu           Địu ConCung Good đa năng có thể địu bé ở 4 tư thế  ┆                         ┆                         ┆            │
# │ đến khi nào các khóa và chốt được cài an toàn và dây đai đã được ┆ khác nhau, giúp bạn thuận tiện hơn khi cùng bé dạo phố, đi chơi. ┆                         ┆                         ┆            │
# │ quấn chặt vào người đeo. Phải ngồi xuống khi đặt hoặc di chuyển  ┆ Dây đai có thể điều chỉnh dễ dàng giúp bé thoải mái hơn.         ┆                         ┆                         ┆            │
# │ bé ra khỏi địu. Hướng dẫn bảo quản: - Vệ sinh thường xuyên bằng  ┆ Hướng dẫn sử dụng               Kiểm tra kĩ lại các khóa, dây    ┆                         ┆                         ┆            │
# │ khăn ẩm. - Sử dụng túi giặt nếu cần thiết và giặt riêng trong    ┆ cài, dây đai và các bộ phận khác thật đảm bảo trước khi sử dụng. ┆                         ┆                         ┆            │
# │ nước lạnh, áp lực nhẹ. - Không dùng chất tẩy trắng hoặc chất làm ┆ Luôn đảm bảo mũi và miệng bé không bị cản trở bởi địu hoặc quần  ┆                         ┆                         ┆            │
# │ mềm vải. - Không cho vào máy sấy hay sử dụng bàn ủi. Cảnh báo an ┆ áo để bé thoải mái.         Luôn để bé hướng mặt về phía bạn cho ┆                         ┆                         ┆            │
# │ toàn: - Không sử dụng khi đường may bị lỏng, rách, hoặc nếu địu  ┆ đến khi nào bé đủ cứng cáp và đầu bé tự giữ thẳng được.          ┆                         ┆                         ┆            │
# │ bị hỏng bất cứ chi tiết nào. - Không để vật nhọn đâm vào các     ┆ Luôn giữ chặt bé cho đến khi nào các khóa và chốt được cài an    ┆                         ┆                         ┆            │
# │ phần của địu. - Không để trẻ ở trong địu mà không có sự giám sát ┆ toàn và dây đai đã được quấn chặt vào người đeo. Phải ngồi xuống ┆                         ┆                         ┆            │
# │ của người lớn. Đối tượng sử dụng: - Chỉ sử dụng cho trẻ từ 3 đến ┆ khi đặt hoặc di chuyển bé ra khỏi địu.                     Hướng ┆                         ┆                         ┆            │
# │ 18tháng. Một số lưu ý khi sử dụng sản phẩm: - Chỉnh dây đai để   ┆ dẫn bảo quản               Vệ sinh thường xuyên bằng khăn ẩm.    ┆                         ┆                         ┆            │
# │ phân tán đều trọng lượng của bé ra hai bên vai. - Đối với những  ┆ Sử dụng túi giặt nếu cần thiết và giặt riêng trong nước lạnh, áp ┆                         ┆                         ┆            │
# │ bé nhỏ, điều chỉnh cho khoảng để chân nhỏ hơn, và đảm bảo có chỗ ┆ lực nhẹ.         Không dùng chất tẩy trắng hoặc chất làm mềm     ┆                         ┆                         ┆            │
# │ để đầu bé được thông thoáng và bé dễ thở. - Nếu bạn cảm thấy cái ┆ vải.         Không cho vào máy sấy hay sử dụng bàn ủi.           ┆                         ┆                         ┆            │
# │ địu bị chật so với bé: + Bước 1: Kiểm tra lại đã điều chỉnh các  ┆ Cảnh báo an toàn               Không sử dụng khi đường may bị    ┆                         ┆                         ┆            │
# │ khóa cài đúng với size của bé hay chưa. + Bước 2: Điều chỉnh     ┆ lỏng, rách, hoặc nếu địu bị hỏng bất cứ chi tiết nào.            ┆                         ┆                         ┆            │
# │ chốt khóa để gia tăng độ dài dây đai, việc này sẽ cho bé có      ┆ Không để vật nhọn đâm vào các phần của địu.         Không để trẻ ┆                         ┆                         ┆            │
# │ nhiều không gian hơn. Thương hiệu: ConCung Good Màu sắc: Xanh    ┆ ở trong địu mà không có sự giám sát của người lớn.               ┆                         ┆                         ┆            │
# │ dương, Đỏ Xuất xứ: Trung Quốc                                    ┆ Lưu ý               Chỉnh dây đai để phân tán đều trọng lượng    ┆                         ┆                         ┆            │
# │                                                                  ┆ của bé ra hai bên vai.         Đối với những bé nhỏ, điều chỉnh  ┆                         ┆                         ┆            │
# │                                                                  ┆ cho khoảng để chân nhỏ hơn, và đảm bảo có chỗ để đầu bé đư…      ┆                         ┆                         ┆            │
# │ Hộp thực phẩm vuông Hokkaido 750ml (nắp màu xanh)sử dụng 100%    ┆ Chi tiết sản phẩm                     Tên sản phẩm: Hộp thực     ┆ 0.898667                ┆ 0.920765                ┆ 0.909582   │
# │ nguyên liệu nhựa nguyên sinh an toàn, thân thiện với sức khỏe    ┆ phẩm vuông Hokkaido 750ml (nắp màu xanh)         Màu sắc nắp     ┆                         ┆                         ┆            │
# │ người dùng. Chất lượng cao, tích hợp các tính năng vượt trội,    ┆ hộp: Trắng sữa, Xanh sữa, Cam Hồng, Trắng trong         Màu sắc  ┆                         ┆                         ┆            │
# │ kháng khuẩn, khử mùi... Thiết kế đẹp và tiện lợi, phục vụ tối đa ┆ thân hộp: màu trong suốt         Kích thước sản phẩm: 128 x 128  ┆                         ┆                         ┆            │
# │ các nhu cầu thiết yếu và tiện ích của mọi gia đình. ĐẶC ĐIỂM SẢN ┆ x 66 mm (dài x rộng x cao)         Thương hiệu: Inochi           ┆                         ┆                         ┆            │
# │ PHẨM: Nguyên liệu an toàn, thân thiện với sức khỏe người         ┆ Xuất xứ: Việt Nam                        **Hộp thực phẩm vuông   ┆                         ┆                         ┆            │
# │ dùng: 100% hộp đựng thực phẩm Hokkaido được làm từ nhựa nguyên   ┆ Hokkaido 750ml (nắp màu xanh)** là hộp đựng thực phẩm dành cho   ┆                         ┆                         ┆            │
# │ sinh PP, đã thông qua kiểm định tiêu chuẩn về An toàn VSTP,      ┆ mọi gia đình của thương hiệu Inochi đến từ Việt Nam. Sản phẩm    ┆                         ┆                         ┆            │
# │ không chứa BPA, không màu, không mùi và không tiết ra các chất   ┆ này nổi bật với nguyên liệu nhựa an toàn, thân thiện với sức     ┆                         ┆                         ┆            │
# │ có hại trong quá trình sử dụng. Đặc biệt, việc sử dụng công nghệ ┆ khỏe người dùng.                        Nguyên liệu an toàn,     ┆                         ┆                         ┆            │
# │ ion bạc (Ag+) giúp sản phẩm có tính năng kháng khuẩn, khử mùi,   ┆ thân thiện với sức khỏe người dùng           100% hộp đựng thực  ┆                         ┆                         ┆            │
# │ đảm bảo độ tươi ngon, an toàn của thực phẩm. Thiết kế thông      ┆ phẩm Hokkaido được làm từ nhựa nguyên sinh PP, đã thông qua kiểm ┆                         ┆                         ┆            │
# │ minh, phù hợp với đa dạng nhu cầu sử dụng: Hộp đựng thực phẩm    ┆ định tiêu chuẩn về An toàn VSTP, không chứa BPA, không màu,      ┆                         ┆                         ┆            │
# │ Hokkaido được thiết kế với đa dạng kích cỡ để người dùng dự trữ  ┆ không mùi và không tiết ra các chất có hại trong quá trình sử    ┆                         ┆                         ┆            │
# │ khẩu phần một cách khoa học. Nắp đậy của hộp được làm kín khít   ┆ dụng. Đặc biệt, việc sử dụng công nghệ ion bạc (Ag+) giúp sản    ┆                         ┆                         ┆            │
# │ để giữ tối đa độ tươi ngon của thực phẩm. Hộp được dùng để lưu   ┆ phẩm có tính năng kháng khuẩn, khử mùi, đảm bảo độ tươi ngon, an ┆                         ┆                         ┆            │
# │ trữ, bảo quản cả thực phẩm khô, thực phẩm tươi sống hay thực     ┆ toàn của thực phẩm.               Thiết kế thông minh, phù hợp   ┆                         ┆                         ┆            │
# │ phẩm chín. Với trọng lượng gọn nhẹ, dễ di chuyển, bạn cũng có    ┆ với đa dạng nhu cầu sử dụng           Hộp đựng thực phẩm         ┆                         ┆                         ┆            │
# │ thể mang đồ ăn bằng những chiếc hộp xinh xắn này cho các chuyến  ┆ Hokkaido được thiết kế với đa dạng kích cỡ để người dùng dự trữ  ┆                         ┆                         ┆            │
# │ dã ngoại, picnic cùng người thân Bền bỉ, dẻo dai và chịu nhiệt   ┆ khẩu phần một cách khoa học. Nắp đậy của hộp được làm kín khít   ┆                         ┆                         ┆            │
# │ tốt: Hộp đựng thực phẩm Hokkaido chịu được cả nhiệt độ cao và    ┆ để giữ tối đa độ tươi ngon của thực phẩm. Hộp được dùng để lưu   ┆                         ┆                         ┆            │
# │ thấp (từ -20 đến 120 độ C). Bởi vậy độ bền của sản phẩm cao,     ┆ trữ, bảo quản cả thực phẩm khô, thực phẩm tươi sống hay thực     ┆                         ┆                         ┆            │
# │ không bị biến dạng và không tương tác hóa học với thực phẩm ngay ┆ phẩm chín. Với trọng lượng gọn nhẹ, dễ di chuyển, bạn cũng có    ┆                         ┆                         ┆            │
# │ cả khi sử dụng trong tủ lạnh hay máy rửa chén. Sử dụng hộp thực  ┆ thể mang đồ ăn bằng những chiếc hộp xinh xắn này cho các chuyến  ┆                         ┆                         ┆            │
# │ phẩm Hokkaido là bạn đã nắm trong tay các bí quyết giữ thực phẩm ┆ dã ngoại, picnic cùng người thân.               Bền bỉ, dẻo dai  ┆                         ┆                         ┆            │
# │ tươi ngon và an toàn của các đầu bếp và người nội trợ Nhật.      ┆ và chịu nhiệt tốt           Hộp đựng thực phẩm Hokkaido chịu     ┆                         ┆                         ┆            │
# │ THÔNG TIN SẢN PHẨM: Tên sản phẩm: Hộp thực phẩm vuông Hokkaido   ┆ được cả nhiệt độ cao và thấp (từ -20 đến 120 độ C). Bởi vậy độ   ┆                         ┆                         ┆            │
# │ 750ml (nắp màu xanh) Màu sắc nắp hộp: Trắng sữa, Xanh sữa, Cam   ┆ bền của sản phẩm cao, không bị biến dạng và không tương tác hóa  ┆                         ┆                         ┆            │
# │ Hồng, Trắng trong Màu sắc thân hộp: màu trong suốt Kích thước    ┆ học với thực phẩm ngay cả khi sử dụng trong tủ lạnh hay máy rửa  ┆                         ┆                         ┆            │
# │ sản phẩm: 128 x 128 x 66 mm (dài x rộng x cao) Thương            ┆ chén. Sử dụng hộp thực phẩm Hokkaido là bạn đã nắm trong tay các ┆                         ┆                         ┆            │
# │ hiệu: Inochi Xuất xứ: Việt Nam LƯU Ý: - Mở nắp sản phẩm khi sử   ┆ bí quyết giữ thực phẩm tươi ngon và an toàn của các đầu bếp và   ┆                         ┆                         ┆            │
# │ dụng trong lò vi sóng. - Không nên hâm trong lò vi sóng quá 2    ┆ người nội trợ Nhật.                  Hướng dẫn sử dụng    …      ┆                         ┆                         ┆            │
# │ phút. -…                                                         ┆                                                                  ┆                         ┆                         ┆            │
# │ Chất liệu an toàn - Phao bơi Spiderman Z802010-S được làm từ     ┆ Chi tiết sản phẩm                     Tên sản phẩm: Phao bơi     ┆ 0.972509                ┆ 0.84985                 ┆ 0.907051   │
# │ chất liệu an toàn với bề mặt mềm mại, láng mịn, bảo vệ làn da bé ┆ Spiderman Z802010-S         Thương hiệu: Mesuca         Xuất xứ: ┆                         ┆                         ┆            │
# │ và không gây kích ứng cho da, giúp bé thoải mái khi vui chơi.    ┆ Trung Quốc         Chất liệu: Nhựa PVC         Kích thước:       ┆                         ┆                         ┆            │
# │ Thích hợp sử dụng với bé - Phao bơi dạng hình tròn, dễ sử dụng   ┆ 60x60x12(cm)         Phù hợp cho bé từ: 3 tuổi trở lên           ┆                         ┆                         ┆            │
# ...
# │ chuyên dụng để thổi không khí vào cho sản phẩm căng lên. Hoặc bố ┆ căng lại            Tiện lợi, thuận tiện mang theo bởi có thể    ┆                         ┆                         ┆            │
# │ mẹ có thể bóp tay ở phần van 1 chiều và thổi bằng miệng. Sau khi ┆ rút hơi và gấp gọn. Phao bơi dễ dàng bơm căng lại chỉ với bơm    ┆                         ┆                         ┆            │
# │ thổi không khí vào ba mẹ đậy kín phần van lại và ấn phần van     ┆ hơi bằng tay.            Màu sắc nổi bật + Họa tiết Spiderman    ┆                         ┆                         ┆            │
# │ chìm và bên trong lật đật để van không bị vướng bên ngoài. - Bố  ┆ đáng yêu            Phao bơi Spiderman Z802010-S thu hút bé bởi  ┆                         ┆                         ┆            │
# │ mẹ dùng 1 tay bóp phần van 1 chiều, đồng thời dùng tay còn lại   ┆ màu sắc nổi bật và họa tiết ngộ nghĩnh. Họa tiết Spiderman đáng  ┆                         ┆                         ┆            │
# │ ấn chặt lật đật để xả hơi ra ngoài. - Cho bé đeo dùng bơi dưới   ┆ yêu mang đến cho bé cảm giác gắn kết hơn với hoạt động vui chơi  ┆                         ┆                         ┆            │
# │ nước. - Sử dụng dưới sự giám sát của người lớn trong lúc bơi.    ┆ dưới nước trong những ngày hè, từ đó tạo cho bé sự nổi bật và    ┆                         ┆                         ┆            │
# │ HƯỚNG DẪN BẢO QUẢN - Vệ sinh trước và sau sử dụng, tránh va đập  ┆ cảm giác thích thú khi vui chơi.               Hướng dẫn sử dụng ┆                         ┆                         ┆            │
# │ mạnh. - Tránh xa nguồn nhiệt.                                    ┆ Dùng bơm chuyên dụng để thổi không khí vào cho sản phẩm căng     ┆                         ┆                         ┆            │
# │                                                                  ┆ lên. Hoặc bố mẹ có thể bóp tay ở phần van 1 chiều và thổi bằng   ┆                         ┆                         ┆            │
# │                                                                  ┆ miệng.         Sau khi thổi không khí vào ba mẹ đậy kín phần van ┆                         ┆                         ┆            │
# │                                                                  ┆ lại và ấn phần van chìm và bên trong lật đật để van không bị     ┆                         ┆                         ┆            │
# │                                                                  ┆ vướng bên ngoài.         Bố mẹ dùng 1 tay bóp phần van 1 chiều,  ┆                         ┆                         ┆            │
# │                                                                  ┆ đồng thời dùng tay còn lại ấn chặt lật đật để …                  ┆                         ┆                         ┆            │
# │ Hộp thực phẩm vuông Hokkaido 1000ml (nắp màu xanh) sử dụng 100%  ┆ Chi tiết sản phẩm                     Tên sản phẩm: Hộp thực     ┆ 0.901333                ┆ 0.908602                ┆ 0.904953   │
# │ nguyên liệu nhựa nguyên sinh an toàn, thân thiện với sức khỏe    ┆ phẩm vuông Hokkaido 1000ml (nắp màu xanh)         Màu sắc nắp    ┆                         ┆                         ┆            │
# │ người dùng. Chất lượng cao, tích hợp các tính năng vượt trội,    ┆ hộp: Trắng sữa, Xanh sữa, Cam Hồng, Trắng trong         Màu sắc  ┆                         ┆                         ┆            │
# │ kháng khuẩn, khử mùi... Thiết kế đẹp và tiện lợi, phục vụ tối đa ┆ thân hộp: màu trong suốt         Kích thước sản phẩm: 128 x 128  ┆                         ┆                         ┆            │
# │ các nhu cầu thiết yếu và tiện ích của mọi gia đình. ĐẶC ĐIỂM SẢN ┆ x 88 mm (dài x rộng x cao)         Thương hiệu: Inochi           ┆                         ┆                         ┆            │
# │ PHẨM: Nguyên liệu an toàn, thân thiện với sức khỏe người         ┆ Xuất xứ: Việt Nam                        **Hộp thực phẩm vuông   ┆                         ┆                         ┆            │
# │ dùng: 100% hộp đựng thực phẩm Hokkaido được làm từ nhựa nguyên   ┆ Hokkaido 1000ml (nắp màu xanh)** là đồ dùng tiện ích dành cho    ┆                         ┆                         ┆            │
# │ sinh PP, đã thông qua kiểm định tiêu chuẩn về An toàn VSTP,      ┆ mọi gia đình của thương hiệu Inochi đến từ Việt Nam. Sản phẩm    ┆                         ┆                         ┆            │
# │ không chứa BPA, không màu, không mùi và không tiết ra các chất   ┆ được làm từ nguyên liệu nhựa nguyên sinh hoàn toàn an toàn cho   ┆                         ┆                         ┆            │
# │ có hại trong quá trình sử dụng. Đặc biệt, việc sử dụng công nghệ ┆ sức khỏe người sử dụng.                        Nguyên liệu an    ┆                         ┆                         ┆            │
# │ ion bạc (Ag+) giúp sản phẩm có tính năng kháng khuẩn, khử mùi,   ┆ toàn, thân thiện với sức khỏe người dùng           100% hộp đựng ┆                         ┆                         ┆            │
# │ đảm bảo độ tươi ngon, an toàn của thực phẩm. Thiết kế thông      ┆ thực phẩm Hokkaido được làm từ nhựa nguyên sinh PP, đã thông qua ┆                         ┆                         ┆            │
# │ minh, phù hợp với đa dạng nhu cầu sử dụng: Hộp đựng thực phẩm    ┆ kiểm định tiêu chuẩn về An toàn VSTP, không chứa BPA, không màu, ┆                         ┆                         ┆            │
# │ Hokkaido được thiết kế với đa dạng kích cỡ để người dùng dự trữ  ┆ không mùi và không tiết ra các chất có hại trong quá trình sử    ┆                         ┆                         ┆            │
# │ khẩu phần một cách khoa học. Nắp đậy của hộp được làm kín khít   ┆ dụng. Đặc biệt, việc sử dụng công nghệ ion bạc (Ag+) giúp sản    ┆                         ┆                         ┆            │
# │ để giữ tối đa độ tươi ngon của thực phẩm. Hộp được dùng để lưu   ┆ phẩm có tính năng kháng khuẩn, khử mùi, đảm bảo độ tươi ngon, an ┆                         ┆                         ┆            │
# │ trữ, bảo quản cả thực phẩm khô, thực phẩm tươi sống hay thực     ┆ toàn của thực phẩm.            Thiết kế thông minh, phù hợp với  ┆                         ┆                         ┆            │
# │ phẩm chín. Với trọng lượng gọn nhẹ, dễ di chuyển, bạn cũng có    ┆ đa dạng nhu cầu sử dụng           Hộp đựng thực phẩm Hokkaido    ┆                         ┆                         ┆            │
# │ thể mang đồ ăn bằng những chiếc hộp xinh xắn này cho các chuyến  ┆ được thiết kế với đa dạng kích cỡ để người dùng dự trữ khẩu phần ┆                         ┆                         ┆            │
# │ dã ngoại, picnic cùng người thân Bền bỉ, dẻo dai và chịu nhiệt   ┆ một cách khoa học. Nắp đậy của hộp được làm kín khít để giữ tối  ┆                         ┆                         ┆            │
# │ tốt: Hộp đựng thực phẩm Hokkaido chịu được cả nhiệt độ cao và    ┆ đa độ tươi ngon của thực phẩm. Hộp được dùng để lưu trữ, bảo     ┆                         ┆                         ┆            │
# │ thấp (từ -20 đến 120 độ C). Bởi vậy độ bền của sản phẩm cao,     ┆ quản cả thực phẩm khô, thực phẩm tươi sống hay thực phẩm chín.   ┆                         ┆                         ┆            │
# │ không bị biến dạng và không tương tác hóa học với thực phẩm ngay ┆ Với trọng lượng gọn nhẹ, dễ di chuyển, bạn cũng có thể mang đồ   ┆                         ┆                         ┆            │
# │ cả khi sử dụng trong tủ lạnh hay máy rửa chén. Sử dụng hộp thực  ┆ ăn bằng những chiếc hộp xinh xắn này cho các chuyến dã ngoại,    ┆                         ┆                         ┆            │
# │ phẩm Hokkaido là bạn đã nắm trong tay các bí quyết giữ thực phẩm ┆ picnic cùng người thân.            Bền bỉ, dẻo dai và chịu nhiệt ┆                         ┆                         ┆            │
# │ tươi ngon và an toàn của các đầu bếp và người nội trợ Nhật.      ┆ tốt           Hộp đựng thực phẩm Hokkaido chịu được cả nhiệt độ  ┆                         ┆                         ┆            │
# │ THÔNG TIN SẢN PHẨM: Tên sản phẩm: Hộp thực phẩm vuông Hokkaido   ┆ cao và thấp (từ -20 đến 120 độ C). Bởi vậy độ bền của sản phẩm   ┆                         ┆                         ┆            │
# │ 1000ml (nắp màu xanh) Màu sắc nắp hộp: Trắng sữa, Xanh sữa, Cam  ┆ cao, không bị biến dạng và không tương tác hóa học với thực phẩm ┆                         ┆                         ┆            │
# │ Hồng, Trắng trong Màu sắc thân hộp: màu trong suốt Kích thước    ┆ ngay cả khi sử dụng trong tủ lạnh hay máy rửa chén. Sử dụng hộp  ┆                         ┆                         ┆            │
# │ sản phẩm: 128 x 128 x 88 mm (dài x rộng x cao) Thương            ┆ thực phẩm Hokkaido là bạn đã nắm trong tay các bí quyết giữ thực ┆                         ┆                         ┆            │
# │ hiệu: Inochi Xuất xứ: Việt Nam LƯU Ý: - Mở nắp sản phẩm khi sử   ┆ phẩm tươi ngon và an toàn của các đầu bếp và người nội trợ Nhật. ┆                         ┆                         ┆            │
# │ dụng trong lò vi sóng. - Không nên hâm trong lò vi sóng quá 2    ┆ Hướng dẫn sử dụng    …                                           ┆                         ┆                         ┆            │
# │ phút…                                                            ┆                                                                  ┆                         ┆                         ┆            │
# │ ﻿﻿Gối memory foam chống trào ngược và cho bé bú ConCung Good       ┆ Chi tiết sản phẩm                     Tên sản phẩm: Gối memory   ┆ 0.941176                ┆ 0.858757                ┆ 0.89808    │
# │ (Xanh) là sản phẩm gối chống trào ngược cao cấp được làm từ chất ┆ foam chống trào ngược và cho bé bú ConCung Good (Xanh)           ┆                         ┆                         ┆            │
# │ liệu Memory Foam an toàn và ngủ yên giấc suốt đêm. ĐẶC ĐIỂM SẢN  ┆ Thương hiệu: ConCung Good         Chất liệu:                     ┆                         ┆                         ┆            │
# │ PHẨM: - Gối có góc nghiêng phù hợp giúp nâng đỡ đầu và cơ thể    ┆ Vỏ gối bên ngoài: Cotton                 Vỏ gối bên trong:       ┆                         ┆                         ┆            │
# │ của bé. Hướng nâng cao này tạo thêm sự thoải mái dẫn đến giấc    ┆ Polyester                 Ruột gối: Memory Foam (100% PU)        ┆                         ┆                         ┆            │
# │ ngủ ngon hơn và giúp bé thở và tiêu hóa dễ dàng sau khi bú mẹ.   ┆ Độ tuổi sử dụng: từ 0 tháng tuổi trở lên         Kích thước: 35  ┆                         ┆                         ┆            │
# │ Nó có thể cải thiện hiệu quả giấc ngủ và giảm trào ngược axit và ┆ x 50 x 7 cm         Xuất Xứ: Trung Quốc                          ┆                         ┆                         ┆            │
# │ vấn đề nghẹt mũi. - Ruột gối bằng chất liệu Memory Foam cao cấp  ┆ **Gối memory foam chống trào ngược và cho bé bú ConCung Good     ┆                         ┆                         ┆            │
# │ giúp bé luôn thoải mái và ngủ yên giấc suốt đêm dài. Chất Memory ┆ (Xanh)** là gối chống trào ngược cao cấp dành cho bé sơ sinh của ┆                         ┆                         ┆            │
# │ Foam siêu an toàn và không có hóa chất, không có BPA,            ┆ thương hiệu ConCung Good đến từ Trung Quốc. Sản phẩm giúp bé ngủ ┆                         ┆                         ┆            │
# │ formaldehyde,vv... - Vỏ gối có thể tháo rời và giặt được. Lớp vỏ ┆ ngon hơn nhờ thiết kế nâng cao giúp giảm trào ngược axit.        ┆                         ┆                         ┆            │
# │ mềm mại không gây dị ứng này giúp dễ dàng lau sạch các vết rỉ,   ┆ GỐI CHỐNG TRÀO NGƯỢC giúp nâng đỡ đầu và cơ thể của bé           ┆                         ┆                         ┆            │
# │ nước dãi và tã lót của em bé. - Gối chống trào ngược được thiết  ┆ Gối có góc nghiêng phù hợp giúp nâng đỡ đầu và cơ thể của bé.    ┆                         ┆                         ┆            │
# │ kế với sự thoải mái và lưu tâm đến em bé của bạn, và phổ biến    ┆ Hướng nâng cao này tạo thêm sự thoải mái dẫn đến giấc ngủ ngon   ┆                         ┆                         ┆            │
# │ cho bé. - Có thể xách tay và mang đi dễ dàng. Đơn giản chỉ cần   ┆ hơn và giúp bé thở và tiêu hóa dễ dàng sau khi bú mẹ. Nó có thể  ┆                         ┆                         ┆            │
# │ cuộn chiếc gối nêm lại, cho vào túi xách hoặc đóng gói trong     ┆ cải thiện hiệu quả giấc ngủ và giảm trào ngược axit và vấn đề    ┆                         ┆                         ┆            │
# │ vali. - Đặt bé nằm lên phần cao hơn của gối. THÔNG TIN SẢN PHẨM  ┆ nghẹt mũi.               RUỘT GỐI MEMORY FOAM cao cấp mang lại   ┆                         ┆                         ┆            │
# │ - Tên sản phẩm: Gối memory foam chống trào ngược và cho bé bú    ┆ sự thoải mái            Ruột gối bằng chất liệu Memory Foam cao  ┆                         ┆                         ┆            │
# │ ConCung Good (Xanh) - Thương hiệu: ConCung Good - Chất liệu: +   ┆ cấp giúp bé luôn thoải mái và ngủ yên giấc suốt đêm dài. Chất    ┆                         ┆                         ┆            │
# │ Vỏ gối bên ngoài: Cotton + Vỏ gối bên trong: Polyester + Ruột    ┆ Memory Foam siêu an toàn và không có hóa chất, không có BPA,     ┆                         ┆                         ┆            │
# │ gối: Memory Foam (100% PU) - Độ tuổi sử dụng: từ 0 tháng tuổi    ┆ formaldehyde, vv...               VỎ GỐI THÁO RỜI và DỄ GIẶT     ┆                         ┆                         ┆            │
# │ trở lên - Kích thước: 35 x 50 x 7 cm - Xuất Xứ: Trung Quốc LƯU Ý ┆ Vỏ gối có thể tháo rời và giặt được. Lớp vỏ mềm mại không gây dị ┆                         ┆                         ┆            │
# │ BẢO QUẢN: - Chỉ vệ sinh vỏ gối - Không dùng bột giặt có chất     ┆ ứng này giúp dễ dàng lau sạch các vết rỉ, nước dãi và tã lót của ┆                         ┆                         ┆            │
# │ tẩy. - Hạn chế ngâm lâu trong nước, giặt chung với các sản phẩm  ┆ em bé.            THIẾT KẾ GỌN NHẸ và TIỆN DỤNG            Gối   ┆                         ┆                         ┆            │
# │ đậm mài, dễ ra màu - Không giặt bằng nước nóng (nhiệt độ tối đa  ┆ chống trào ngược được thiết kế với sự thoải mái và lưu tâm đến   ┆                         ┆                         ┆            │
# │ 30 độ) - Không nên giặt máy. - Hạn chế phơi trực tiếp dưới ánh   ┆ em bé của bạn, và phổ biến cho bé. Có thể xách tay và mang đi dễ ┆                         ┆                         ┆            │
# │ nắng đối với sản phẩm đậm màu. THÔNG TIN CẢNH BÁO: - Kiểm tra    ┆ dàng. Đơn giản chỉ cần cuộn chiếc gối nêm lại, cho vào túi xách  ┆                         ┆                         ┆            │
# │ sản phẩm trước khi sử dụng - Sử dụng sản phẩm dưới sự giám sát   ┆ hoặc đóng gói trong vali.               HƯỚNG DẪN SỬ DỤNG GÓI    ┆                         ┆                         ┆            │
# │ của người lớn - Tránh để gối tiếp xúc trực tiếp với nguồn nhiệt. ┆ Đặt bé nằm lên phần cao hơn của gối.                  Hướng dẫn  ┆                         ┆                         ┆            │
# │                                                                  ┆ bảo quản               Chỉ vệ sinh vỏ gối         Không dùng bột ┆                         ┆                         ┆            │
# │                                                                  ┆ giặt có chất tẩy.         Hạn chế…                               ┆                         ┆                         ┆            │
# └──────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────┴─────────────────────────┴─────────────────────────┴────────────┘

# %% [markdown]
# **mean Contain(A|B) = 0.623**
# - Trung bình 62.3% bigram trong description cũng có trong description_new.
# - Khi có dữ liệu thật, description_new bao phủ phần lớn nội dung của description.
#
# **mean Contain(B|A) = 0.324**
# - Chỉ 32.4% bigram trong description_new xuất hiện trong description.
# -  description_new giàu/chi tiết hơn, có nhiều cụm mới (vd. “Tên sản phẩm/Thương hiệu/Xuất xứ/Kích thước…”) mà description không có.
# -  Đây là lý do precision thấp.
#
# **mean F1 = 0.405**
# - Trung bình độ khớp hai chiều chỉ ở mức vừa (hàm hòa hợp của hai contain). Bị kéo xuống bởi B|A thấp.
#
# **median Contain(A|B) = 0.620; p90 = 0.807**
# - 50% cặp có ≥62% nội dung description được bao bởi description_new; top 10% đạt ≥80.7%.
# - Phân bố khá lệch: nhiều cặp khớp tốt, nhưng cũng có không ít cặp lệch mạnh (kéo mean xuống).
